# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from skimage.metrics import structural_similarity as ssim
from sklearn import preprocessing
from keras.utils import to_categorical
from keras import regularizers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.layers import Input, Dense, Dropout, Lambda, GlobalAveragePooling2D
from keras.src.legacy.preprocessing.image import ImageDataGenerator

import random
import re
import glob
from tqdm import tqdm
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
import gc
# Out:
# 2025-03-14 12:34:25.716835: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-14 12:34:25.824435: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-14 12:34:25.862151: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-14 12:34:26.580838: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs disponíveis: {gpus}")
else:
    print("Nenhuma GPU encontrada.")
# Out:
# GPUs disponíveis: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741966485.495540    1129 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741966487.497222    1129 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741966487.497316    1129 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# nome = 'PACS'
nome = 'Yildirim'
#nome = 'Todos'

imgs_path = 'Bases/Dataset' + nome

TEST_SIZE = 0.1
VALIDATION_SIZE = 0.1

SIMILARITY = 0.75

EPOCHS = 100
BATCH_SIZE = 32

HIGH_FREQ_THRESHOLD = 12

# %%
def get_next_filename(output_folder, base_name, type):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    image_index = 0
    
    while True:
        output_filename = f"{base_name}_{image_index}.{type}"
        output_path = os.path.join(output_folder, output_filename)
        
        if not os.path.exists(output_path):
            return output_filename
            
        image_index += 1

# %%
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else 0

# %%
def sort_files_numerically(file_paths):
    return sorted(file_paths, key=lambda x: extract_number(x))

# %%
def find_groups(images, image_paths, test_size, similarity_threshold):
    def are_similar(img1, img2, threshold):
        similarity = ssim(img1, img2)
        return similarity >= threshold

    groups = []
    current_group = [image_paths[0]]

    for i in range(1, len(images)):
        if are_similar(images[i-1], images[i], similarity_threshold):
            current_group.append(image_paths[i])
        else:
            groups.append(current_group)
            current_group = [image_paths[i]]
    
    if current_group:
        groups.append(current_group)

    all_images = [img_path for group in groups for img_path in group]

    for img_path in image_paths:
        if img_path not in all_images:
            groups.append([img_path])

    random.shuffle(groups)

    train_set = []
    test_set = []
    current_test_size = 0
    
    for i, group in enumerate(groups):
        if current_test_size + len(group) <= test_size:
            test_set.extend(group)
            current_test_size += len(group)
        else:
            train_set.extend(group)

    return train_set, test_set

# %%
output_folder = 'Groups'
type = 'txt'

def save_groups(train_groups, test_groups, base_name):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    output_filename = get_next_filename(output_folder, base_name, type)
    output_path = os.path.join(output_folder, output_filename)

    with open(output_path, 'w') as file:
        file.write('- test:\n')
        for idx, group in enumerate(test_groups, start=1):
            for img in group:
                file.write(f"{img}\n")
        
        file.write('- train:\n')
        for idx, group in enumerate(train_groups, start=1):
            for img in group:
                file.write(f'{img}\n')
    
    print(f'Group information saved in {output_path}')

# %%
def read_dataset(path, jpg, png):
    print(f'Reading dataset...\n')
    
    img_type = []
    images = []
    image_paths = []

    if jpg:
        img_type.append('*.jpg')
    if png:
        img_type.append('*.png')

# Normal

    normal_path = os.path.join(path, 'Train', 'Normal')
    print(f'Reading Normal images from: {normal_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(normal_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# Kidney

    kidney_stone_path = os.path.join(path, 'Train', 'Kidney_stone')
    print(f'Reading Kidney_stone images from: {kidney_stone_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(kidney_stone_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# ...
    
    images = np.array(images)
    image_paths = np.array(image_paths)

    return images, image_paths

# %%
all_X, all_image_paths = read_dataset(path=imgs_path, jpg=True, png=True)
# Out:
# Reading dataset...
#
# Reading Normal images from: Bases/DatasetYildirim/Train/Normal
# Reading Kidney_stone images from: Bases/DatasetYildirim/Train/Kidney_stone

# %%
def freq_spec(image, threshold, add_noise):
    f = np.fft.fft2(image)
    fshift = np.fft.fftshift(f)

    if add_noise:
        amplification_factor = 0.5
        
        rows, cols = image.shape
        crow, ccol = rows//2, cols//2

        mask = np.zeros((rows, cols), dtype=bool)
        mask[crow-threshold:crow+threshold, ccol-threshold:ccol+threshold] = True
        high_freq_mask = ~mask

        fshift[high_freq_mask] *= amplification_factor

    magnitude_spectrum_high = 20 * np.log(np.abs(fshift) + 1)

    return magnitude_spectrum_high

# %%
def save_specs(images, threshold, add_noise):
    specs = []
    for img in images:
        specs.append(freq_spec(img, threshold, add_noise))
    return specs

# %%
# Processar todas as imagens e criar labels
all_specs = []
all_labels = []

# Processar metade normal e metade hackeada
half = len(all_X) // 2
for i, img in enumerate(all_X):
    if i < half:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=False))
        all_labels.append(0)
    else:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=True))
        all_labels.append(1)

all_specs = np.array(all_specs)
all_labels = np.array(all_labels)

# %%
#len_normal_specs = int(len(all_X) / 2)

# %%
#normal_specs = all_X[0:len_normal_specs]

# %%
#normal_specs = save_specs(normal_specs, 100 - HIGH_FREQ_THRESHOLD, add_noise = False)

# %%
#print(len(normal_specs))

# %%
#hacked_specs = all_X[len_normal_specs:len(all_X)]

# %%
#hacked_specs = save_specs(hacked_specs, 100 - HIGH_FREQ_THRESHOLD, add_noise = True)

# %%
#print(len(hacked_specs))

# %%
print("Quantidade das imagens:", all_specs.shape)
print("Exemplo dos labels (False = original, True = com ruído):", all_labels)
# Out:
# Quantidade das imagens: (1799, 224, 224)
# Exemplo dos labels (False = original, True = com ruído): [0 0 0 ... 1 1 1]

# %%
X_train, X_test, y_train, y_test, paths_train, paths_test = train_test_split(
        all_specs, all_labels, all_image_paths,
        test_size=TEST_SIZE, 
        stratify=all_labels,
#       random_state=53
    )

# %%
def plot_specs(specs, title):
    total_images = len(specs)
    imgs_per_figure = 100
    cols = 5
    rows = (imgs_per_figure + cols - 1) // cols

    for start in range(0, total_images, imgs_per_figure):
        plt.figure(figsize=(cols * 3, rows * 3))
        end = min(start + imgs_per_figure, total_images)
        
        for i in range(start, end):
            plt.subplot(rows, cols, i - start + 1)
            plt.imshow(specs[i], cmap='gray')
            plt.title(f"{title} - freq spec: img {i+1}")
            plt.axis('off')
            
        plt.tight_layout()
        plt.show()

# %%
# Plotar todos os espectros de teste
#plot_specs(X_test, title="test")

# %%
#pausa de teste

# %%
# Defines the model layers (now for ResNet50)
def model_resnet50():  # (Optional: Rename the function for clarity)
    # Camada de entrada para imagens em escala de cinza (mantido igual)
    inputs = Input(shape=(224, 224, 1))
    
    # 1. Conversão para 3 canais (mantido igual)
    x = Lambda(lambda x: tf.repeat(x, 3, axis=-1))(inputs)
    
    # 2. Pré-processamento ResNet (mantido igual)
    x = tf.keras.applications.resnet.preprocess_input(x)
    
    # 3. *** ALTERAÇÃO PRINCIPAL: Carregar ResNet-50 ***
    base_model = tf.keras.applications.ResNet50(
        weights='imagenet',
        include_top=False,
        input_tensor=x
    )
    
    # 4. Topo personalizado (mantido igual)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(150, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    x = Dense(100, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    outputs = Dense(2, activation='softmax')(x)
    
    # Compilação (mantido igual)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer='Adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
# Configurar K-Fold
kfold = StratifiedKFold(n_splits=5, shuffle=True)
#kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=53)
fold_no = 1
histories = []
metrics = []

for train_idx, val_idx in kfold.split(X_train, y_train):
    print(f'\nTraining Fold {fold_no}/5')
    
# Split dos dados
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]
    
# Pré-processamento final
    X_train_fold = np.expand_dims(X_train_fold, axis=-1)
    X_val_fold = np.expand_dims(X_val_fold, axis=-1)
    y_train_fold_cat = to_categorical(y_train_fold, 2)
    y_val_fold_cat = to_categorical(y_val_fold, 2)

# Criar novo modelo para cada fold
    model = model_resnet50()

# Checkpoint com nome do fold
    output_folder = 'Models_saves'
    base_name = 'model_' + nome
    type = 'keras'
    model_filepath = os.path.join(output_folder, get_next_filename(output_folder, base_name, type))
    
    checkpoint = ModelCheckpoint(
        f'model_{nome}_fold_{fold_no}.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1,
        mode='max'
    )

# Calcula tempo
    start_time = time.time()
    
# Treinar modelo
    history = model.fit(
        X_train_fold, y_train_fold_cat,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val_fold, y_val_fold_cat),
        callbacks=[checkpoint],
        verbose=1
    )

# Calcula tempo
    end_time = time.time()

    training_time = end_time - start_time
    print(f"\nO modelo demorou {training_time:.2f} segundos para treinar.")
    
# Coletar métricas
    histories.append(history)
    predictions = model.predict(X_val_fold)
    y_pred = np.argmax(predictions, axis=1)
    metrics.append({
        'fold': fold_no,
        'report': classification_report(y_val_fold, y_pred, output_dict=True, zero_division=0),
        'matrix': confusion_matrix(y_val_fold, y_pred)
    })
    
    fold_no += 1

    del model  # Liberar memória do modelo
    tf.keras.backend.clear_session()  # Limpar sessão do TensorFlow
    gc.collect()  # Forçar coleta de lixo
# Out:
# Training Fold 1/5
# I0000 00:00:1741966552.659061    1129 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741966552.659552    1129 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741966552.659668    1129 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741966553.062541    1129 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741966553.062645    1129 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-14 12:35:53.062657: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1741966553.062740    1129 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-14 12:35:53.062814: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:10:00.0, compute capability: 8.6
# Epoch 1/100
# I0000 00:00:1741966585.281314    1190 service.cc:146] XLA service 0x7fe0d0002b50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741966585.281415    1190 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-03-14 12:36:26.592038: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-14 12:36:29.548554: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 2025-03-14 12:36:33.682413: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15567', 196 bytes spill stores, 196 bytes spill loads
#
# 2025-03-14 12:36:59.061251: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng53{k2=5,k13=1,k14=2,k18=1,k23=0} for conv (f32[32,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,28,28]{3,2,1,0}, f32[128,512,1,1]{3,2,1,0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-03-14 12:36:59.064756: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.93679252s
# Trying algorithm eng53{k2=5,k13=1,k14=2,k18=1,k23=0} for conv (f32[32,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,28,28]{3,2,1,0}, f32[128,512,1,1]{3,2,1,0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# I0000 00:00:1741966638.028465    1190 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 896ms/step - accuracy: 0.8779 - loss: 3.6297
# 2025-03-14 12:37:59.808634: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1760', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-03-14 12:38:00.094510: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1760', 8 bytes spill stores, 8 bytes spill loads
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.8798 - loss: 3.6114 - val_accuracy: 0.5000 - val_loss: 405235.2500
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 1.2919
# Epoch 2: val_accuracy improved from 0.50000 to 0.50309, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 274ms/step - accuracy: 1.0000 - loss: 1.2863 - val_accuracy: 0.5031 - val_loss: 58.6313
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.5490
# Epoch 3: val_accuracy improved from 0.50309 to 0.98765, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 244ms/step - accuracy: 1.0000 - loss: 0.5469 - val_accuracy: 0.9877 - val_loss: 0.6481
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.2667
# Epoch 4: val_accuracy improved from 0.98765 to 1.00000, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 13s 315ms/step - accuracy: 1.0000 - loss: 0.2659 - val_accuracy: 1.0000 - val_loss: 0.3952
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.1449
# Epoch 5: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 1.0000 - loss: 0.1446 - val_accuracy: 1.0000 - val_loss: 0.2019
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0877
# Epoch 6: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 1.0000 - loss: 0.0875 - val_accuracy: 1.0000 - val_loss: 0.1172
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0582
# Epoch 7: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 1.0000 - loss: 0.0581 - val_accuracy: 1.0000 - val_loss: 0.0661
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0413
# Epoch 8: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 1.0000 - loss: 0.0413 - val_accuracy: 1.0000 - val_loss: 0.0414
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 1.0000 - loss: 0.0303
# Epoch 9: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - accuracy: 1.0000 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 0.0372
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0234
# Epoch 10: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 167ms/step - accuracy: 1.0000 - loss: 0.0233 - val_accuracy: 1.0000 - val_loss: 0.0255
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0196
# Epoch 11: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 1.0000 - val_loss: 0.0231
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0151
# Epoch 12: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 0.0222
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 13: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 1.0000 - loss: 0.0110
# Epoch 14: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 15: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 167ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 16: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 172ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 17: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 170ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 18: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 19: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 166ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 20: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 21: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 166ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 22: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 23: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 228ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 24: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 25: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 26: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 27: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 28: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 29: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 30: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 31: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 32: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 33: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 232ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 34: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 35: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 36: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 37: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 38: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 39: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 40: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 41: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 42: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 43: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 44: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 45: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 46: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 47: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 48: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 49: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 50: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 51: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 52: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 53: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 54: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 55: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 56: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 57: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 58: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 59: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 60: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 61: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 62: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 236ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 63: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 64: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 65/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 65: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 66: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 67: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 68/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 68: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 69/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 69: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 70/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 70: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 71/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 71: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 72/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 72: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 234ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 73/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 73: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 74/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 74: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 75/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 75: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 76/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 76: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 77/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 77: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 232ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 78/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 78: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 79/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 79: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 80/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 80: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 81/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 81: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 82/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 82: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 83/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 83: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 84/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 84: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 85/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 85: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 86/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 86: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 87/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 87: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 88/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 88: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 89/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 89: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 90/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 90: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 91/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 91: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 92/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 92: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 234ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 93/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 93: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 94/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 94: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 95/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 95: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 96/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 96: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 97/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 97: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 98/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0152
# Epoch 98: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 1.0000 - val_loss: 0.0216
# Epoch 99/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9988 - loss: 0.0241
# Epoch 99: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 0.9988 - loss: 0.0248 - val_accuracy: 1.0000 - val_loss: 0.1254
# Epoch 100/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0976
# Epoch 100: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 1.0000 - loss: 0.0971 - val_accuracy: 1.0000 - val_loss: 0.0369
#
# O modelo demorou 856.51 segundos para treinar.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 273ms/step
#
# Training Fold 2/5
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.8866 - loss: 3.5730
# Epoch 1: val_accuracy improved from -inf to 0.49383, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.8885 - loss: 3.5532 - val_accuracy: 0.4938 - val_loss: 43.8690
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 1.1281
# Epoch 2: val_accuracy improved from 0.49383 to 0.76235, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 213ms/step - accuracy: 1.0000 - loss: 1.1226 - val_accuracy: 0.7623 - val_loss: 1.0074
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.4223
# Epoch 3: val_accuracy improved from 0.76235 to 0.89198, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 229ms/step - accuracy: 1.0000 - loss: 0.4206 - val_accuracy: 0.8920 - val_loss: 0.4723
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.1858
# Epoch 4: val_accuracy improved from 0.89198 to 0.99691, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 300ms/step - accuracy: 1.0000 - loss: 0.1851 - val_accuracy: 0.9969 - val_loss: 0.1152
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0920
# Epoch 5: val_accuracy improved from 0.99691 to 1.00000, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 230ms/step - accuracy: 1.0000 - loss: 0.0917 - val_accuracy: 1.0000 - val_loss: 0.0583
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0512
# Epoch 6: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0511 - val_accuracy: 1.0000 - val_loss: 0.0354
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9913 - loss: 0.1010
# Epoch 7: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 0.9914 - loss: 0.1017 - val_accuracy: 0.5000 - val_loss: 26165.8555
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.1164
# Epoch 8: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.1159 - val_accuracy: 0.5000 - val_loss: 63.9182
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 1.0000 - loss: 0.0518
# Epoch 9: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 236ms/step - accuracy: 1.0000 - loss: 0.0517 - val_accuracy: 1.0000 - val_loss: 0.0385
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0312
# Epoch 10: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0312 - val_accuracy: 1.0000 - val_loss: 0.0255
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0216
# Epoch 11: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 0.0313
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0165
# Epoch 12: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0165 - val_accuracy: 1.0000 - val_loss: 0.0243
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0132
# Epoch 13: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 0.0146
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0112
# Epoch 14: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0105
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 15: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 16: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 17: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 18: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 19: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 20: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 21: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 22: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 23: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 24: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 25: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 26: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 27: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 28: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 29: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 30: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 31: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 32: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 33: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 34: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 35: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 36: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9981 - loss: 0.0319
# Epoch 37: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 0.9981 - loss: 0.0317 - val_accuracy: 0.5000 - val_loss: 4291.4033
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 38: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.5000 - val_loss: 28.5168
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 39: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9784 - val_loss: 0.1319
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 40: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0238
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 41: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0320
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 42: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 43: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 44: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 45: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 46: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 166ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 47: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 48: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 232ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 49: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 50: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 51: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 52: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 53: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 54: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 55: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 56: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 171ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 57: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 58: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 59: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 60: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 61: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 62: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 226ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 63: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9969 - val_loss: 0.0085
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9999 - loss: 0.0031
# Epoch 64: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 0.9999 - loss: 0.0037 - val_accuracy: 0.5000 - val_loss: 1.1697
# Epoch 65/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7751 - loss: 1.5082
# Epoch 65: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 0.7782 - loss: 1.4907 - val_accuracy: 0.5000 - val_loss: 796653.0625
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9839 - loss: 0.3193
# Epoch 66: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 0.9840 - loss: 0.3179 - val_accuracy: 0.5000 - val_loss: 874.4360
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9929 - loss: 0.1380
# Epoch 67: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 234ms/step - accuracy: 0.9928 - loss: 0.1378 - val_accuracy: 0.5000 - val_loss: 144.3734
# Epoch 68/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9946 - loss: 0.0953
# Epoch 68: val_accuracy did not improve from 1.00000
# ...
# Epoch 39: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 40: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 41: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 42: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 43: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 44: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 169ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 45: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 46: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 172ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 47: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 48: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 49: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 50: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 51: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 52: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 226ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 53: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 172ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 54: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 55: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 56: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 57: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 58: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 59: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 60: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 61: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 62: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 63: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 64: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 184ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 65/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 65: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 66: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 67: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 234ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 68/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 68: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 69/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 69: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 70/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 70: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 71/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 71: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 72/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 72: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 73/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 73: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 74/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 74: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 173ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 75/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 75: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 76/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 76: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 237ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 77/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 77: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 78/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 78: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 79/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 79: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 80/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 80: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 81/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 81: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 226ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 82/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 82: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 83/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 83: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 84/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 84: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 85/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 85: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 86/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 86: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 234ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 87/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 87: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 88/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 88: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 169ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 89/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 89: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 90/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 90: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 91/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 91: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 234ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 92/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 92: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 93/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 93: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 94/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 94: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 95/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 95: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 96/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 96: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 97/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 97: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 98/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 98: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 99/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 99: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 100/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 100: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0302
#
# O modelo demorou 798.35 segundos para treinar.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 281ms/step
#
# Training Fold 4/5
# Epoch 1/100

# %%
print('\n\nCross-Validation Results:')
for metric in metrics:
    print(f'\nFold {metric["fold"]}:')
    print(classification_report(y_val_fold, y_pred, target_names=cm_plot_labels))

# Treinar modelo final com todos os dados de treino
final_model = model_resnet50()
final_model.fit(
    np.expand_dims(all_train_specs, axis=-1),
    to_categorical(all_train_labels, 2),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    verbose=1
)

# Avaliar no teste final
test_loss, test_acc = final_model.evaluate(
    np.expand_dims(X_test, axis=-1),
    to_categorical(y_test, 2),
    verbose=0
)
print(f'\nFinal Test Accuracy: {test_acc:.4f}')

# Gerar gráficos finais (substituir)
y_pred_test = np.argmax(final_model.predict(np.expand_dims(X_test, axis=-1)), axis=1)
plot_and_save_report(y_test, y_pred_test)
plot_and_matrix(y_test, y_pred_test, cm_plot_labels)

cm_plot_labels = ['Normal', 'Hacked']

# %%
# GC collect
tf.keras.backend.clear_session()
gc.collect()
