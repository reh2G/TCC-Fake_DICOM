# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, jaccard_score, f1_score, precision_score, recall_score
from skimage.metrics import structural_similarity as ssim
from sklearn import preprocessing
from keras.utils import to_categorical
from keras import regularizers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.layers import Input, Dense, Dropout, Lambda, GlobalAveragePooling2D
from keras.src.legacy.preprocessing.image import ImageDataGenerator

import random
import re
import glob
from tqdm import tqdm
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
import gc
# Out:
# 2025-03-14 18:25:28.394815: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-14 18:25:28.408734: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-14 18:25:28.412074: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-14 18:25:28.421780: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs disponíveis: {gpus}")
else:
    print("Nenhuma GPU encontrada.")
# Out:
# GPUs disponíveis: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741987542.103224   47629 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741987542.762862   47629 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741987542.762967   47629 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# nome = 'PACS'
nome = 'Yildirim'
#nome = 'Todos'

imgs_path = 'Bases/Dataset' + nome

TEST_SIZE = 0.1
VALIDATION_SIZE = 0.1

SIMILARITY = 0.75

EPOCHS = 100
BATCH_SIZE = 32

HIGH_FREQ_THRESHOLD = 12

# %%
def get_next_filename(output_folder, base_name, type):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    image_index = 0
    
    while True:
        output_filename = f"{base_name}_{image_index}.{type}"
        output_path = os.path.join(output_folder, output_filename)
        
        if not os.path.exists(output_path):
            return output_filename
            
        image_index += 1

# %%
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else 0

# %%
def sort_files_numerically(file_paths):
    return sorted(file_paths, key=lambda x: extract_number(x))

# %%
def find_groups(images, image_paths, test_size, similarity_threshold):
    def are_similar(img1, img2, threshold):
        similarity = ssim(img1, img2)
        return similarity >= threshold

    groups = []
    current_group = [image_paths[0]]

    for i in range(1, len(images)):
        if are_similar(images[i-1], images[i], similarity_threshold):
            current_group.append(image_paths[i])
        else:
            groups.append(current_group)
            current_group = [image_paths[i]]
    
    if current_group:
        groups.append(current_group)

    all_images = [img_path for group in groups for img_path in group]

    for img_path in image_paths:
        if img_path not in all_images:
            groups.append([img_path])

    random.shuffle(groups)

    train_set = []
    test_set = []
    current_test_size = 0
    
    for i, group in enumerate(groups):
        if current_test_size + len(group) <= test_size:
            test_set.extend(group)
            current_test_size += len(group)
        else:
            train_set.extend(group)

    return train_set, test_set

# %%
output_folder = 'Groups'
type = 'txt'

def save_groups(train_groups, test_groups, base_name):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    output_filename = get_next_filename(output_folder, base_name, type)
    output_path = os.path.join(output_folder, output_filename)

    with open(output_path, 'w') as file:
        file.write('- test:\n')
        for idx, group in enumerate(test_groups, start=1):
            for img in group:
                file.write(f"{img}\n")
        
        file.write('- train:\n')
        for idx, group in enumerate(train_groups, start=1):
            for img in group:
                file.write(f'{img}\n')
    
    print(f'Group information saved in {output_path}')

# %%
def read_dataset(path, jpg, png):
    print(f'Reading dataset...\n')
    
    img_type = []
    images = []
    image_paths = []

    if jpg:
        img_type.append('*.jpg')
    if png:
        img_type.append('*.png')

# Normal

    normal_path = os.path.join(path, 'Train', 'Normal')
    print(f'Reading Normal images from: {normal_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(normal_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# Kidney

    kidney_stone_path = os.path.join(path, 'Train', 'Kidney_stone')
    print(f'Reading Kidney_stone images from: {kidney_stone_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(kidney_stone_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# ...
    
    images = np.array(images)
    image_paths = np.array(image_paths)

    return images, image_paths

# %%
all_X, all_image_paths = read_dataset(path=imgs_path, jpg=True, png=True)
# Out:
# Reading dataset...
#
# Reading Normal images from: Bases/DatasetYildirim/Train/Normal
# Reading Kidney_stone images from: Bases/DatasetYildirim/Train/Kidney_stone

# %%
def freq_spec(image, threshold, add_noise):
    f = np.fft.fft2(image)
    fshift = np.fft.fftshift(f)

    if add_noise:
        amplification_factor = 0.5
        
        rows, cols = image.shape
        crow, ccol = rows//2, cols//2

        mask = np.zeros((rows, cols), dtype=bool)
        mask[crow-threshold:crow+threshold, ccol-threshold:ccol+threshold] = True
        high_freq_mask = ~mask

        fshift[high_freq_mask] *= amplification_factor

    magnitude_spectrum_high = 20 * np.log(np.abs(fshift) + 1)

    return magnitude_spectrum_high

# %%
def save_specs(images, threshold, add_noise):
    specs = []
    for img in images:
        specs.append(freq_spec(img, threshold, add_noise))
    return specs

# %%
# Processar todas as imagens e criar labels
all_specs = []
all_labels = []

# Processar metade normal e metade hackeada
half = len(all_X) // 2
for i, img in enumerate(all_X):
    if i < half:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=False))
        all_labels.append(0)
    else:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=True))
        all_labels.append(1)

all_specs = np.array(all_specs)
all_labels = np.array(all_labels)

# %%
#len_normal_specs = int(len(all_X) / 2)

# %%
#normal_specs = all_X[0:len_normal_specs]

# %%
#normal_specs = save_specs(normal_specs, 100 - HIGH_FREQ_THRESHOLD, add_noise = False)

# %%
#print(len(normal_specs))

# %%
#hacked_specs = all_X[len_normal_specs:len(all_X)]

# %%
#hacked_specs = save_specs(hacked_specs, 100 - HIGH_FREQ_THRESHOLD, add_noise = True)

# %%
#print(len(hacked_specs))

# %%
print("Quantidade das imagens:", all_specs.shape)
print("Exemplo dos labels (False = original, True = com ruído):", all_labels)
# Out:
# Quantidade das imagens: (1799, 224, 224)
# Exemplo dos labels (False = original, True = com ruído): [0 0 0 ... 1 1 1]

# %%
X_train, X_test, y_train, y_test, paths_train, paths_test = train_test_split(
        all_specs, all_labels, all_image_paths,
        test_size=TEST_SIZE, 
        stratify=all_labels,
#       random_state=53
    )

# %%
def plot_specs(specs, title):
    total_images = len(specs)
    imgs_per_figure = 100
    cols = 5
    rows = (imgs_per_figure + cols - 1) // cols

    for start in range(0, total_images, imgs_per_figure):
        plt.figure(figsize=(cols * 3, rows * 3))
        end = min(start + imgs_per_figure, total_images)
        
        for i in range(start, end):
            plt.subplot(rows, cols, i - start + 1)
            plt.imshow(specs[i], cmap='gray')
            plt.title(f"{title} - freq spec: img {i+1}")
            plt.axis('off')
            
        plt.tight_layout()
        plt.show()

# %%
# Plotar todos os espectros de teste
#plot_specs(X_test, title="test")

# %%
#pausa de teste

# %%
# Defines the model layers (now for ResNet50)
def model_mobilenetv2():
    inputs = Input(shape=(224, 224, 1))
    
    # 1. Conversão para 3 canais (igual ao anterior)
    x = Lambda(lambda x: tf.repeat(x, 3, axis=-1))(inputs)
    
    # 2. Pré-processamento específico do MobileNetV2
    x = tf.keras.applications.mobilenet_v2.preprocess_input(x)
    
    # 3. Carregar MobileNetV2
    base_model = tf.keras.applications.MobileNetV2(
        weights='imagenet',
        include_top=False,
        input_tensor=x,
        alpha=1.0  # Controla a largura da rede (1.0 = 224x224)
    )
    
    # 4. Topo personalizado (ajustar camadas se necessário)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    
    # Reduzir unidades para melhor compatibilidade
    x = Dense(128, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.3)(x)
    
    x = Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.3)(x)
    
    outputs = Dense(2, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []

# Configurar K-Fold com random_state fixo para reprodutibilidade
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=53)

# Verificar quais folds já foram completados
completed_folds = []
for f in range(1, 6):
    model_path = f'model_{nome}_fold_{f}.keras'
    if os.path.exists(model_path):
        completed_folds.append(f)
print(f"Folds concluídos: {completed_folds}")

fold_no = 1
histories = []
metrics = []

for train_idx, val_idx in kfold.split(X_train, y_train):
# Pular folds já concluídos
    if fold_no in completed_folds:
        print(f"\nPulando fold {fold_no} (já concluído)")
        fold_no += 1
        continue

    print(f'\nTreinando Fold {fold_no}/5')
    
# Split dos dados
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]

# Pré-processamento final
    X_train_fold = np.expand_dims(X_train_fold, axis=-1)
    X_val_fold = np.expand_dims(X_val_fold, axis=-1)
    y_train_fold_cat = to_categorical(y_train_fold, 2)
    y_val_fold_cat = to_categorical(y_val_fold, 2)

# Criar novo modelo para cada fold
    model = model_mobilenetv2()

# Checkpoint com nome do fold
    checkpoint_filepath = f'model_{nome}_fold_{fold_no}.keras'
    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss'),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
            verbose=1
        )
    ]

# Calcula tempo (start)
    start_time = time.time()
    
# Treinar modelo
    history = model.fit(
        X_train_fold, y_train_fold_cat,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val_fold, y_val_fold_cat),
        callbacks=callbacks,
        verbose=1
    )

# Calcula tempo (end)
    end_time = time.time()

    training_time = end_time - start_time
    print(f"\nO modelo demorou {training_time:.2f} segundos para treinar.")

# Coletar métricas e salvar modelo
    predictions = model.predict(X_val_fold)
    y_pred = np.argmax(predictions, axis=1)
    
    metrics.append({
        'fold': fold_no,
        'report': classification_report(y_val_fold, y_pred, output_dict=True, zero_division=0),
        'matrix': confusion_matrix(y_val_fold, y_pred)
    })

    # Métricas de classificação (por fold)
    acc.append(accuracy_score(y_val_fold, y_pred))
    jacc.append(jaccard_score(y_val_fold, y_pred))
    f1.append(f1_score(y_val_fold, y_pred))
    prec.append(precision_score(y_val_fold, y_pred))
    rec.append(recall_score(y_val_fold, y_pred))

# Limpeza de memória
    del model
    tf.keras.backend.clear_session()
    gc.collect()

# Salvar checkpoint a cada 3 folds
    if fold_no % 3 == 0:
        print(f"\nCheckpoint: Folds {fold_no-2}-{fold_no} concluídos")

    fold_no += 1
# Out:
# Folds concluídos: []
#
# Treinando Fold 1/5
# /tmp/ipykernel_47629/1359235689.py:12: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(
# I0000 00:00:1741987593.225378   47629 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741987593.225514   47629 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741987593.225570   47629 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741987593.407495   47629 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741987593.407626   47629 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-14 18:26:33.407639: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1741987593.407728   47629 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-14 18:26:33.407748: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:10:00.0, compute capability: 8.6
# Epoch 1/100
# I0000 00:00:1741987611.184349   47697 service.cc:146] XLA service 0x7fbd300058f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741987611.184386   47697 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-03-14 18:26:51.586085: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-14 18:26:53.139877: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 2025-03-14 18:26:55.647924: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_8073', 148 bytes spill stores, 148 bytes spill loads
#
# 2025-03-14 18:26:55.783147: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15109', 36 bytes spill stores, 40 bytes spill loads
#
# 2025-03-14 18:26:55.880835: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_8073', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-03-14 18:26:56.149035: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15109', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1741987634.298318   47697 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7283 - loss: 3.7078
# 2025-03-14 18:27:23.339837: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_8073', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-03-14 18:27:40.192037: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_divide_multiply_subtract_fusion_29', 8 bytes spill stores, 8 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_divide_multiply_subtract_fusion_8', 8 bytes spill stores, 8 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_divide_multiply_subtract_fusion_7', 8 bytes spill stores, 8 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_divide_multiply_subtract_fusion', 8 bytes spill stores, 8 bytes spill loads
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 650ms/step - accuracy: 0.7317 - loss: 3.7018
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 73s 863ms/step - accuracy: 0.7349 - loss: 3.6961 - val_accuracy: 0.5000 - val_loss: 4.9789
# Epoch 2/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 3.0789
# Epoch 2: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 3.0767 - val_accuracy: 0.5000 - val_loss: 6.1517
# Epoch 3/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9978 - loss: 2.9078
# Epoch 3: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - accuracy: 0.9979 - loss: 2.9057 - val_accuracy: 0.5000 - val_loss: 6.4576
# Epoch 4/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9998 - loss: 2.7282
# Epoch 4: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9997 - loss: 2.7262 - val_accuracy: 0.5000 - val_loss: 6.2903
# Epoch 5/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 2.5486
# Epoch 5: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 2.5465 - val_accuracy: 0.5000 - val_loss: 6.1572
# Epoch 6/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 2.3701
# Epoch 6: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 2.3681 - val_accuracy: 0.5000 - val_loss: 6.1339
# Epoch 7/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 2.1982
# Epoch 7: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 2.1962 - val_accuracy: 0.5000 - val_loss: 5.9321
# Epoch 8/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 2.0296
# Epoch 8: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 2.0277 - val_accuracy: 0.5000 - val_loss: 5.4742
# Epoch 9/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 1.8671
# Epoch 9: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 1.8652 - val_accuracy: 0.5000 - val_loss: 4.9961
# Epoch 10/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 1.7136
# Epoch 10: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 1.7120 - val_accuracy: 0.5000 - val_loss: 4.7473
# Epoch 11/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 1.5708
# Epoch 11: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9999 - loss: 1.5693 - val_accuracy: 0.5000 - val_loss: 4.1424
# Epoch 12/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 1.4359
# Epoch 12: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 1.4344 - val_accuracy: 0.5000 - val_loss: 3.4707
# Epoch 13/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 1.3112
# Epoch 13: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 1.3098 - val_accuracy: 0.5000 - val_loss: 3.3353
# Epoch 14/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 1.1934
# Epoch 14: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 1.1921 - val_accuracy: 0.5000 - val_loss: 3.1662
# Epoch 15/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 1.0855
# Epoch 15: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - accuracy: 1.0000 - loss: 1.0843 - val_accuracy: 0.5000 - val_loss: 3.2003
# Epoch 16/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.9864
# Epoch 16: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.9853 - val_accuracy: 0.5000 - val_loss: 3.1805
# Epoch 17/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.8960
# Epoch 17: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.8950 - val_accuracy: 0.5000 - val_loss: 2.9546
# Epoch 18/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.8119
# Epoch 18: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.8110 - val_accuracy: 0.5000 - val_loss: 3.1399
# Epoch 19/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.7364
# Epoch 19: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.7356 - val_accuracy: 0.5000 - val_loss: 2.9364
# Epoch 20/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.6681
# Epoch 20: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.6674 - val_accuracy: 0.5000 - val_loss: 3.0202
# Epoch 21/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.6043
# Epoch 21: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.6036 - val_accuracy: 0.5000 - val_loss: 2.9798
# Epoch 22/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.5466
# Epoch 22: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.5459 - val_accuracy: 0.5000 - val_loss: 2.7339
# Epoch 23/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.4941
# Epoch 23: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.4936 - val_accuracy: 0.5000 - val_loss: 2.5900
# Epoch 24/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.4474
# Epoch 24: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.4469 - val_accuracy: 0.5000 - val_loss: 2.5030
# Epoch 25/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.4056
# Epoch 25: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.4051 - val_accuracy: 0.5000 - val_loss: 2.4650
# Epoch 26/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.3666
# Epoch 26: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.3663 - val_accuracy: 0.5000 - val_loss: 2.4793
# Epoch 27/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.3317
# Epoch 27: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.3313 - val_accuracy: 0.5000 - val_loss: 2.3932
# Epoch 28/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.3012
# Epoch 28: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - accuracy: 1.0000 - loss: 0.3009 - val_accuracy: 0.5000 - val_loss: 2.2634
# Epoch 29/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.2729
# Epoch 29: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.2726 - val_accuracy: 0.5000 - val_loss: 2.2140
# Epoch 30/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.2468
# Epoch 30: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.2465 - val_accuracy: 0.5000 - val_loss: 2.1831
# Epoch 31/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.2245
# Epoch 31: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.2242 - val_accuracy: 0.5000 - val_loss: 2.1378
# Epoch 32/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.2033
# Epoch 32: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.2031 - val_accuracy: 0.5000 - val_loss: 2.0043
# Epoch 33/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.1855
# Epoch 33: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.1853 - val_accuracy: 0.5000 - val_loss: 1.6751
# Epoch 34/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1693
# Epoch 34: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.1691 - val_accuracy: 0.5000 - val_loss: 1.6762
# Epoch 35/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1543
# Epoch 35: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.1541 - val_accuracy: 0.5000 - val_loss: 1.6215
# Epoch 36/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1407
# Epoch 36: val_accuracy improved from 0.50000 to 0.50309, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.1405 - val_accuracy: 0.5031 - val_loss: 1.3203
# Epoch 37/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1278
# Epoch 37: val_accuracy did not improve from 0.50309
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.1277 - val_accuracy: 0.5000 - val_loss: 1.4867
# Epoch 38/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1170
# Epoch 38: val_accuracy did not improve from 0.50309
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.1169 - val_accuracy: 0.5000 - val_loss: 1.5086
# Epoch 39/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.1069
# Epoch 39: val_accuracy did not improve from 0.50309
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.1067 - val_accuracy: 0.5031 - val_loss: 1.4026
# Epoch 40/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0972
# Epoch 40: val_accuracy did not improve from 0.50309
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - accuracy: 1.0000 - loss: 0.0972 - val_accuracy: 0.5031 - val_loss: 1.4108
# Epoch 41/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9998 - loss: 0.0918
# Epoch 41: val_accuracy improved from 0.50309 to 0.51235, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.9998 - loss: 0.0918 - val_accuracy: 0.5123 - val_loss: 1.5551
# Epoch 42/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0831
# Epoch 42: val_accuracy improved from 0.51235 to 0.53395, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 1.0000 - loss: 0.0830 - val_accuracy: 0.5340 - val_loss: 1.4525
# Epoch 43/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0757
# Epoch 43: val_accuracy improved from 0.53395 to 0.54938, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0756 - val_accuracy: 0.5494 - val_loss: 1.1899
# Epoch 44/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0697
# Epoch 44: val_accuracy improved from 0.54938 to 0.55864, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0696 - val_accuracy: 0.5586 - val_loss: 1.0435
# Epoch 45/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0642
# Epoch 45: val_accuracy improved from 0.55864 to 0.57099, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0642 - val_accuracy: 0.5710 - val_loss: 0.9177
# Epoch 46/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0592
# Epoch 46: val_accuracy improved from 0.57099 to 0.62346, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0592 - val_accuracy: 0.6235 - val_loss: 0.7548
# Epoch 47/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0546
# Epoch 47: val_accuracy improved from 0.62346 to 0.65741, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 1.0000 - loss: 0.0546 - val_accuracy: 0.6574 - val_loss: 0.6564
# Epoch 48/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0505
# Epoch 48: val_accuracy improved from 0.65741 to 0.69136, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 1.0000 - loss: 0.0505 - val_accuracy: 0.6914 - val_loss: 0.5799
# Epoch 49/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0465
# Epoch 49: val_accuracy improved from 0.69136 to 0.71605, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - accuracy: 1.0000 - loss: 0.0465 - val_accuracy: 0.7160 - val_loss: 0.5451
# Epoch 50/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0435
# Epoch 50: val_accuracy improved from 0.71605 to 0.75926, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 1.0000 - loss: 0.0435 - val_accuracy: 0.7593 - val_loss: 0.4499
# Epoch 51/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0397
# Epoch 51: val_accuracy improved from 0.75926 to 0.76543, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0397 - val_accuracy: 0.7654 - val_loss: 0.4259
# Epoch 52/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0369
# Epoch 52: val_accuracy improved from 0.76543 to 0.76852, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0369 - val_accuracy: 0.7685 - val_loss: 0.4147
# Epoch 53/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0340
# Epoch 53: val_accuracy improved from 0.76852 to 0.77778, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0339 - val_accuracy: 0.7778 - val_loss: 0.4081
# Epoch 54/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0318
# Epoch 54: val_accuracy improved from 0.77778 to 0.82099, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 1.0000 - loss: 0.0318 - val_accuracy: 0.8210 - val_loss: 0.3527
# Epoch 55/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0295
# Epoch 55: val_accuracy improved from 0.82099 to 0.82407, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0295 - val_accuracy: 0.8241 - val_loss: 0.3430
# Epoch 56/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0281
# Epoch 56: val_accuracy did not improve from 0.82407
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0281 - val_accuracy: 0.8210 - val_loss: 0.3402
# Epoch 57/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0260
# Epoch 57: val_accuracy improved from 0.82407 to 0.84877, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 0.8488 - val_loss: 0.3041
# Epoch 58/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0243
# Epoch 58: val_accuracy improved from 0.84877 to 0.90123, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0243 - val_accuracy: 0.9012 - val_loss: 0.2342
# Epoch 59/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0224
# Epoch 59: val_accuracy did not improve from 0.90123
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.9012 - val_loss: 0.2220
# Epoch 60/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0211
# Epoch 60: val_accuracy improved from 0.90123 to 0.93827, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0211 - val_accuracy: 0.9383 - val_loss: 0.1685
# Epoch 61/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0199
# Epoch 61: val_accuracy improved from 0.93827 to 0.94136, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0198 - val_accuracy: 0.9414 - val_loss: 0.1616
# Epoch 62/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0184
# Epoch 62: val_accuracy did not improve from 0.94136
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0184 - val_accuracy: 0.9414 - val_loss: 0.1569
# Epoch 63/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0172
# Epoch 63: val_accuracy improved from 0.94136 to 0.94753, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 1.0000 - loss: 0.0172 - val_accuracy: 0.9475 - val_loss: 0.1355
# Epoch 64/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0163
# Epoch 64: val_accuracy improved from 0.94753 to 0.97222, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 0.9722 - val_loss: 0.1125
# Epoch 65/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0156
# Epoch 65: val_accuracy improved from 0.97222 to 0.99074, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 0.9907 - val_loss: 0.0913
# Epoch 66/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0150
# Epoch 66: val_accuracy improved from 0.99074 to 0.99383, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.9938 - val_loss: 0.0777
# Epoch 67/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0142
# Epoch 67: val_accuracy improved from 0.99383 to 0.99691, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 0.9969 - val_loss: 0.0647
# Epoch 68/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 68: val_accuracy did not improve from 0.99691
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.9969 - val_loss: 0.0596
# Epoch 69/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 69: val_accuracy did not improve from 0.99691
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.9969 - val_loss: 0.0528
# Epoch 70/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0120
# Epoch 70: val_accuracy did not improve from 0.99691
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.9969 - val_loss: 0.0492
# Epoch 71/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 71: val_accuracy did not improve from 0.99691
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.9969 - val_loss: 0.0458
# Epoch 72/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 72: val_accuracy improved from 0.99691 to 1.00000, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0340
# Epoch 73/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 73: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 0.0337
# Epoch 74/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0098
# Epoch 74: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 0.0300
# Epoch 75/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 75: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0258
# Epoch 76/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0090
# Epoch 76: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0262
# Epoch 77/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 77: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0244
# Epoch 78/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 78: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 0.0197
# Epoch 79/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 79: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 0.0147
# Epoch 80/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 80: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0148
# Epoch 81/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 81: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 82/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 82: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 83/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 83: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 0.0115
# Epoch 84/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0073
# Epoch 84: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 85/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 85: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 0.0095
# Epoch 86/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 86: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 87/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 87: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 88/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 88: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 89/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 89: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 90/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 90: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 91/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 91: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 92/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 92: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 93/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 93: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 94/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 94: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 95/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 95: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 96/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 96: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 97/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 97: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 98/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9995 - loss: 0.0108
# Epoch 98: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9995 - loss: 0.0109 - val_accuracy: 0.9599 - val_loss: 0.2246
# Epoch 99/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 99: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0329
# Epoch 100/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 100: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 0.0239
#
# O modelo demorou 377.34 segundos para treinar.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step
#
# Treinando Fold 2/5
# /tmp/ipykernel_47629/1359235689.py:12: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.7216 - loss: 3.6429
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 47s 536ms/step - accuracy: 0.7250 - loss: 3.6376 - val_accuracy: 0.5000 - val_loss: 5.1092
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9934 - loss: 3.0236
# Epoch 2: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9934 - loss: 3.0225 - val_accuracy: 0.5000 - val_loss: 6.8294
# Epoch 3/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9978 - loss: 2.8218
# Epoch 3: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9978 - loss: 2.8196 - val_accuracy: 0.5000 - val_loss: 5.0715
# Epoch 4/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9994 - loss: 2.6256
# Epoch 4: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9994 - loss: 2.6233 - val_accuracy: 0.5000 - val_loss: 6.2948
# Epoch 5/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 2.4249
# Epoch 5: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 2.4227 - val_accuracy: 0.5000 - val_loss: 6.3185
# Epoch 6/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 2.2366
# Epoch 6: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 2.2344 - val_accuracy: 0.5000 - val_loss: 7.3882
# Epoch 7/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 2.0493
# Epoch 7: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 2.0473 - val_accuracy: 0.5000 - val_loss: 7.2176
# Epoch 8/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 1.8725
# Epoch 8: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 1.8706 - val_accuracy: 0.5000 - val_loss: 6.8602
# Epoch 9/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 1.7072
# Epoch 9: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 1.7054 - val_accuracy: 0.5000 - val_loss: 6.3193
# Epoch 10/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9997 - loss: 1.5527
# Epoch 10: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9997 - loss: 1.5510 - val_accuracy: 0.5000 - val_loss: 5.5238
# Epoch 11/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 1.4083
# Epoch 11: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 1.0000 - loss: 1.4068 - val_accuracy: 0.5000 - val_loss: 5.0174
# Epoch 12/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 1.2744
# Epoch 12: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 1.2730 - val_accuracy: 0.5000 - val_loss: 4.5872
# Epoch 13/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 1.1524
# Epoch 13: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 1.0000 - loss: 1.1510 - val_accuracy: 0.5000 - val_loss: 4.7769
# Epoch 14/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 1.0410
# Epoch 14: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 1.0398 - val_accuracy: 0.5000 - val_loss: 4.8565
# Epoch 15/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.9390
# Epoch 15: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 1.0000 - loss: 0.9379 - val_accuracy: 0.5000 - val_loss: 4.5186
# Epoch 16/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.8463
# Epoch 16: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.8453 - val_accuracy: 0.5000 - val_loss: 4.1159
# Epoch 17/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.7620
# Epoch 17: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.7611 - val_accuracy: 0.5000 - val_loss: 3.9113
# Epoch 18/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.6895
# Epoch 18: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.6885 - val_accuracy: 0.5000 - val_loss: 3.8598
# Epoch 19/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.6178
# Epoch 19: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.6171 - val_accuracy: 0.5000 - val_loss: 3.9247
# Epoch 20/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.5584
# Epoch 20: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 1.0000 - loss: 0.5577 - val_accuracy: 0.5000 - val_loss: 4.0777
# Epoch 21/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.5015
# Epoch 21: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 1.0000 - loss: 0.5009 - val_accuracy: 0.5000 - val_loss: 3.7662
# Epoch 22/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.4516
# Epoch 22: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 1.0000 - loss: 0.4510 - val_accuracy: 0.5000 - val_loss: 3.4580
# Epoch 23/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.4071
# Epoch 23: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.4066 - val_accuracy: 0.5000 - val_loss: 3.3405
# Epoch 24/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.3672
# Epoch 24: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 1.0000 - loss: 0.3668 - val_accuracy: 0.5000 - val_loss: 3.0613
# Epoch 25/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.3323
# Epoch 25: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - accuracy: 1.0000 - loss: 0.3319 - val_accuracy: 0.5000 - val_loss: 3.2567
# Epoch 26/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.3000
# Epoch 26: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 1.0000 - loss: 0.2997 - val_accuracy: 0.5000 - val_loss: 3.1064
# Epoch 27/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.2715
# Epoch 27: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 1.0000 - loss: 0.2712 - val_accuracy: 0.5000 - val_loss: 3.0194
# Epoch 28/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.2456
# Epoch 28: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.2453 - val_accuracy: 0.5000 - val_loss: 2.7178
# Epoch 29/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.2226
# Epoch 29: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 1.0000 - loss: 0.2224 - val_accuracy: 0.5000 - val_loss: 2.7414
# Epoch 30/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.2027
# Epoch 30: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 1.0000 - loss: 0.2025 - val_accuracy: 0.5000 - val_loss: 2.8591
# Epoch 31/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.1836
# Epoch 31: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.1834 - val_accuracy: 0.5000 - val_loss: 2.7474
# Epoch 32/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.1681
# Epoch 32: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.1679 - val_accuracy: 0.5000 - val_loss: 2.5067
# Epoch 33/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.1525
# Epoch 33: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.1523 - val_accuracy: 0.5000 - val_loss: 2.6101
# Epoch 34/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.1392
# Epoch 34: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.1391 - val_accuracy: 0.5000 - val_loss: 2.6294
# Epoch 35/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.1273
# Epoch 35: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.1271 - val_accuracy: 0.5000 - val_loss: 2.7310
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.1161
# Epoch 36: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 1.0000 - loss: 0.1160 - val_accuracy: 0.5000 - val_loss: 2.5153
# Epoch 37/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.1061
# Epoch 37: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 1.0000 - loss: 0.1060 - val_accuracy: 0.5000 - val_loss: 2.4203
# Epoch 38/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0975
# Epoch 38: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0974 - val_accuracy: 0.5000 - val_loss: 2.4062
# Epoch 39/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0897
# Epoch 39: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0896 - val_accuracy: 0.5000 - val_loss: 2.4026
# Epoch 40/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0827
# Epoch 40: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 1.0000 - loss: 0.0826 - val_accuracy: 0.5000 - val_loss: 2.4798
# Epoch 41/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0754
# Epoch 41: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 1.0000 - loss: 0.0754 - val_accuracy: 0.5000 - val_loss: 2.6155
# Epoch 42/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0696
# Epoch 42: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 1.0000 - loss: 0.0695 - val_accuracy: 0.5000 - val_loss: 2.6517
# Epoch 43/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0639
# Epoch 43: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0639 - val_accuracy: 0.5000 - val_loss: 2.6406
# Epoch 44/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0592
# Epoch 44: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0591 - val_accuracy: 0.5000 - val_loss: 2.6038
# Epoch 45/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0539
# Epoch 45: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0539 - val_accuracy: 0.5000 - val_loss: 2.5391
# Epoch 46/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0501
# Epoch 46: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 1.0000 - loss: 0.0500 - val_accuracy: 0.5000 - val_loss: 2.5950
# Epoch 47/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0463
# Epoch 47: val_accuracy improved from 0.50000 to 0.50309, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 1.0000 - loss: 0.0463 - val_accuracy: 0.5031 - val_loss: 2.5095
# Epoch 48/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0426
# Epoch 48: val_accuracy did not improve from 0.50309
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - accuracy: 1.0000 - loss: 0.0426 - val_accuracy: 0.5031 - val_loss: 2.5000
# Epoch 49/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0395
# Epoch 49: val_accuracy did not improve from 0.50309
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 1.0000 - loss: 0.0395 - val_accuracy: 0.5031 - val_loss: 2.4634
# Epoch 50/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0368
# Epoch 50: val_accuracy did not improve from 0.50309
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 1.0000 - loss: 0.0368 - val_accuracy: 0.5031 - val_loss: 2.5805
# Epoch 51/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0335
# Epoch 51: val_accuracy did not improve from 0.50309
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 1.0000 - loss: 0.0335 - val_accuracy: 0.5031 - val_loss: 2.3849
# Epoch 52/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0311
# Epoch 52: val_accuracy did not improve from 0.50309
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0310 - val_accuracy: 0.5031 - val_loss: 2.2831
# Epoch 53/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0291
# Epoch 53: val_accuracy improved from 0.50309 to 0.50617, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - accuracy: 1.0000 - loss: 0.0291 - val_accuracy: 0.5062 - val_loss: 2.3246
# Epoch 54/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0269
# Epoch 54: val_accuracy did not improve from 0.50617
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0269 - val_accuracy: 0.5062 - val_loss: 2.2215
# Epoch 55/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0266
# Epoch 55: val_accuracy improved from 0.50617 to 0.86420, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 1.0000 - loss: 0.0266 - val_accuracy: 0.8642 - val_loss: 0.4135
# Epoch 56/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0244
# Epoch 56: val_accuracy improved from 0.86420 to 0.89506, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 1.0000 - loss: 0.0243 - val_accuracy: 0.8951 - val_loss: 0.3069
# Epoch 57/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0223
# Epoch 57: val_accuracy did not improve from 0.89506
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: 0.8827 - val_loss: 0.3457
# Epoch 58/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0211
# Epoch 58: val_accuracy did not improve from 0.89506
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0211 - val_accuracy: 0.8858 - val_loss: 0.3067
# Epoch 59/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0192
# Epoch 59: val_accuracy improved from 0.89506 to 0.91667, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0192 - val_accuracy: 0.9167 - val_loss: 0.2292
# Epoch 60/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0183
# Epoch 60: val_accuracy improved from 0.91667 to 0.93210, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.9321 - val_loss: 0.1998
# Epoch 61/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0169
# Epoch 61: val_accuracy did not improve from 0.93210
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 0.9321 - val_loss: 0.1963
# Epoch 62/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0161
# Epoch 62: val_accuracy improved from 0.93210 to 0.93827, saving model to model_Yildirim_fold_2.keras
# ...
# Epoch 64: val_accuracy improved from 0.97222 to 0.97840, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.9784 - val_loss: 0.0910
# Epoch 65/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 65: val_accuracy improved from 0.97840 to 0.98765, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.9877 - val_loss: 0.0827
# Epoch 66/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 66: val_accuracy did not improve from 0.98765
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.9074 - val_loss: 0.2377
# Epoch 67/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 67: val_accuracy improved from 0.98765 to 1.00000, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 0.0150
# Epoch 68/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 68: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 69/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0108
# Epoch 69: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 70/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 70: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 0.0125
# Epoch 71/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0101
# Epoch 71: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 72/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 72: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 73/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 73: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0106
# Epoch 74/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 74: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 0.0097
# Epoch 75/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 75: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0092
# Epoch 76/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 76: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 77/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 77: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 78/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 78: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 79/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 79: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 80/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 80: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 81/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 81: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 82/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 82: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 83/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 83: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 84/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 84: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 85/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 85: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 86/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 86: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 87/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 87: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 88/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 88: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 89/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 89: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 90/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 90: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 91/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 91: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 92/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 92: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 93/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 93: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 94/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 94: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 95/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 95: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 96/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 96: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 97/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 97: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 98/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 98: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 99/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 99: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 100/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 100: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0047
#
# O modelo demorou 353.16 segundos para treinar.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step
#
# Checkpoint: Folds 1-3 concluídos
#
# Treinando Fold 4/5
# /tmp/ipykernel_47629/1359235689.py:12: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(
# Epoch 1/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 63
#      60     start_time = time.time()
#      62 # Treinar modelo
# ---> 63     history = model.fit(
#      64         X_train_fold, y_train_fold_cat,
#      65         batch_size=BATCH_SIZE,
#      66         epochs=EPOCHS,
#      67         validation_data=(X_val_fold, y_val_fold_cat),
#      68         callbacks=callbacks,
#      69         verbose=1
#      70     )
#      72 # Calcula tempo (end)
#      73     end_time = time.time()
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:919, in Function._call(self, *args, **kwds)
#     913   # If we did not create any variables the trace we have is good enough.
#     914   filtered_flat_args = (
#     915       self._concrete_variable_creation_fn.function_type.unpack_inputs(
#     916           bound_args
#     917       )
#     918   )
# --> 919   return self._concrete_variable_creation_fn._call_flat(  # pylint: disable=protected-access
#     920       filtered_flat_args,
#     921       self._concrete_variable_creation_fn.captured_inputs,
#     922   )
#     924 def fn_with_cond(inner_args, inner_kwds):
#     925   """Conditionally runs initialization if it's needed."""
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
print("Dice: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))

# %%
# GC collect
tf.keras.backend.clear_session()
gc.collect()
