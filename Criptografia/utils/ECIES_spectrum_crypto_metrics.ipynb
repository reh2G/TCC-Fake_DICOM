# %%
from Crypto.PublicKey import ECC
from Crypto.Cipher import AES
from Crypto.Protocol.KDF import HKDF
from Crypto.Hash import SHA256
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Chave ECC

# %% [markdown]
# | Curva  | Segurança (bits) | Performance                 | Uso comum                                  |
# |--------|------------------|-----------------------------|--------------------------------------------|
# | P-192  | 96 bits          | Rápida, porém menos segura  | Obsoleta                                   |
# | P-256  | 128 bits         | Muito bom equilíbrio        | ✅ Recomendado                              |
# | P-384  | 192 bits         | Mais lenta                  | Ambientes que exigem maior segurança       |
# | P-521  | 256 bits         | Muito lenta                 | Pouco usada na prática                     |

# %%
key = ECC.generate(curve='P-256') # curvas recomendadas pelo NIST
private_key = key # private_key é usada localmente para operações que exigem sigilo.
public_key = key.public_key() # public_key será usada na negociação da chave simétrica com a parte que quer se comunicar.

# %% [markdown]
# Porque a curva P-256?
# * P-256 oferece um nível de segurança equivalente a uma chave RSA de 3072 bits. É mais que suficiente para garantir proteção contra ataques modernos.
# * Mais rápidas (em geral) e mais eficientes em uso de memória

# %%
# Exporta as chaves ECC em formato legível (PEM) para reuso ou armazenamento seguro.
with open("ECIES_keys/ECC_256_private.pem", "wt") as f:
    f.write(private_key.export_key(format='PEM'))

with open("ECIES_keys/ECC_256public.pem", "wt") as f:
    f.write(public_key.export_key(format='PEM'))

# %% [markdown]
# # Criptografia

# %%
# Tempo de excecução
tempos_execucao = []
execucoes = []

for rodagem in range(218, 391): # Loop para os slices
    inicio = time.perf_counter()

    print(f'Iniciando criptografia ECIES: arquivo {rodagem}')

    dicom_path = f'C:\\Users\\CarlosChinen\\OneDrive\\Main\\FEI\\TCC\\Criptografia\\criptografia\\DATASET_dicom_fourier_spectrum\\spectrum_slice_{rodagem}.png'
    # dicom_path = f'C:\\Users\\massa\\OneDrive\\Main\\FEI\\TCC\\Criptografia\\criptografia\\DATASET_dicom_fourier_spectrum\\spectrum_slice_{rodagem}.png'

    with open(dicom_path, "rb") as dicom_file: # Lê os bytes da imagem do espectro.
        image_data = dicom_file.read() 

    # Negociação de chave com ECC (ECDH) - cria uma chave secreta compartilhada
    session_key = ECC.generate(curve='P-256') # chave ECC gerada temporariamente para esta sessão (chave de sessão).
    shared_secret = session_key.d * public_key.pointQ # Elliptic Curve Diffie-Hellman - a session_key multiplica a chave pública do receptor para gerar um secret compartilhado (ponto na curva elíptica).

    # Deriva uma chave AES a partir do segredo compartilhado
    shared_secret_bytes = int(shared_secret.x).to_bytes(32, byteorder='big') # Extrai o valor X do ponto da curva para gerar um número (convertido em 32 bytes).
    aes_key = HKDF(shared_secret_bytes, 32, b'', SHA256) # Usa o HKDF com SHA-256 para derivar uma chave AES forte e segura de 256 bits (32 bytes) a partir do segredo compartilhado.

    cipher_aes = AES.new(aes_key, AES.MODE_EAX) # Cria um objeto de cifra AES no modo EAX, que suporta confidencialidade + integridade.
    ciphertext, tag = cipher_aes.encrypt_and_digest(image_data) # encrypt_and_digest: criptografa os dados e gera um authentication tag para verificar integridade posteriormente.

    # Salva os componentes necessários para descriptografia:
    with open(f"ECIES_crypto_spectrum_metrics/ECIES_spectrum_criptografado_{rodagem}.enc", "wb") as out_file:
        out_file.write(session_key.public_key().export_key(format='DER')) # permite ao receptor refazer o segredo compartilhado.
        out_file.write(cipher_aes.nonce) # único por criptografia, necessário para decifrar no modo EAX.
        out_file.write(tag) # autenticação da mensagem.
        out_file.write(ciphertext) # os dados efetivamente criptografados.
    
    fim = time.perf_counter()
    tempo_execucao = fim - inicio
    tempos_execucao.append(tempo_execucao)
    execucoes.append(rodagem)

    print(f'Criptografia ECC finalizada: arquivo {rodagem}')
    print(f"Tempo de execução: {tempo_execucao:.5f} segundos\n")

print(f'\nTempo médio de execução: {np.mean(tempos_execucao):.5f}')
# Out:
# Iniciando criptografia ECIES: arquivo 218
# Criptografia ECC finalizada: arquivo 218
# Tempo de execução: 0.00630 segundos
#
# Iniciando criptografia ECIES: arquivo 219
# Criptografia ECC finalizada: arquivo 219
# Tempo de execução: 0.00527 segundos
#
# Iniciando criptografia ECIES: arquivo 220
# Criptografia ECC finalizada: arquivo 220
# Tempo de execução: 0.00630 segundos
#
# Iniciando criptografia ECIES: arquivo 221
# Criptografia ECC finalizada: arquivo 221
# Tempo de execução: 0.00585 segundos
#
# Iniciando criptografia ECIES: arquivo 222
# Criptografia ECC finalizada: arquivo 222
# Tempo de execução: 0.00664 segundos
#
# Iniciando criptografia ECIES: arquivo 223
# Criptografia ECC finalizada: arquivo 223
# Tempo de execução: 0.00572 segundos
#
# Iniciando criptografia ECIES: arquivo 224
# Criptografia ECC finalizada: arquivo 224
# Tempo de execução: 0.00652 segundos
#
# Iniciando criptografia ECIES: arquivo 225
# Criptografia ECC finalizada: arquivo 225
# Tempo de execução: 0.00531 segundos
#
# Iniciando criptografia ECIES: arquivo 226
# Criptografia ECC finalizada: arquivo 226
# Tempo de execução: 0.00597 segundos
#
# Iniciando criptografia ECIES: arquivo 227
# Criptografia ECC finalizada: arquivo 227
# Tempo de execução: 0.00549 segundos
#
# Iniciando criptografia ECIES: arquivo 228
# Criptografia ECC finalizada: arquivo 228
# Tempo de execução: 0.00601 segundos
#
# Iniciando criptografia ECIES: arquivo 229
# Criptografia ECC finalizada: arquivo 229
# Tempo de execução: 0.00601 segundos
#
# Iniciando criptografia ECIES: arquivo 230
# Criptografia ECC finalizada: arquivo 230
# Tempo de execução: 0.00569 segundos
#
# Iniciando criptografia ECIES: arquivo 231
# Criptografia ECC finalizada: arquivo 231
# Tempo de execução: 0.00544 segundos
#
# Iniciando criptografia ECIES: arquivo 232
# Criptografia ECC finalizada: arquivo 232
# Tempo de execução: 0.00552 segundos
#
# Iniciando criptografia ECIES: arquivo 233
# Criptografia ECC finalizada: arquivo 233
# Tempo de execução: 0.00568 segundos
#
# Iniciando criptografia ECIES: arquivo 234
# Criptografia ECC finalizada: arquivo 234
# Tempo de execução: 0.00678 segundos
#
# Iniciando criptografia ECIES: arquivo 235
# Criptografia ECC finalizada: arquivo 235
# Tempo de execução: 0.00650 segundos
#
# Iniciando criptografia ECIES: arquivo 236
# Criptografia ECC finalizada: arquivo 236
# Tempo de execução: 0.00392 segundos
#
# Iniciando criptografia ECIES: arquivo 237
# Criptografia ECC finalizada: arquivo 237
# Tempo de execução: 0.00462 segundos
#
# Iniciando criptografia ECIES: arquivo 238
# Criptografia ECC finalizada: arquivo 238
# Tempo de execução: 0.00494 segundos
#
# Iniciando criptografia ECIES: arquivo 239
# Criptografia ECC finalizada: arquivo 239
# Tempo de execução: 0.00590 segundos
#
# Iniciando criptografia ECIES: arquivo 240
# Criptografia ECC finalizada: arquivo 240
# Tempo de execução: 0.00528 segundos
#
# Iniciando criptografia ECIES: arquivo 241
# Criptografia ECC finalizada: arquivo 241
# Tempo de execução: 0.00494 segundos
#
# Iniciando criptografia ECIES: arquivo 242
# Criptografia ECC finalizada: arquivo 242
# Tempo de execução: 0.00427 segundos
#
# Iniciando criptografia ECIES: arquivo 243
# Criptografia ECC finalizada: arquivo 243
# Tempo de execução: 0.00330 segundos
#
# Iniciando criptografia ECIES: arquivo 244
# Criptografia ECC finalizada: arquivo 244
# Tempo de execução: 0.00429 segundos
#
# Iniciando criptografia ECIES: arquivo 245
# Criptografia ECC finalizada: arquivo 245
# Tempo de execução: 0.00342 segundos
#
# Iniciando criptografia ECIES: arquivo 246
# Criptografia ECC finalizada: arquivo 246
# Tempo de execução: 0.00305 segundos
#
# Iniciando criptografia ECIES: arquivo 247
# Criptografia ECC finalizada: arquivo 247
# Tempo de execução: 0.00386 segundos
#
# Iniciando criptografia ECIES: arquivo 248
# Criptografia ECC finalizada: arquivo 248
# Tempo de execução: 0.00307 segundos
#
# Iniciando criptografia ECIES: arquivo 249
# Criptografia ECC finalizada: arquivo 249
# Tempo de execução: 0.00317 segundos
#
# Iniciando criptografia ECIES: arquivo 250
# Criptografia ECC finalizada: arquivo 250
# Tempo de execução: 0.00302 segundos
#
# Iniciando criptografia ECIES: arquivo 251
# Criptografia ECC finalizada: arquivo 251
# Tempo de execução: 0.00311 segundos
#
# Iniciando criptografia ECIES: arquivo 252
# Criptografia ECC finalizada: arquivo 252
# Tempo de execução: 0.00381 segundos
#
# Iniciando criptografia ECIES: arquivo 253
# Criptografia ECC finalizada: arquivo 253
# Tempo de execução: 0.00362 segundos
#
# Iniciando criptografia ECIES: arquivo 254
# Criptografia ECC finalizada: arquivo 254
# Tempo de execução: 0.00363 segundos
#
# Iniciando criptografia ECIES: arquivo 255
# Criptografia ECC finalizada: arquivo 255
# Tempo de execução: 0.00319 segundos
#
# Iniciando criptografia ECIES: arquivo 256
# Criptografia ECC finalizada: arquivo 256
# Tempo de execução: 0.00339 segundos
#
# Iniciando criptografia ECIES: arquivo 257
# Criptografia ECC finalizada: arquivo 257
# Tempo de execução: 0.00372 segundos
#
# Iniciando criptografia ECIES: arquivo 258
# Criptografia ECC finalizada: arquivo 258
# Tempo de execução: 0.00330 segundos
#
# Iniciando criptografia ECIES: arquivo 259
# Criptografia ECC finalizada: arquivo 259
# Tempo de execução: 0.00296 segundos
#
# Iniciando criptografia ECIES: arquivo 260
# Criptografia ECC finalizada: arquivo 260
# Tempo de execução: 0.00333 segundos
#
# Iniciando criptografia ECIES: arquivo 261
# Criptografia ECC finalizada: arquivo 261
# Tempo de execução: 0.00336 segundos
#
# Iniciando criptografia ECIES: arquivo 262
# Criptografia ECC finalizada: arquivo 262
# Tempo de execução: 0.00346 segundos
#
# Iniciando criptografia ECIES: arquivo 263
# Criptografia ECC finalizada: arquivo 263
# Tempo de execução: 0.00295 segundos
#
# Iniciando criptografia ECIES: arquivo 264
# Criptografia ECC finalizada: arquivo 264
# Tempo de execução: 0.00308 segundos
#
# Iniciando criptografia ECIES: arquivo 265
# Criptografia ECC finalizada: arquivo 265
# Tempo de execução: 0.00310 segundos
#
# Iniciando criptografia ECIES: arquivo 266
# Criptografia ECC finalizada: arquivo 266
# Tempo de execução: 0.00358 segundos
#
# Iniciando criptografia ECIES: arquivo 267
# Criptografia ECC finalizada: arquivo 267
# Tempo de execução: 0.00356 segundos
#
# Iniciando criptografia ECIES: arquivo 268
# Criptografia ECC finalizada: arquivo 268
# Tempo de execução: 0.00331 segundos
#
# Iniciando criptografia ECIES: arquivo 269
# Criptografia ECC finalizada: arquivo 269
# Tempo de execução: 0.00363 segundos
#
# Iniciando criptografia ECIES: arquivo 270
# Criptografia ECC finalizada: arquivo 270
# Tempo de execução: 0.00380 segundos
#
# Iniciando criptografia ECIES: arquivo 271
# Criptografia ECC finalizada: arquivo 271
# Tempo de execução: 0.00369 segundos
#
# Iniciando criptografia ECIES: arquivo 272
# Criptografia ECC finalizada: arquivo 272
# Tempo de execução: 0.00329 segundos
#
# Iniciando criptografia ECIES: arquivo 273
# Criptografia ECC finalizada: arquivo 273
# Tempo de execução: 0.00295 segundos
#
# Iniciando criptografia ECIES: arquivo 274
# Criptografia ECC finalizada: arquivo 274
# Tempo de execução: 0.00319 segundos
#
# Iniciando criptografia ECIES: arquivo 275
# Criptografia ECC finalizada: arquivo 275
# Tempo de execução: 0.00305 segundos
#
# Iniciando criptografia ECIES: arquivo 276
# Criptografia ECC finalizada: arquivo 276
# Tempo de execução: 0.00313 segundos
#
# Iniciando criptografia ECIES: arquivo 277
# Criptografia ECC finalizada: arquivo 277
# Tempo de execução: 0.00266 segundos
#
# Iniciando criptografia ECIES: arquivo 278
# Criptografia ECC finalizada: arquivo 278
# Tempo de execução: 0.00278 segundos
#
# Iniciando criptografia ECIES: arquivo 279
# Criptografia ECC finalizada: arquivo 279
# Tempo de execução: 0.00304 segundos
#
# Iniciando criptografia ECIES: arquivo 280
# Criptografia ECC finalizada: arquivo 280
# Tempo de execução: 0.00320 segundos
#
# Iniciando criptografia ECIES: arquivo 281
# Criptografia ECC finalizada: arquivo 281
# Tempo de execução: 0.00289 segundos
#
# Iniciando criptografia ECIES: arquivo 282
# Criptografia ECC finalizada: arquivo 282
# Tempo de execução: 0.00299 segundos
#
# Iniciando criptografia ECIES: arquivo 283
# Criptografia ECC finalizada: arquivo 283
# Tempo de execução: 0.00295 segundos
#
# Iniciando criptografia ECIES: arquivo 284
# Criptografia ECC finalizada: arquivo 284
# Tempo de execução: 0.00276 segundos
#
# Iniciando criptografia ECIES: arquivo 285
# Criptografia ECC finalizada: arquivo 285
# Tempo de execução: 0.00306 segundos
#
# Iniciando criptografia ECIES: arquivo 286
# Criptografia ECC finalizada: arquivo 286
# Tempo de execução: 0.00402 segundos
#
# Iniciando criptografia ECIES: arquivo 287
# Criptografia ECC finalizada: arquivo 287
# Tempo de execução: 0.00302 segundos
#
# Iniciando criptografia ECIES: arquivo 288
# Criptografia ECC finalizada: arquivo 288
# Tempo de execução: 0.00313 segundos
#
# Iniciando criptografia ECIES: arquivo 289
# Criptografia ECC finalizada: arquivo 289
# Tempo de execução: 0.00280 segundos
#
# Iniciando criptografia ECIES: arquivo 290
# Criptografia ECC finalizada: arquivo 290
# Tempo de execução: 0.00339 segundos
#
# Iniciando criptografia ECIES: arquivo 291
# Criptografia ECC finalizada: arquivo 291
# Tempo de execução: 0.00304 segundos
#
# Iniciando criptografia ECIES: arquivo 292
# Criptografia ECC finalizada: arquivo 292
# Tempo de execução: 0.00311 segundos
#
# Iniciando criptografia ECIES: arquivo 293
# Criptografia ECC finalizada: arquivo 293
# Tempo de execução: 0.00282 segundos
#
# Iniciando criptografia ECIES: arquivo 294
# Criptografia ECC finalizada: arquivo 294
# Tempo de execução: 0.00344 segundos
#
# Iniciando criptografia ECIES: arquivo 295
# Criptografia ECC finalizada: arquivo 295
# Tempo de execução: 0.00354 segundos
#
# Iniciando criptografia ECIES: arquivo 296
# Criptografia ECC finalizada: arquivo 296
# Tempo de execução: 0.00323 segundos
#
# Iniciando criptografia ECIES: arquivo 297
# Criptografia ECC finalizada: arquivo 297
# Tempo de execução: 0.00312 segundos
#
# Iniciando criptografia ECIES: arquivo 298
# Criptografia ECC finalizada: arquivo 298
# Tempo de execução: 0.00382 segundos
#
# Iniciando criptografia ECIES: arquivo 299
# Criptografia ECC finalizada: arquivo 299
# Tempo de execução: 0.00412 segundos
#
# Iniciando criptografia ECIES: arquivo 300
# Criptografia ECC finalizada: arquivo 300
# Tempo de execução: 0.00292 segundos
#
# Iniciando criptografia ECIES: arquivo 301
# Criptografia ECC finalizada: arquivo 301
# Tempo de execução: 0.00255 segundos
#
# Iniciando criptografia ECIES: arquivo 302
# Criptografia ECC finalizada: arquivo 302
# Tempo de execução: 0.00251 segundos
#
# Iniciando criptografia ECIES: arquivo 303
# Criptografia ECC finalizada: arquivo 303
# Tempo de execução: 0.00341 segundos
#
# Iniciando criptografia ECIES: arquivo 304
# Criptografia ECC finalizada: arquivo 304
# Tempo de execução: 0.00296 segundos
#
# Iniciando criptografia ECIES: arquivo 305
# Criptografia ECC finalizada: arquivo 305
# Tempo de execução: 0.00235 segundos
#
# Iniciando criptografia ECIES: arquivo 306
# Criptografia ECC finalizada: arquivo 306
# Tempo de execução: 0.00240 segundos
#
# Iniciando criptografia ECIES: arquivo 307
# Criptografia ECC finalizada: arquivo 307
# Tempo de execução: 0.00220 segundos
#
# Iniciando criptografia ECIES: arquivo 308
# Criptografia ECC finalizada: arquivo 308
# Tempo de execução: 0.00233 segundos
#
# Iniciando criptografia ECIES: arquivo 309
# Criptografia ECC finalizada: arquivo 309
# Tempo de execução: 0.00248 segundos
#
# Iniciando criptografia ECIES: arquivo 310
# Criptografia ECC finalizada: arquivo 310
# Tempo de execução: 0.00256 segundos
#
# Iniciando criptografia ECIES: arquivo 311
# Criptografia ECC finalizada: arquivo 311
# Tempo de execução: 0.00232 segundos
#
# Iniciando criptografia ECIES: arquivo 312
# Criptografia ECC finalizada: arquivo 312
# Tempo de execução: 0.00225 segundos
#
# Iniciando criptografia ECIES: arquivo 313
# Criptografia ECC finalizada: arquivo 313
# Tempo de execução: 0.00229 segundos
#
# Iniciando criptografia ECIES: arquivo 314
# Criptografia ECC finalizada: arquivo 314
# Tempo de execução: 0.00210 segundos
#
# Iniciando criptografia ECIES: arquivo 315
# Criptografia ECC finalizada: arquivo 315
# Tempo de execução: 0.00211 segundos
#
# Iniciando criptografia ECIES: arquivo 316
# Criptografia ECC finalizada: arquivo 316
# Tempo de execução: 0.00266 segundos
#
# Iniciando criptografia ECIES: arquivo 317
# Criptografia ECC finalizada: arquivo 317
# Tempo de execução: 0.00242 segundos
#
# Iniciando criptografia ECIES: arquivo 318
# Criptografia ECC finalizada: arquivo 318
# Tempo de execução: 0.00211 segundos
#
# Iniciando criptografia ECIES: arquivo 319
# Criptografia ECC finalizada: arquivo 319
# Tempo de execução: 0.00216 segundos
#
# Iniciando criptografia ECIES: arquivo 320
# Criptografia ECC finalizada: arquivo 320
# Tempo de execução: 0.00208 segundos
#
# Iniciando criptografia ECIES: arquivo 321
# Criptografia ECC finalizada: arquivo 321
# Tempo de execução: 0.00196 segundos
#
# Iniciando criptografia ECIES: arquivo 322
# Criptografia ECC finalizada: arquivo 322
# Tempo de execução: 0.00216 segundos
#
# Iniciando criptografia ECIES: arquivo 323
# Criptografia ECC finalizada: arquivo 323
# Tempo de execução: 0.00287 segundos
#
# Iniciando criptografia ECIES: arquivo 324
# Criptografia ECC finalizada: arquivo 324
# Tempo de execução: 0.00288 segundos
#
# Iniciando criptografia ECIES: arquivo 325
# Criptografia ECC finalizada: arquivo 325
# Tempo de execução: 0.00226 segundos
#
# Iniciando criptografia ECIES: arquivo 326
# Criptografia ECC finalizada: arquivo 326
# Tempo de execução: 0.00285 segundos
#
# Iniciando criptografia ECIES: arquivo 327
# Criptografia ECC finalizada: arquivo 327
# Tempo de execução: 0.00337 segundos
#
# Iniciando criptografia ECIES: arquivo 328
# Criptografia ECC finalizada: arquivo 328
# Tempo de execução: 0.00344 segundos
#
# Iniciando criptografia ECIES: arquivo 329
# Criptografia ECC finalizada: arquivo 329
# Tempo de execução: 0.00310 segundos
#
# Iniciando criptografia ECIES: arquivo 330
# Criptografia ECC finalizada: arquivo 330
# Tempo de execução: 0.00327 segundos
#
# Iniciando criptografia ECIES: arquivo 331
# Criptografia ECC finalizada: arquivo 331
# Tempo de execução: 0.00319 segundos
#
# Iniciando criptografia ECIES: arquivo 332
# Criptografia ECC finalizada: arquivo 332
# Tempo de execução: 0.00303 segundos
#
# Iniciando criptografia ECIES: arquivo 333
# Criptografia ECC finalizada: arquivo 333
# Tempo de execução: 0.00267 segundos
#
# Iniciando criptografia ECIES: arquivo 334
# Criptografia ECC finalizada: arquivo 334
# Tempo de execução: 0.00288 segundos
#
# Iniciando criptografia ECIES: arquivo 335
# Criptografia ECC finalizada: arquivo 335
# Tempo de execução: 0.00316 segundos
#
# Iniciando criptografia ECIES: arquivo 336
# Criptografia ECC finalizada: arquivo 336
# Tempo de execução: 0.00244 segundos
#
# Iniciando criptografia ECIES: arquivo 337
# Criptografia ECC finalizada: arquivo 337
# Tempo de execução: 0.00336 segundos
#
# Iniciando criptografia ECIES: arquivo 338
# Criptografia ECC finalizada: arquivo 338
# Tempo de execução: 0.00360 segundos
#
# Iniciando criptografia ECIES: arquivo 339
# Criptografia ECC finalizada: arquivo 339
# Tempo de execução: 0.00355 segundos
#
# Iniciando criptografia ECIES: arquivo 340
# Criptografia ECC finalizada: arquivo 340
# Tempo de execução: 0.00323 segundos
#
# Iniciando criptografia ECIES: arquivo 341
# Criptografia ECC finalizada: arquivo 341
# Tempo de execução: 0.00313 segundos
#
# Iniciando criptografia ECIES: arquivo 342
# Criptografia ECC finalizada: arquivo 342
# Tempo de execução: 0.00282 segundos
#
# Iniciando criptografia ECIES: arquivo 343
# Criptografia ECC finalizada: arquivo 343
# Tempo de execução: 0.00309 segundos
#
# Iniciando criptografia ECIES: arquivo 344
# Criptografia ECC finalizada: arquivo 344
# Tempo de execução: 0.00268 segundos
#
# Iniciando criptografia ECIES: arquivo 345
# Criptografia ECC finalizada: arquivo 345
# Tempo de execução: 0.00289 segundos
#
# Iniciando criptografia ECIES: arquivo 346
# Criptografia ECC finalizada: arquivo 346
# Tempo de execução: 0.00286 segundos
#
# Iniciando criptografia ECIES: arquivo 347
# Criptografia ECC finalizada: arquivo 347
# Tempo de execução: 0.00341 segundos
#
# Iniciando criptografia ECIES: arquivo 348
# Criptografia ECC finalizada: arquivo 348
# Tempo de execução: 0.00305 segundos
#
# Iniciando criptografia ECIES: arquivo 349
# Criptografia ECC finalizada: arquivo 349
# Tempo de execução: 0.01044 segundos
#
# Iniciando criptografia ECIES: arquivo 350
# Criptografia ECC finalizada: arquivo 350
# Tempo de execução: 0.00247 segundos
#
# Iniciando criptografia ECIES: arquivo 351
# Criptografia ECC finalizada: arquivo 351
# Tempo de execução: 0.00238 segundos
#
# Iniciando criptografia ECIES: arquivo 352
# Criptografia ECC finalizada: arquivo 352
# Tempo de execução: 0.00220 segundos
#
# Iniciando criptografia ECIES: arquivo 353
# Criptografia ECC finalizada: arquivo 353
# Tempo de execução: 0.00235 segundos
#
# Iniciando criptografia ECIES: arquivo 354
# Criptografia ECC finalizada: arquivo 354
# Tempo de execução: 0.00203 segundos
#
# Iniciando criptografia ECIES: arquivo 355
# Criptografia ECC finalizada: arquivo 355
# Tempo de execução: 0.00199 segundos
#
# Iniciando criptografia ECIES: arquivo 356
# Criptografia ECC finalizada: arquivo 356
# Tempo de execução: 0.00203 segundos
#
# Iniciando criptografia ECIES: arquivo 357
# Criptografia ECC finalizada: arquivo 357
# Tempo de execução: 0.00188 segundos
#
# Iniciando criptografia ECIES: arquivo 358
# Criptografia ECC finalizada: arquivo 358
# Tempo de execução: 0.00230 segundos
#
# Iniciando criptografia ECIES: arquivo 359
# Criptografia ECC finalizada: arquivo 359
# Tempo de execução: 0.00222 segundos
#
# Iniciando criptografia ECIES: arquivo 360
# Criptografia ECC finalizada: arquivo 360
# Tempo de execução: 0.00210 segundos
#
# Iniciando criptografia ECIES: arquivo 361
# Criptografia ECC finalizada: arquivo 361
# Tempo de execução: 0.00205 segundos
#
# Iniciando criptografia ECIES: arquivo 362
# Criptografia ECC finalizada: arquivo 362
# Tempo de execução: 0.00214 segundos
#
# Iniciando criptografia ECIES: arquivo 363
# Criptografia ECC finalizada: arquivo 363
# Tempo de execução: 0.00189 segundos
#
# Iniciando criptografia ECIES: arquivo 364
# Criptografia ECC finalizada: arquivo 364
# Tempo de execução: 0.00191 segundos
#
# Iniciando criptografia ECIES: arquivo 365
# Criptografia ECC finalizada: arquivo 365
# Tempo de execução: 0.00222 segundos
#
# Iniciando criptografia ECIES: arquivo 366
# Criptografia ECC finalizada: arquivo 366
# Tempo de execução: 0.00245 segundos
#
# Iniciando criptografia ECIES: arquivo 367
# Criptografia ECC finalizada: arquivo 367
# Tempo de execução: 0.00231 segundos
#
# Iniciando criptografia ECIES: arquivo 368
# Criptografia ECC finalizada: arquivo 368
# Tempo de execução: 0.00222 segundos
#
# Iniciando criptografia ECIES: arquivo 369
# Criptografia ECC finalizada: arquivo 369
# Tempo de execução: 0.00273 segundos
#
# Iniciando criptografia ECIES: arquivo 370
# Criptografia ECC finalizada: arquivo 370
# Tempo de execução: 0.00216 segundos
#
# Iniciando criptografia ECIES: arquivo 371
# Criptografia ECC finalizada: arquivo 371
# Tempo de execução: 0.00223 segundos
#
# Iniciando criptografia ECIES: arquivo 372
# Criptografia ECC finalizada: arquivo 372
# Tempo de execução: 0.00262 segundos
#
# Iniciando criptografia ECIES: arquivo 373
# Criptografia ECC finalizada: arquivo 373
# Tempo de execução: 0.00216 segundos
#
# Iniciando criptografia ECIES: arquivo 374
# Criptografia ECC finalizada: arquivo 374
# Tempo de execução: 0.00220 segundos
#
# Iniciando criptografia ECIES: arquivo 375
# Criptografia ECC finalizada: arquivo 375
# Tempo de execução: 0.00239 segundos
#
# Iniciando criptografia ECIES: arquivo 376
# Criptografia ECC finalizada: arquivo 376
# Tempo de execução: 0.00218 segundos
#
# Iniciando criptografia ECIES: arquivo 377
# Criptografia ECC finalizada: arquivo 377
# Tempo de execução: 0.00228 segundos
#
# Iniciando criptografia ECIES: arquivo 378
# Criptografia ECC finalizada: arquivo 378
# Tempo de execução: 0.00223 segundos
#
# Iniciando criptografia ECIES: arquivo 379
# Criptografia ECC finalizada: arquivo 379
# Tempo de execução: 0.00284 segundos
#
# Iniciando criptografia ECIES: arquivo 380
# Criptografia ECC finalizada: arquivo 380
# Tempo de execução: 0.00269 segundos
#
# Iniciando criptografia ECIES: arquivo 381
# Criptografia ECC finalizada: arquivo 381
# Tempo de execução: 0.00260 segundos
#
# Iniciando criptografia ECIES: arquivo 382
# Criptografia ECC finalizada: arquivo 382
# Tempo de execução: 0.00216 segundos
#
# Iniciando criptografia ECIES: arquivo 383
# Criptografia ECC finalizada: arquivo 383
# Tempo de execução: 0.00286 segundos
#
# Iniciando criptografia ECIES: arquivo 384
# Criptografia ECC finalizada: arquivo 384
# Tempo de execução: 0.00277 segundos
#
# Iniciando criptografia ECIES: arquivo 385
# Criptografia ECC finalizada: arquivo 385
# Tempo de execução: 0.00358 segundos
#
# Iniciando criptografia ECIES: arquivo 386
# Criptografia ECC finalizada: arquivo 386
# Tempo de execução: 0.00907 segundos
#
# Iniciando criptografia ECIES: arquivo 387
# Criptografia ECC finalizada: arquivo 387
# Tempo de execução: 0.00496 segundos
#
# Iniciando criptografia ECIES: arquivo 388
# Criptografia ECC finalizada: arquivo 388
# Tempo de execução: 0.00414 segundos
#
# Iniciando criptografia ECIES: arquivo 389
# Criptografia ECC finalizada: arquivo 389
# Tempo de execução: 0.00492 segundos
#
# Iniciando criptografia ECIES: arquivo 390
# Criptografia ECC finalizada: arquivo 390
# Tempo de execução: 0.00826 segundos
#
#
# Tempo médio de execução: 0.00340

# %% [markdown]
# ### Resumo:
# | Etapa           | Função                                                                                      |
# |-----------------|---------------------------------------------------------------------------------------------|
# | ECC Key Gen     | Gera chave pública/privada                                                                  |
# | ECDH            | Deriva um segredo compartilhado via multiplicação de chave de sessão com chave pública do receptor |
# | HKDF            | Deriva uma chave simétrica (AES) segura                                                     |
# | AES-EAX         | Criptografa a imagem garantindo confidencialidade e integridade                             |
# | Armazenamento   | Salva chave de sesssão, nonce, tag e criptograma para uso posterior na descriptografia         |

# %%
df_execucoes = pd.DataFrame({
    'slice': execucoes,
    'tempoExecucaoAES': tempos_execucao
})

df_execucoes.describe()
# Out:
#             slice  tempoExecucaoAES
# count  173.000000        173.000000
# mean   304.000000          0.003400
# std     50.084928          0.001390
# min    218.000000          0.001879
# 25%    261.000000          0.002448
# 50%    304.000000          0.003051
# 75%    347.000000          0.003603
# max    390.000000          0.010442

# %%
plt.figure(figsize=(20, 8))
plt.plot(execucoes, tempos_execucao, marker='o', linestyle='-', color='blue', label='Tempo de Execução (ECC)')

for x, y in zip(execucoes, tempos_execucao):
    plt.text(x, y + 0.00005, f'{y:.4f}', ha='center', va='center', fontsize=8, rotation=70)

plt.xticks(execucoes, rotation=90)
plt.xlabel('Slice/Espectro')
plt.ylabel('Tempo (s)')
plt.title(f'Tempo de Execução da Criptografia ECIES por Slice (tempo médio: {np.mean(tempos_execucao):.5f} s; desvio padrão: {np.std(tempos_execucao, ddof=0):.5f}; tempo total: {np.sum(tempos_execucao):.5f} segundos))')
plt.legend()
plt.grid(True)
plt.savefig('output_images/graph_tempo_execucao_ecc_criptografia_espectro.png')
plt.show()
