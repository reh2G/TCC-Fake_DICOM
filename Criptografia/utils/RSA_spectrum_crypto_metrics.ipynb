# %%
from Crypto.PublicKey import RSA
from Crypto.Cipher import PKCS1_OAEP
import base64
import os
import cv2
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
key = RSA.generate(4096)
private_key = key.export_key() 
public_key = key.publickey().export_key()

# %%
with open("RSA_keys/RSA_private.pem", "wb") as priv_file:
    priv_file.write(private_key)

with open("RSA_keys/RSA_public.pem", "wb") as pub_file:
    pub_file.write(public_key)

# %% [markdown]
# # Criptografia

# %%
tempos_execucao = []
execucoes = []

for rodagem in range(218, 391):
    inicio = time.perf_counter()
    print(f'Iniciando criptografia: arquivo {rodagem}')

    dicom_path = f'C:\\Users\\CarlosChinen\\OneDrive\\Main\\FEI\\TCC\\Criptografia\\criptografia\\DATASET_dicom_fourier_spectrum\\spectrum_slice_{rodagem}.png'
    

    with open(dicom_path, "rb") as dicom_file:
        image_data = dicom_file.read()

    rsa_key = RSA.import_key(public_key)
    cipher = PKCS1_OAEP.new(rsa_key)

    chunk_size = 470
    encrypted_chunks = []

    for i in range(0, len(image_data), chunk_size):
        chunk = image_data[i : i + chunk_size]
        encrypted_chunk = cipher.encrypt(chunk)
        encrypted_chunks.append(encrypted_chunk)

    encrypted_data = b"".join(encrypted_chunks)
    encrypted_base64 = base64.b64encode(encrypted_data)

    with open(f"RSA_crypto_spectrum_metrics/spectrum_criptografado_{rodagem}.enc", "wb") as enc_file:
        enc_file.write(encrypted_base64)
    
    fim = time.perf_counter()
    tempo_execucao = fim - inicio
    tempos_execucao.append(tempo_execucao)
    execucoes.append(rodagem)
    
    print(f'Criptografia finalizada: arquivo {rodagem}')
    print(f"Tempo de execução: {tempo_execucao:.5f} segundos\n")

print(f'\nTempo médio de execução: {np.mean(tempos_execucao):.5f}')
# Out:
# Iniciando criptografia: arquivo 218
# Criptografia finalizada: arquivo 218
# Tempo de execução: 0.67404 segundos
#
# Iniciando criptografia: arquivo 219
# Criptografia finalizada: arquivo 219
# Tempo de execução: 0.68075 segundos
#
# Iniciando criptografia: arquivo 220
# Criptografia finalizada: arquivo 220
# Tempo de execução: 0.66357 segundos
#
# Iniciando criptografia: arquivo 221
# Criptografia finalizada: arquivo 221
# Tempo de execução: 0.69664 segundos
#
# Iniciando criptografia: arquivo 222
# Criptografia finalizada: arquivo 222
# Tempo de execução: 0.63339 segundos
#
# Iniciando criptografia: arquivo 223
# Criptografia finalizada: arquivo 223
# Tempo de execução: 0.64319 segundos
#
# Iniciando criptografia: arquivo 224
# Criptografia finalizada: arquivo 224
# Tempo de execução: 0.63507 segundos
#
# Iniciando criptografia: arquivo 225
# Criptografia finalizada: arquivo 225
# Tempo de execução: 0.62971 segundos
#
# Iniciando criptografia: arquivo 226
# Criptografia finalizada: arquivo 226
# Tempo de execução: 0.65912 segundos
#
# Iniciando criptografia: arquivo 227
# Criptografia finalizada: arquivo 227
# Tempo de execução: 0.64702 segundos
#
# Iniciando criptografia: arquivo 228
# Criptografia finalizada: arquivo 228
# Tempo de execução: 0.62025 segundos
#
# Iniciando criptografia: arquivo 229
# Criptografia finalizada: arquivo 229
# Tempo de execução: 0.66881 segundos
#
# Iniciando criptografia: arquivo 230
# Criptografia finalizada: arquivo 230
# Tempo de execução: 0.63267 segundos
#
# Iniciando criptografia: arquivo 231
# Criptografia finalizada: arquivo 231
# Tempo de execução: 0.69272 segundos
#
# Iniciando criptografia: arquivo 232
# Criptografia finalizada: arquivo 232
# Tempo de execução: 0.74367 segundos
#
# Iniciando criptografia: arquivo 233
# Criptografia finalizada: arquivo 233
# Tempo de execução: 0.68554 segundos
#
# Iniciando criptografia: arquivo 234
# Criptografia finalizada: arquivo 234
# Tempo de execução: 0.69614 segundos
#
# Iniciando criptografia: arquivo 235
# Criptografia finalizada: arquivo 235
# Tempo de execução: 0.77430 segundos
#
# Iniciando criptografia: arquivo 236
# Criptografia finalizada: arquivo 236
# Tempo de execução: 0.69969 segundos
#
# Iniciando criptografia: arquivo 237
# Criptografia finalizada: arquivo 237
# Tempo de execução: 0.66140 segundos
#
# Iniciando criptografia: arquivo 238
# Criptografia finalizada: arquivo 238
# Tempo de execução: 0.64069 segundos
#
# Iniciando criptografia: arquivo 239
# Criptografia finalizada: arquivo 239
# Tempo de execução: 0.65209 segundos
#
# Iniciando criptografia: arquivo 240
# Criptografia finalizada: arquivo 240
# Tempo de execução: 0.66597 segundos
#
# Iniciando criptografia: arquivo 241
# Criptografia finalizada: arquivo 241
# Tempo de execução: 0.63804 segundos
#
# Iniciando criptografia: arquivo 242
# Criptografia finalizada: arquivo 242
# Tempo de execução: 0.67470 segundos
#
# Iniciando criptografia: arquivo 243
# Criptografia finalizada: arquivo 243
# Tempo de execução: 0.75750 segundos
#
# Iniciando criptografia: arquivo 244
# Criptografia finalizada: arquivo 244
# Tempo de execução: 0.65055 segundos
#
# Iniciando criptografia: arquivo 245
# Criptografia finalizada: arquivo 245
# Tempo de execução: 0.62916 segundos
#
# Iniciando criptografia: arquivo 246
# Criptografia finalizada: arquivo 246
# Tempo de execução: 0.64278 segundos
#
# Iniciando criptografia: arquivo 247
# Criptografia finalizada: arquivo 247
# Tempo de execução: 0.66095 segundos
#
# Iniciando criptografia: arquivo 248
# Criptografia finalizada: arquivo 248
# Tempo de execução: 0.63671 segundos
#
# Iniciando criptografia: arquivo 249
# Criptografia finalizada: arquivo 249
# Tempo de execução: 0.64849 segundos
#
# Iniciando criptografia: arquivo 250
# Criptografia finalizada: arquivo 250
# Tempo de execução: 0.66007 segundos
#
# Iniciando criptografia: arquivo 251
# Criptografia finalizada: arquivo 251
# Tempo de execução: 0.66517 segundos
#
# Iniciando criptografia: arquivo 252
# Criptografia finalizada: arquivo 252
# Tempo de execução: 0.64929 segundos
#
# Iniciando criptografia: arquivo 253
# Criptografia finalizada: arquivo 253
# Tempo de execução: 0.64611 segundos
#
# Iniciando criptografia: arquivo 254
# Criptografia finalizada: arquivo 254
# Tempo de execução: 0.66103 segundos
#
# Iniciando criptografia: arquivo 255
# Criptografia finalizada: arquivo 255
# Tempo de execução: 0.64411 segundos
#
# Iniciando criptografia: arquivo 256
# Criptografia finalizada: arquivo 256
# Tempo de execução: 0.63824 segundos
#
# Iniciando criptografia: arquivo 257
# Criptografia finalizada: arquivo 257
# Tempo de execução: 0.62690 segundos
#
# Iniciando criptografia: arquivo 258
# Criptografia finalizada: arquivo 258
# Tempo de execução: 0.67802 segundos
#
# Iniciando criptografia: arquivo 259
# Criptografia finalizada: arquivo 259
# Tempo de execução: 0.68823 segundos
#
# Iniciando criptografia: arquivo 260
# Criptografia finalizada: arquivo 260
# Tempo de execução: 0.67210 segundos
#
# Iniciando criptografia: arquivo 261
# Criptografia finalizada: arquivo 261
# Tempo de execução: 0.65481 segundos
#
# Iniciando criptografia: arquivo 262
# Criptografia finalizada: arquivo 262
# Tempo de execução: 0.67786 segundos
#
# Iniciando criptografia: arquivo 263
# Criptografia finalizada: arquivo 263
# Tempo de execução: 0.66553 segundos
#
# Iniciando criptografia: arquivo 264
# Criptografia finalizada: arquivo 264
# Tempo de execução: 0.65411 segundos
#
# Iniciando criptografia: arquivo 265
# Criptografia finalizada: arquivo 265
# Tempo de execução: 0.61533 segundos
#
# Iniciando criptografia: arquivo 266
# Criptografia finalizada: arquivo 266
# Tempo de execução: 0.61699 segundos
#
# Iniciando criptografia: arquivo 267
# Criptografia finalizada: arquivo 267
# Tempo de execução: 0.63960 segundos
#
# Iniciando criptografia: arquivo 268
# Criptografia finalizada: arquivo 268
# Tempo de execução: 0.62986 segundos
#
# Iniciando criptografia: arquivo 269
# Criptografia finalizada: arquivo 269
# Tempo de execução: 0.63310 segundos
#
# Iniciando criptografia: arquivo 270
# Criptografia finalizada: arquivo 270
# Tempo de execução: 0.64677 segundos
#
# Iniciando criptografia: arquivo 271
# Criptografia finalizada: arquivo 271
# Tempo de execução: 0.78829 segundos
#
# Iniciando criptografia: arquivo 272
# Criptografia finalizada: arquivo 272
# Tempo de execução: 0.67584 segundos
#
# Iniciando criptografia: arquivo 273
# Criptografia finalizada: arquivo 273
# Tempo de execução: 0.68108 segundos
#
# Iniciando criptografia: arquivo 274
# Criptografia finalizada: arquivo 274
# Tempo de execução: 0.68175 segundos
#
# Iniciando criptografia: arquivo 275
# Criptografia finalizada: arquivo 275
# Tempo de execução: 0.67911 segundos
#
# Iniciando criptografia: arquivo 276
# Criptografia finalizada: arquivo 276
# Tempo de execução: 0.69258 segundos
#
# Iniciando criptografia: arquivo 277
# Criptografia finalizada: arquivo 277
# Tempo de execução: 0.69708 segundos
#
# Iniciando criptografia: arquivo 278
# Criptografia finalizada: arquivo 278
# Tempo de execução: 0.72608 segundos
#
# Iniciando criptografia: arquivo 279
# Criptografia finalizada: arquivo 279
# Tempo de execução: 0.73523 segundos
#
# Iniciando criptografia: arquivo 280
# Criptografia finalizada: arquivo 280
# Tempo de execução: 0.76057 segundos
#
# Iniciando criptografia: arquivo 281
# Criptografia finalizada: arquivo 281
# Tempo de execução: 0.75939 segundos
#
# Iniciando criptografia: arquivo 282
# Criptografia finalizada: arquivo 282
# Tempo de execução: 0.81832 segundos
#
# Iniciando criptografia: arquivo 283
# Criptografia finalizada: arquivo 283
# Tempo de execução: 0.74868 segundos
#
# Iniciando criptografia: arquivo 284
# Criptografia finalizada: arquivo 284
# Tempo de execução: 0.75608 segundos
#
# Iniciando criptografia: arquivo 285
# Criptografia finalizada: arquivo 285
# Tempo de execução: 0.74327 segundos
#
# Iniciando criptografia: arquivo 286
# Criptografia finalizada: arquivo 286
# Tempo de execução: 0.76107 segundos
#
# Iniciando criptografia: arquivo 287
# Criptografia finalizada: arquivo 287
# Tempo de execução: 0.79922 segundos
#
# Iniciando criptografia: arquivo 288
# Criptografia finalizada: arquivo 288
# Tempo de execução: 0.74983 segundos
#
# Iniciando criptografia: arquivo 289
# Criptografia finalizada: arquivo 289
# Tempo de execução: 0.77168 segundos
#
# Iniciando criptografia: arquivo 290
# Criptografia finalizada: arquivo 290
# Tempo de execução: 0.77144 segundos
#
# Iniciando criptografia: arquivo 291
# Criptografia finalizada: arquivo 291
# Tempo de execução: 0.73622 segundos
#
# Iniciando criptografia: arquivo 292
# Criptografia finalizada: arquivo 292
# Tempo de execução: 0.72880 segundos
#
# Iniciando criptografia: arquivo 293
# Criptografia finalizada: arquivo 293
# Tempo de execução: 0.75841 segundos
#
# Iniciando criptografia: arquivo 294
# Criptografia finalizada: arquivo 294
# Tempo de execução: 0.73918 segundos
#
# Iniciando criptografia: arquivo 295
# Criptografia finalizada: arquivo 295
# Tempo de execução: 0.72612 segundos
#
# Iniciando criptografia: arquivo 296
# Criptografia finalizada: arquivo 296
# Tempo de execução: 0.74983 segundos
#
# Iniciando criptografia: arquivo 297
# Criptografia finalizada: arquivo 297
# Tempo de execução: 0.75611 segundos
#
# Iniciando criptografia: arquivo 298
# Criptografia finalizada: arquivo 298
# Tempo de execução: 0.76212 segundos
#
# Iniciando criptografia: arquivo 299
# Criptografia finalizada: arquivo 299
# Tempo de execução: 0.78416 segundos
#
# Iniciando criptografia: arquivo 300
# Criptografia finalizada: arquivo 300
# Tempo de execução: 0.03965 segundos
#
# Iniciando criptografia: arquivo 301
# Criptografia finalizada: arquivo 301
# Tempo de execução: 0.04328 segundos
#
# Iniciando criptografia: arquivo 302
# Criptografia finalizada: arquivo 302
# Tempo de execução: 0.04116 segundos
#
# Iniciando criptografia: arquivo 303
# Criptografia finalizada: arquivo 303
# Tempo de execução: 0.04787 segundos
#
# Iniciando criptografia: arquivo 304
# Criptografia finalizada: arquivo 304
# Tempo de execução: 0.04280 segundos
#
# Iniciando criptografia: arquivo 305
# Criptografia finalizada: arquivo 305
# Tempo de execução: 0.04111 segundos
#
# Iniciando criptografia: arquivo 306
# Criptografia finalizada: arquivo 306
# Tempo de execução: 0.04136 segundos
#
# Iniciando criptografia: arquivo 307
# Criptografia finalizada: arquivo 307
# Tempo de execução: 0.03751 segundos
#
# Iniciando criptografia: arquivo 308
# Criptografia finalizada: arquivo 308
# Tempo de execução: 0.03739 segundos
#
# Iniciando criptografia: arquivo 309
# Criptografia finalizada: arquivo 309
# Tempo de execução: 0.03475 segundos
#
# Iniciando criptografia: arquivo 310
# Criptografia finalizada: arquivo 310
# Tempo de execução: 0.04801 segundos
#
# Iniciando criptografia: arquivo 311
# Criptografia finalizada: arquivo 311
# Tempo de execução: 0.04516 segundos
#
# Iniciando criptografia: arquivo 312
# Criptografia finalizada: arquivo 312
# Tempo de execução: 0.04002 segundos
#
# Iniciando criptografia: arquivo 313
# Criptografia finalizada: arquivo 313
# Tempo de execução: 0.03669 segundos
#
# Iniciando criptografia: arquivo 314
# Criptografia finalizada: arquivo 314
# Tempo de execução: 0.03872 segundos
#
# Iniciando criptografia: arquivo 315
# Criptografia finalizada: arquivo 315
# Tempo de execução: 0.04106 segundos
#
# Iniciando criptografia: arquivo 316
# Criptografia finalizada: arquivo 316
# Tempo de execução: 0.04369 segundos
#
# Iniciando criptografia: arquivo 317
# Criptografia finalizada: arquivo 317
# Tempo de execução: 0.04118 segundos
#
# Iniciando criptografia: arquivo 318
# Criptografia finalizada: arquivo 318
# Tempo de execução: 0.04569 segundos
#
# Iniciando criptografia: arquivo 319
# Criptografia finalizada: arquivo 319
# Tempo de execução: 0.03649 segundos
#
# Iniciando criptografia: arquivo 320
# Criptografia finalizada: arquivo 320
# Tempo de execução: 0.03767 segundos
#
# Iniciando criptografia: arquivo 321
# Criptografia finalizada: arquivo 321
# Tempo de execução: 0.03840 segundos
#
# Iniciando criptografia: arquivo 322
# Criptografia finalizada: arquivo 322
# Tempo de execução: 0.03805 segundos
#
# Iniciando criptografia: arquivo 323
# Criptografia finalizada: arquivo 323
# Tempo de execução: 0.03803 segundos
#
# Iniciando criptografia: arquivo 324
# Criptografia finalizada: arquivo 324
# Tempo de execução: 0.04576 segundos
#
# Iniciando criptografia: arquivo 325
# Criptografia finalizada: arquivo 325
# Tempo de execução: 0.04307 segundos
#
# Iniciando criptografia: arquivo 326
# Criptografia finalizada: arquivo 326
# Tempo de execução: 0.04046 segundos
#
# Iniciando criptografia: arquivo 327
# Criptografia finalizada: arquivo 327
# Tempo de execução: 0.04323 segundos
#
# Iniciando criptografia: arquivo 328
# Criptografia finalizada: arquivo 328
# Tempo de execução: 0.04332 segundos
#
# Iniciando criptografia: arquivo 329
# Criptografia finalizada: arquivo 329
# Tempo de execução: 0.03944 segundos
#
# Iniciando criptografia: arquivo 330
# Criptografia finalizada: arquivo 330
# Tempo de execução: 0.05680 segundos
#
# Iniciando criptografia: arquivo 331
# Criptografia finalizada: arquivo 331
# Tempo de execução: 0.04449 segundos
#
# Iniciando criptografia: arquivo 332
# Criptografia finalizada: arquivo 332
# Tempo de execução: 0.03853 segundos
#
# Iniciando criptografia: arquivo 333
# Criptografia finalizada: arquivo 333
# Tempo de execução: 0.03787 segundos
#
# Iniciando criptografia: arquivo 334
# Criptografia finalizada: arquivo 334
# Tempo de execução: 0.03889 segundos
#
# Iniciando criptografia: arquivo 335
# Criptografia finalizada: arquivo 335
# Tempo de execução: 0.03696 segundos
#
# Iniciando criptografia: arquivo 336
# Criptografia finalizada: arquivo 336
# Tempo de execução: 0.04259 segundos
#
# Iniciando criptografia: arquivo 337
# Criptografia finalizada: arquivo 337
# Tempo de execução: 0.04185 segundos
#
# Iniciando criptografia: arquivo 338
# Criptografia finalizada: arquivo 338
# Tempo de execução: 0.04442 segundos
#
# Iniciando criptografia: arquivo 339
# Criptografia finalizada: arquivo 339
# Tempo de execução: 0.03900 segundos
#
# Iniciando criptografia: arquivo 340
# Criptografia finalizada: arquivo 340
# Tempo de execução: 0.04027 segundos
#
# Iniciando criptografia: arquivo 341
# Criptografia finalizada: arquivo 341
# Tempo de execução: 0.03839 segundos
#
# Iniciando criptografia: arquivo 342
# Criptografia finalizada: arquivo 342
# Tempo de execução: 0.04099 segundos
#
# Iniciando criptografia: arquivo 343
# Criptografia finalizada: arquivo 343
# Tempo de execução: 0.04685 segundos
#
# Iniciando criptografia: arquivo 344
# Criptografia finalizada: arquivo 344
# Tempo de execução: 0.03801 segundos
#
# Iniciando criptografia: arquivo 345
# Criptografia finalizada: arquivo 345
# Tempo de execução: 0.04226 segundos
#
# Iniciando criptografia: arquivo 346
# Criptografia finalizada: arquivo 346
# Tempo de execução: 0.03899 segundos
#
# Iniciando criptografia: arquivo 347
# Criptografia finalizada: arquivo 347
# Tempo de execução: 0.03481 segundos
#
# Iniciando criptografia: arquivo 348
# Criptografia finalizada: arquivo 348
# Tempo de execução: 0.04309 segundos
#
# Iniciando criptografia: arquivo 349
# Criptografia finalizada: arquivo 349
# Tempo de execução: 0.04256 segundos
#
# Iniciando criptografia: arquivo 350
# Criptografia finalizada: arquivo 350
# Tempo de execução: 0.04763 segundos
#
# Iniciando criptografia: arquivo 351
# Criptografia finalizada: arquivo 351
# Tempo de execução: 0.03787 segundos
#
# Iniciando criptografia: arquivo 352
# Criptografia finalizada: arquivo 352
# Tempo de execução: 0.04008 segundos
#
# Iniciando criptografia: arquivo 353
# Criptografia finalizada: arquivo 353
# Tempo de execução: 0.03480 segundos
#
# Iniciando criptografia: arquivo 354
# Criptografia finalizada: arquivo 354
# Tempo de execução: 0.04027 segundos
#
# Iniciando criptografia: arquivo 355
# Criptografia finalizada: arquivo 355
# Tempo de execução: 0.03722 segundos
#
# Iniciando criptografia: arquivo 356
# Criptografia finalizada: arquivo 356
# Tempo de execução: 0.03533 segundos
#
# Iniciando criptografia: arquivo 357
# Criptografia finalizada: arquivo 357
# Tempo de execução: 0.03657 segundos
#
# Iniciando criptografia: arquivo 358
# Criptografia finalizada: arquivo 358
# Tempo de execução: 0.03296 segundos
#
# Iniciando criptografia: arquivo 359
# Criptografia finalizada: arquivo 359
# Tempo de execução: 0.03129 segundos
#
# Iniciando criptografia: arquivo 360
# Criptografia finalizada: arquivo 360
# Tempo de execução: 0.03562 segundos
#
# Iniciando criptografia: arquivo 361
# Criptografia finalizada: arquivo 361
# Tempo de execução: 0.04340 segundos
#
# Iniciando criptografia: arquivo 362
# Criptografia finalizada: arquivo 362
# Tempo de execução: 0.03826 segundos
#
# Iniciando criptografia: arquivo 363
# Criptografia finalizada: arquivo 363
# Tempo de execução: 0.04133 segundos
#
# Iniciando criptografia: arquivo 364
# Criptografia finalizada: arquivo 364
# Tempo de execução: 0.03492 segundos
#
# Iniciando criptografia: arquivo 365
# Criptografia finalizada: arquivo 365
# Tempo de execução: 0.03489 segundos
#
# Iniciando criptografia: arquivo 366
# Criptografia finalizada: arquivo 366
# Tempo de execução: 0.03732 segundos
#
# Iniciando criptografia: arquivo 367
# Criptografia finalizada: arquivo 367
# Tempo de execução: 0.03314 segundos
#
# Iniciando criptografia: arquivo 368
# Criptografia finalizada: arquivo 368
# Tempo de execução: 0.03500 segundos
#
# Iniciando criptografia: arquivo 369
# Criptografia finalizada: arquivo 369
# Tempo de execução: 0.03780 segundos
#
# Iniciando criptografia: arquivo 370
# Criptografia finalizada: arquivo 370
# Tempo de execução: 0.04110 segundos
#
# Iniciando criptografia: arquivo 371
# Criptografia finalizada: arquivo 371
# Tempo de execução: 0.04379 segundos
#
# Iniciando criptografia: arquivo 372
# Criptografia finalizada: arquivo 372
# Tempo de execução: 0.04630 segundos
#
# Iniciando criptografia: arquivo 373
# Criptografia finalizada: arquivo 373
# Tempo de execução: 0.03407 segundos
#
# Iniciando criptografia: arquivo 374
# Criptografia finalizada: arquivo 374
# Tempo de execução: 0.03415 segundos
#
# Iniciando criptografia: arquivo 375
# Criptografia finalizada: arquivo 375
# Tempo de execução: 0.03959 segundos
#
# Iniciando criptografia: arquivo 376
# Criptografia finalizada: arquivo 376
# Tempo de execução: 0.03639 segundos
#
# Iniciando criptografia: arquivo 377
# Criptografia finalizada: arquivo 377
# Tempo de execução: 0.03628 segundos
#
# Iniciando criptografia: arquivo 378
# Criptografia finalizada: arquivo 378
# Tempo de execução: 0.03364 segundos
#
# Iniciando criptografia: arquivo 379
# Criptografia finalizada: arquivo 379
# Tempo de execução: 0.03448 segundos
#
# Iniciando criptografia: arquivo 380
# Criptografia finalizada: arquivo 380
# Tempo de execução: 0.03373 segundos
#
# Iniciando criptografia: arquivo 381
# Criptografia finalizada: arquivo 381
# Tempo de execução: 0.03559 segundos
#
# Iniciando criptografia: arquivo 382
# Criptografia finalizada: arquivo 382
# Tempo de execução: 0.03893 segundos
#
# Iniciando criptografia: arquivo 383
# Criptografia finalizada: arquivo 383
# Tempo de execução: 0.03612 segundos
#
# Iniciando criptografia: arquivo 384
# Criptografia finalizada: arquivo 384
# Tempo de execução: 0.03908 segundos
#
# Iniciando criptografia: arquivo 385
# Criptografia finalizada: arquivo 385
# Tempo de execução: 0.04042 segundos
#
# Iniciando criptografia: arquivo 386
# Criptografia finalizada: arquivo 386
# Tempo de execução: 0.04185 segundos
#
# Iniciando criptografia: arquivo 387
# Criptografia finalizada: arquivo 387
# Tempo de execução: 0.03226 segundos
#
# Iniciando criptografia: arquivo 388
# Criptografia finalizada: arquivo 388
# Tempo de execução: 0.03245 segundos
#
# Iniciando criptografia: arquivo 389
# Criptografia finalizada: arquivo 389
# Tempo de execução: 0.03475 segundos
#
# Iniciando criptografia: arquivo 390
# Criptografia finalizada: arquivo 390
# Tempo de execução: 0.03907 segundos
#
#
# Tempo médio de execução: 0.34754

# %%
df_execucoes = pd.DataFrame({
    'slice': execucoes,
    'tempoExecucaoAES': tempos_execucao
})

df_execucoes.describe()
# Out:
#             slice  tempoExecucaoAES
# count  173.000000        173.000000
# mean   304.000000          0.347540
# std     50.084928          0.327485
# min    218.000000          0.031291
# 25%    261.000000          0.038886
# 50%    304.000000          0.046846
# 75%    347.000000          0.672105
# max    390.000000          0.818320

# %%
plt.figure(figsize=(20, 8))
plt.plot(execucoes, tempos_execucao, marker='o', linestyle='-', color='b', label='Tempo de Execução')

for x, y in zip(execucoes, tempos_execucao):
    plt.text(x, y + 0.002, f'{y:.2f}', ha='center', va='bottom', fontsize=8, rotation=45)
    
plt.xticks(execucoes, rotation=90)
plt.xlabel('Slice/Espectro')
plt.ylabel('Tempo (s)')
plt.title(f'Tempo de Execução da Criptografia por ESPECTRO de Slices (tempo médio: {np.mean(tempos_execucao):.5f} segundos; desvio padrão: {np.std(tempos_execucao, ddof=0):.5f}; tempo total: {np.sum(tempos_execucao):.5f} segundos)')
plt.legend()
plt.grid(True)

plt.savefig('output_images/graph_tempo_execucao_criptografia_espectro.png')

plt.show()
