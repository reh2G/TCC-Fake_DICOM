# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, jaccard_score, f1_score, precision_score, recall_score
from skimage.metrics import structural_similarity as ssim
from sklearn import preprocessing
from keras.utils import to_categorical
from keras import regularizers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.layers import Input, Dense, Dropout, Lambda, GlobalAveragePooling2D
from keras.src.legacy.preprocessing.image import ImageDataGenerator

import random
import re
import glob
from tqdm import tqdm
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
import gc
# Out:
# 2025-05-08 11:34:58.083037: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-08 11:34:58.167990: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-08 11:34:58.211204: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-08 11:34:58.969908: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs disponíveis: {gpus}")
else:
    print("Nenhuma GPU encontrada.")
# Out:
# GPUs disponíveis: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746714917.444940    1343 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746714919.541432    1343 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746714919.541523    1343 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# nome = 'PACS'
nome = 'Yildirim'
#nome = 'Todos'

imgs_path = 'Bases/Dataset' + nome

output_dir = "Results/test-CNN-espectro-ResNet50 new results (1%)/"
os.makedirs(output_dir, exist_ok=True)

TEST_SIZE = 0.1
VALIDATION_SIZE = 0.1

SIMILARITY = 0.75

EPOCHS = 200
BATCH_SIZE = 32

HIGH_FREQ_THRESHOLD = 1
NUM_FOLD = 5

# %%
def get_next_filename(output_folder, base_name, type):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    image_index = 0
    
    while True:
        output_filename = f"{base_name}_{image_index}.{type}"
        output_path = os.path.join(output_folder, output_filename)
        
        if not os.path.exists(output_path):
            return output_filename
            
        image_index += 1

# %%
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else 0

# %%
def sort_files_numerically(file_paths):
    return sorted(file_paths, key=lambda x: extract_number(x))

# %%
def read_dataset(path, jpg, png):
    print(f'Reading dataset...\n')
    
    img_type = []
    images = []
    image_paths = []

    if jpg:
        img_type.append('*.jpg')
    if png:
        img_type.append('*.png')

# Normal

    normal_path = os.path.join(path, 'Train', 'Normal')
    print(f'Reading Normal images from: {normal_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(normal_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# Kidney

    kidney_stone_path = os.path.join(path, 'Train', 'Kidney_stone')
    print(f'Reading Kidney_stone images from: {kidney_stone_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(kidney_stone_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# ...
    
    images = np.array(images)
    image_paths = np.array(image_paths)

    return images, image_paths

# %%
all_X, all_image_paths = read_dataset(path=imgs_path, jpg=True, png=True)
# Out:
# Reading dataset...
#
# Reading Normal images from: Bases/DatasetYildirim/Train/Normal
# Reading Kidney_stone images from: Bases/DatasetYildirim/Train/Kidney_stone

# %%
def freq_spec(image, threshold, add_noise):
    f = np.fft.fft2(image)
    fshift = np.fft.fftshift(f)

    if add_noise:
        amplification_factor = 0.5
        rows, cols = image.shape
        crow, ccol = rows//2, cols//2

        corner = np.random.randint(0, 4)
        
        mask = np.zeros((rows, cols), dtype=bool)
        
        if corner == 0:    # Canto superior esquerdo
            mask[:crow - threshold, :ccol - threshold] = True
        elif corner == 1:  # Canto superior direito
            mask[:crow - threshold, ccol + threshold:] = True
        elif corner == 2:  # Canto inferior esquerdo
            mask[crow + threshold:, :ccol - threshold] = True
        else:              # Canto inferior direito
            mask[crow + threshold:, ccol + threshold:] = True

        fshift[mask] *= amplification_factor

    magnitude_spectrum_high = 20 * np.log(np.abs(fshift) + 1)

    return magnitude_spectrum_high

# %%
def save_specs(images, threshold, add_noise):
    specs = []
    for img in images:
        specs.append(freq_spec(img, threshold, add_noise))
    return specs

# %%
all_specs = []
all_labels = []

for i, img in enumerate(all_X):
    all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=False))
    all_labels.append(0)

for i, img in enumerate(all_X):
    all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=True))
    all_labels.append(1)

all_image_paths = np.concatenate([all_image_paths, all_image_paths])

all_image_paths = np.array(all_image_paths)
all_specs = np.array(all_specs)
all_labels = np.array(all_labels)

# %%
print("Quantidade das imagens:", all_specs.shape)
print("Quantidade dos paths de imagens:", all_image_paths.shape)
print("Exemplo dos labels (False = original, True = com ruído):", all_labels)
# Out:
# Quantidade das imagens: (3598, 224, 224)
# Quantidade dos paths de imagens: (3598,)
# Exemplo dos labels (False = original, True = com ruído): [0 0 0 ... 1 1 1]

# %%
X_train, X_test, y_train, y_test, paths_train, paths_test = train_test_split(
        all_specs, all_labels, all_image_paths,
        test_size=TEST_SIZE, 
        stratify=all_labels,
#       random_state=53
    )

# %%
def plot_specs(specs, title):
    total_images = len(specs)
    imgs_per_figure = 100
    cols = 5
    rows = (imgs_per_figure + cols - 1) // cols

    for start in range(0, total_images, imgs_per_figure):
        plt.figure(figsize=(cols * 3, rows * 3))
        end = min(start + imgs_per_figure, total_images)
        
        for i in range(start, end):
            plt.subplot(rows, cols, i - start + 1)
            plt.imshow(specs[i], cmap='gray')
            plt.title(f"{title} - freq spec: img {i+1}")
            plt.axis('off')
            
        plt.tight_layout()
        plt.show()

# %%
# Plotar todos os espectros de teste
#plot_specs(X_test, title="test")

# %%
#pausa de teste

# %%
# Define as layers do modelo ResNet50
def model_resnet50():
# Camada com tamanho padronizado para imagens em escala de cinza
    inputs = Input(shape=(224, 224, 1))
    
# 1. Conversão para 3 canais
    x = Lambda(
        lambda x: tf.stack([x[..., 0]]*3, axis=-1),
        output_shape=(224, 224, 3)
    )(inputs)
    
# 2. Pré-processamento ResNet
    x = tf.keras.applications.resnet.preprocess_input(x)
    
# 3. Carregar ResNet-50
    base_model = tf.keras.applications.ResNet50(
        weights='imagenet',
        include_top=False,
        input_tensor=x
    )
    
# 4. Topo personalizado
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(150, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    x = Dense(100, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    outputs = Dense(2, activation='softmax')(x)
    
# Compilação
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer='Adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []

# Configurar K-Fold com random_state fixo para reprodutibilidade
#kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=53)
kfold = StratifiedKFold(n_splits=NUM_FOLD, shuffle=True, random_state=53)

# Verificar quais folds já foram completados
completed_folds = []
for f in range(1, NUM_FOLD + 1):
    model_path = output_dir + f'model_{nome}_fold_{f}.keras'
    if os.path.exists(model_path):
        completed_folds.append(f)
print(f"Folds concluídos: {completed_folds}")

fold_no = 1
histories = []
metrics = []

for train_idx, val_idx in kfold.split(X_train, y_train):
# Pular folds já concluídos
    if fold_no in completed_folds:
        print(f"\nPulando fold {fold_no} (já concluído)")
        fold_no += 1
        continue

    print(f'\nTreinando Fold {fold_no}/{NUM_FOLD}')
    
# Split dos dados
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]

# Pré-processamento final
    X_train_fold = np.expand_dims(X_train_fold, axis=-1)
    X_val_fold = np.expand_dims(X_val_fold, axis=-1)
    y_train_fold_cat = to_categorical(y_train_fold, 2)
    y_val_fold_cat = to_categorical(y_val_fold, 2)

# Criar novo modelo para cada fold
    model = model_resnet50()

# Checkpoint com nome do fold
    checkpoint_filepath = output_dir + f'model_{nome}_fold_{fold_no}.keras'
    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss'),
        tf.keras.callbacks.TensorBoard(log_dir='logs'),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=False,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
            verbose=1
        )
    ]

# Calcula tempo (start)
    start_time = time.time()
    
# Treinar modelo
    history = model.fit(
        X_train_fold, y_train_fold_cat,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val_fold, y_val_fold_cat),
        callbacks=callbacks,
        verbose=1
    )

# Calcula tempo (end)
    end_time = time.time()

    training_time = end_time - start_time
    print(f"\nO modelo demorou {training_time:.2f} segundos para treinar.")

# Coletar métricas e salvar modelo
    predictions = model.predict(X_val_fold)
    y_pred = np.argmax(predictions, axis=1)
    
    metrics.append({
        'fold': fold_no,
        'report': classification_report(y_val_fold, y_pred, output_dict=True, zero_division=0),
        'matrix': confusion_matrix(y_val_fold, y_pred)
    })

# Métricas de classificação (por fold)
    acc.append(accuracy_score(y_val_fold, y_pred))
    jacc.append(jaccard_score(y_val_fold, y_pred))
    f1.append(f1_score(y_val_fold, y_pred))
    prec.append(precision_score(y_val_fold, y_pred))
    rec.append(recall_score(y_val_fold, y_pred))

# Salvar métricas em um arquivo .txt
    metrics_filename = os.path.join(output_dir, f'metrics_{nome}_fold_{fold_no}.txt')
    with open(metrics_filename, 'w') as f:
        f.write(f"Fold {fold_no} Metrics:\n")
        f.write(f"Accuracy: {acc[-1]}\n")
        f.write(f"Jaccard Score: {jacc[-1]}\n")
        f.write(f"F1 Score: {f1[-1]}\n")
        f.write(f"Precision: {prec[-1]}\n")
        f.write(f"Recall: {rec[-1]}\n")
        f.write("\nClassification Report:\n")
        f.write(classification_report(y_val_fold, y_pred, zero_division=0))
        f.write("\nConfusion Matrix:\n")
        f.write(np.array2string(confusion_matrix(y_val_fold, y_pred)))

# Limpeza de memória
    del model
    tf.keras.backend.clear_session()
    gc.collect()

# Salvar checkpoint a cada 3 folds
    if fold_no % 3 == 0:
        print(f"\nCheckpoint: Folds {fold_no-2}-{fold_no} concluídos")

    fold_no += 1
# Out:
# Folds concluídos: []
#
# Treinando Fold 1/2
# I0000 00:00:1746715056.268363    1343 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746715056.268714    1343 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746715056.268824    1343 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746715060.687839    1343 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746715060.688006    1343 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-08 11:37:40.688040: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1746715060.688136    1343 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-08 11:37:40.688187: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:10:00.0, compute capability: 8.6
# 2025-05-08 11:38:20.979636: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 324939776 exceeds 10% of free system memory.
# 2025-05-08 11:38:21.296751: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 324939776 exceeds 10% of free system memory.
# Epoch 1/200
# I0000 00:00:1746715128.545877    1479 service.cc:146] XLA service 0x7f5d74005250 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746715128.545940    1479 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-05-08 11:38:50.322415: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-05-08 11:38:58.663756: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 2025-05-08 11:39:04.273957: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15572', 196 bytes spill stores, 196 bytes spill loads
#
# 2025-05-08 11:39:18.471317: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[32,1024,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,7,7]{3,2,1,0}, f32[512,1024,1,1]{3,2,1,0}), window={size=1x1 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-08 11:39:18.530300: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.645854134s
# Trying algorithm eng0{} for conv (f32[32,1024,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,7,7]{3,2,1,0}, f32[512,1024,1,1]{3,2,1,0}), window={size=1x1 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# I0000 00:00:1746715178.100163    1479 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7168 - loss: 3.9231
# 2025-05-08 11:39:58.065482: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15572', 208 bytes spill stores, 208 bytes spill loads
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 769ms/step - accuracy: 0.7197 - loss: 3.9056
# 2025-05-08 11:40:38.829653: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 324939776 exceeds 10% of free system memory.
# 2025-05-08 11:40:39.166523: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 324939776 exceeds 10% of free system memory.
# Epoch 1: val_accuracy improved from -inf to 0.50031, saving model to Results/test-CNN-espectro-ResNet50 new results (1%)/model_Yildirim_fold_1.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.7226 - loss: 3.8887 - val_accuracy: 0.5003 - val_loss: 875.3421
# Epoch 2/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9966 - loss: 1.3109
# Epoch 2: val_accuracy did not improve from 0.50031
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 195ms/step - accuracy: 0.9966 - loss: 1.3063 - val_accuracy: 0.4997 - val_loss: 1.5300
# Epoch 3/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9978 - loss: 0.5718
# Epoch 3: val_accuracy did not improve from 0.50031
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 194ms/step - accuracy: 0.9978 - loss: 0.5701 - val_accuracy: 0.4997 - val_loss: 1.9493
# Epoch 4/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9889 - loss: 0.3244
# Epoch 4: val_accuracy improved from 0.50031 to 0.60716, saving model to Results/test-CNN-espectro-ResNet50 new results (1%)/model_Yildirim_fold_1.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 309ms/step - accuracy: 0.9888 - loss: 0.3241 - val_accuracy: 0.6072 - val_loss: 1.3642
# Epoch 5/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9964 - loss: 0.1943
# Epoch 5: val_accuracy improved from 0.60716 to 0.73996, saving model to Results/test-CNN-espectro-ResNet50 new results (1%)/model_Yildirim_fold_1.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 242ms/step - accuracy: 0.9964 - loss: 0.1940 - val_accuracy: 0.7400 - val_loss: 1.4428
# Epoch 6/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9925 - loss: 0.1449
# Epoch 6: val_accuracy improved from 0.73996 to 0.99815, saving model to Results/test-CNN-espectro-ResNet50 new results (1%)/model_Yildirim_fold_1.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 239ms/step - accuracy: 0.9924 - loss: 0.1448 - val_accuracy: 0.9981 - val_loss: 0.1326
# Epoch 7/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9969 - loss: 0.1111
# Epoch 7: val_accuracy did not improve from 0.99815
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 252ms/step - accuracy: 0.9969 - loss: 0.1110 - val_accuracy: 0.9951 - val_loss: 0.0979
# Epoch 8/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9984 - loss: 0.0764
# Epoch 8: val_accuracy did not improve from 0.99815
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.9984 - loss: 0.0763 - val_accuracy: 0.9975 - val_loss: 0.0604
# Epoch 9/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 1.0000 - loss: 0.0521
# Epoch 9: val_accuracy improved from 0.99815 to 0.99876, saving model to Results/test-CNN-espectro-ResNet50 new results (1%)/model_Yildirim_fold_1.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 253ms/step - accuracy: 1.0000 - loss: 0.0521 - val_accuracy: 0.9988 - val_loss: 0.0458
# Epoch 10/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 0.0402
# Epoch 10: val_accuracy did not improve from 0.99876
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 261ms/step - accuracy: 1.0000 - loss: 0.0402 - val_accuracy: 0.9981 - val_loss: 0.0389
# Epoch 11/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.0327
# Epoch 11: val_accuracy improved from 0.99876 to 0.99938, saving model to Results/test-CNN-espectro-ResNet50 new results (1%)/model_Yildirim_fold_1.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 248ms/step - accuracy: 1.0000 - loss: 0.0326 - val_accuracy: 0.9994 - val_loss: 0.0315
# Epoch 12/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 1.0000 - loss: 0.0271
# Epoch 12: val_accuracy did not improve from 0.99938
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 203ms/step - accuracy: 1.0000 - loss: 0.0271 - val_accuracy: 0.9994 - val_loss: 0.0272
# Epoch 13/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 1.0000 - loss: 0.0227
# Epoch 13: val_accuracy did not improve from 0.99938
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 271ms/step - accuracy: 1.0000 - loss: 0.0227 - val_accuracy: 0.9988 - val_loss: 0.0229
# Epoch 14/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 1.0000 - loss: 0.0190
# Epoch 14: val_accuracy improved from 0.99938 to 1.00000, saving model to Results/test-CNN-espectro-ResNet50 new results (1%)/model_Yildirim_fold_1.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 259ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 0.0191
# Epoch 15/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9975 - loss: 0.0292
# Epoch 15: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.9975 - loss: 0.0295 - val_accuracy: 0.5306 - val_loss: 7.8273
# Epoch 16/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9965 - loss: 0.0485
# Epoch 16: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 0.9964 - loss: 0.0485 - val_accuracy: 0.5269 - val_loss: 27.4792
# Epoch 17/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9897 - loss: 0.0650
# Epoch 17: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.9898 - loss: 0.0647 - val_accuracy: 0.8283 - val_loss: 2.4166
# Epoch 18/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0197
# Epoch 18: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 257ms/step - accuracy: 1.0000 - loss: 0.0197 - val_accuracy: 0.9796 - val_loss: 0.1494
# Epoch 19/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.0179
# Epoch 19: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 1.0000 - loss: 0.0179 - val_accuracy: 0.9988 - val_loss: 0.0201
# Epoch 20/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 20: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 196ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.9994 - val_loss: 0.0132
# Epoch 21/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 21: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 195ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 0.9994 - val_loss: 0.0152
# Epoch 22/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 22: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 254ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 23/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 23: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 196ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.9988 - val_loss: 0.0122
# Epoch 24/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0104
# Epoch 24: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 196ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.9839 - val_loss: 0.0606
# Epoch 25/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 1.0000 - loss: 0.0214
# Epoch 25: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 255ms/step - accuracy: 1.0000 - loss: 0.0214 - val_accuracy: 0.9969 - val_loss: 0.0192
# Epoch 26/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0108
# Epoch 26: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 195ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.9907 - val_loss: 0.0372
# Epoch 27/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9948 - loss: 0.0400
# Epoch 27: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9948 - loss: 0.0400 - val_accuracy: 0.5003 - val_loss: 21.3785
# Epoch 28/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9992 - loss: 0.0190
# Epoch 28: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 255ms/step - accuracy: 0.9992 - loss: 0.0189 - val_accuracy: 0.9969 - val_loss: 0.0275
# Epoch 29/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9936 - loss: 0.0315
# Epoch 29: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9936 - loss: 0.0315 - val_accuracy: 0.9765 - val_loss: 0.1469
# Epoch 30/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9987 - loss: 0.0238
# Epoch 30: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9987 - loss: 0.0238 - val_accuracy: 0.9901 - val_loss: 0.0458
# Epoch 31/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9987 - loss: 0.0214
# Epoch 31: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 254ms/step - accuracy: 0.9987 - loss: 0.0214 - val_accuracy: 0.9969 - val_loss: 0.0233
# Epoch 32/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9991 - loss: 0.0139
# Epoch 32: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9991 - loss: 0.0139 - val_accuracy: 0.9889 - val_loss: 0.0500
# Epoch 33/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9998 - loss: 0.0100
# Epoch 33: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.9997 - loss: 0.0101 - val_accuracy: 0.9988 - val_loss: 0.0169
# Epoch 34/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 34: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 35/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 35: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 197ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9994 - val_loss: 0.0080
# Epoch 36/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 36: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.9981 - val_loss: 0.0128
# Epoch 37/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 37: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9981 - val_loss: 0.0112
# Epoch 38/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 38: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 260ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9981 - val_loss: 0.0112
# Epoch 39/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 39: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 201ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9981 - val_loss: 0.0108
# Epoch 40/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 40: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9981 - val_loss: 0.0106
# Epoch 41/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9999 - loss: 0.0051
# Epoch 41: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 258ms/step - accuracy: 0.9999 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0247
# Epoch 42/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.0197
# Epoch 42: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 201ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 0.9981 - val_loss: 0.0154
# Epoch 43/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 43: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9988 - val_loss: 0.0155
# Epoch 44/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 44: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 258ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9988 - val_loss: 0.0141
# Epoch 45/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0073
# Epoch 45: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9994 - val_loss: 0.0074
# Epoch 46/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9995 - loss: 0.0064
# Epoch 46: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 203ms/step - accuracy: 0.9995 - loss: 0.0064 - val_accuracy: 0.9994 - val_loss: 0.0095
# Epoch 47/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9993 - loss: 0.0114
# Epoch 47: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 257ms/step - accuracy: 0.9993 - loss: 0.0114 - val_accuracy: 0.9994 - val_loss: 0.0108
# Epoch 48/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 48: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9994 - val_loss: 0.0093
# Epoch 49/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9999 - loss: 0.0109
# Epoch 49: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.9998 - loss: 0.0109 - val_accuracy: 0.9994 - val_loss: 0.0226
# Epoch 50/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0151
# Epoch 50: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 257ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.9988 - val_loss: 0.0102
# Epoch 51/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9979 - loss: 0.0213
# Epoch 51: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9979 - loss: 0.0213 - val_accuracy: 0.9920 - val_loss: 0.0407
# Epoch 52/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9993 - loss: 0.0114
# Epoch 52: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9993 - loss: 0.0114 - val_accuracy: 0.9994 - val_loss: 0.0141
# Epoch 53/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0090
# Epoch 53: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.9994 - val_loss: 0.0066
# Epoch 54/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 54: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 257ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 55/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9997 - loss: 0.0092
# Epoch 55: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9997 - loss: 0.0093 - val_accuracy: 1.0000 - val_loss: 0.0162
# Epoch 56/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9999 - loss: 0.0131
# Epoch 56: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9999 - loss: 0.0131 - val_accuracy: 0.9981 - val_loss: 0.0118
# Epoch 57/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9996 - loss: 0.0099
# Epoch 57: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 258ms/step - accuracy: 0.9995 - loss: 0.0100 - val_accuracy: 0.9901 - val_loss: 0.0598
# Epoch 58/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9945 - loss: 0.0561
# Epoch 58: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9946 - loss: 0.0557 - val_accuracy: 0.9685 - val_loss: 0.1231
# Epoch 59/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9909 - loss: 0.0479
# Epoch 59: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9910 - loss: 0.0478 - val_accuracy: 0.9284 - val_loss: 0.3082
# Epoch 60/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9953 - loss: 0.0401
# Epoch 60: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 258ms/step - accuracy: 0.9954 - loss: 0.0398 - val_accuracy: 0.9907 - val_loss: 0.0559
# Epoch 61/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0099
# Epoch 61: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.9981 - val_loss: 0.0146
# Epoch 62/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 62: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 63/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9993 - loss: 0.0095
# Epoch 63: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 259ms/step - accuracy: 0.9993 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0184
# Epoch 64/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 64: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.9988 - val_loss: 0.0107
# Epoch 65/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 65: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9981 - val_loss: 0.0111
# Epoch 66/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9986 - loss: 0.0137
# Epoch 66: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 257ms/step - accuracy: 0.9986 - loss: 0.0137 - val_accuracy: 0.9981 - val_loss: 0.0111
# Epoch 67/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 67: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9981 - val_loss: 0.0081
# Epoch 68/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 68: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9981 - val_loss: 0.0109
# Epoch 69/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 69: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9994 - val_loss: 0.0066
# Epoch 70/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 70: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 257ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 71/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9967 - loss: 0.0214
# Epoch 71: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9966 - loss: 0.0220 - val_accuracy: 0.7671 - val_loss: 3.0786
# Epoch 72/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8700 - loss: 0.3409
# Epoch 72: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.8696 - loss: 0.3423 - val_accuracy: 0.5003 - val_loss: 66.3381
# Epoch 73/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9815 - loss: 0.1255
# Epoch 73: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 257ms/step - accuracy: 0.9817 - loss: 0.1245 - val_accuracy: 0.9067 - val_loss: 0.5330
# Epoch 74/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0225
# Epoch 74: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.9914 - val_loss: 0.0496
# Epoch 75/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9872 - loss: 0.0632
# Epoch 75: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9872 - loss: 0.0633 - val_accuracy: 0.7962 - val_loss: 0.9392
# Epoch 76/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9946 - loss: 0.0362
# Epoch 76: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 257ms/step - accuracy: 0.9946 - loss: 0.0362 - val_accuracy: 0.9852 - val_loss: 0.0821
# Epoch 77/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9987 - loss: 0.0163
# Epoch 77: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9987 - loss: 0.0163 - val_accuracy: 0.9920 - val_loss: 0.0408
# Epoch 78/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9988 - loss: 0.0135
# Epoch 78: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 0.9988 - loss: 0.0135 - val_accuracy: 0.9926 - val_loss: 0.0296
# Epoch 79/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 79: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 260ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9957 - val_loss: 0.0196
# Epoch 80/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9969 - loss: 0.0224
# Epoch 80: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9968 - loss: 0.0229 - val_accuracy: 0.6973 - val_loss: 1.4563
# Epoch 81/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9913 - loss: 0.0366
# Epoch 81: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9913 - loss: 0.0366 - val_accuracy: 0.9710 - val_loss: 0.1148
# Epoch 82/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0187
# Epoch 82: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 256ms/step - accuracy: 1.0000 - loss: 0.0186 - val_accuracy: 0.9981 - val_loss: 0.0132
# Epoch 83/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 83: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 84/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 84: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 85/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 85: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 257ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 86/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0063
# Epoch 86: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9994 - val_loss: 0.0066
# Epoch 87/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 87: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9994 - val_loss: 0.0062
# Epoch 88/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9987 - loss: 0.0088
# Epoch 88: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9987 - loss: 0.0088 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 89/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9998 - loss: 0.0085
# Epoch 89: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 257ms/step - accuracy: 0.9997 - loss: 0.0085 - val_accuracy: 0.9901 - val_loss: 0.0389
# Epoch 90/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9990 - loss: 0.0133
# Epoch 90: val_accuracy did not improve from 1.00000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9990 - loss: 0.0133 - val_accuracy: 0.9938 - val_loss: 0.0261
#
# O modelo demorou 1167.52 segundos para treinar.
# 2025-05-08 11:57:48.172870: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 324939776 exceeds 10% of free system memory.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step
#
# Treinando Fold 2/2
# Epoch 1/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 66
#      63 start_time = time.time()
#      65 # Treinar modelo
# ---> 66 history = model.fit(
#      67     X_train_fold, y_train_fold_cat,
#      68     batch_size=BATCH_SIZE,
#      69     epochs=EPOCHS,
#      70     validation_data=(X_val_fold, y_val_fold_cat),
#      71     callbacks=callbacks,
#      72     verbose=1
#      73 )
#      75 # Calcula tempo (end)
#      76 end_time = time.time()
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:919, in Function._call(self, *args, **kwds)
#     913   # If we did not create any variables the trace we have is good enough.
#     914   filtered_flat_args = (
#     915       self._concrete_variable_creation_fn.function_type.unpack_inputs(
#     916           bound_args
#     917       )
#     918   )
# --> 919   return self._concrete_variable_creation_fn._call_flat(  # pylint: disable=protected-access
#     920       filtered_flat_args,
#     921       self._concrete_variable_creation_fn.captured_inputs,
#     922   )
#     924 def fn_with_cond(inner_args, inner_kwds):
#     925   """Conditionally runs initialization if it's needed."""
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File ~/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
print("Dice: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))
