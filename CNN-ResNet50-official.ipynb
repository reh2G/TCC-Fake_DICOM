# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, jaccard_score, f1_score, precision_score, recall_score
from skimage.metrics import structural_similarity as ssim
from sklearn import preprocessing
from keras.utils import to_categorical
from keras import regularizers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.layers import Input, Dense, Dropout, Lambda, GlobalAveragePooling2D
from keras.src.legacy.preprocessing.image import ImageDataGenerator

import random
import re
import glob
from tqdm import tqdm
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
import gc
# Out:
# 2025-05-10 09:37:36.845752: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-10 09:37:36.921284: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-10 09:37:36.973623: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-10 09:37:37.656688: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs disponíveis: {gpus}")
else:
    print("Nenhuma GPU encontrada.")
# Out:
# GPUs disponíveis: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746880674.099910   15427 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746880675.846934   15427 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746880675.847071   15427 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# nome = 'PACS'
nome = 'Yildirim'
#nome = 'Todos'

imgs_path = 'Bases/Dataset' + nome

output_dir = "Results/test-CNN-espectro-ResNet50 new results (0.1%)/"
os.makedirs(output_dir, exist_ok=True)

TEST_SIZE = 0.1
VALIDATION_SIZE = 0.1

EPOCHS = 200
BATCH_SIZE = 32

HIGH_FREQ_THRESHOLD = 0.1
NUM_FOLD = 5

# %%
def get_next_filename(output_folder, base_name, type):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    image_index = 0
    
    while True:
        output_filename = f"{base_name}_{image_index}.{type}"
        output_path = os.path.join(output_folder, output_filename)
        
        if not os.path.exists(output_path):
            return output_filename
            
        image_index += 1

# %%
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else 0

# %%
def sort_files_numerically(file_paths):
    return sorted(file_paths, key=lambda x: extract_number(x))

# %%
def read_dataset(path, jpg, png):
    print(f'Reading dataset...\n')
    
    img_type = []
    images = []
    image_paths = []

    if jpg:
        img_type.append('*.jpg')
    if png:
        img_type.append('*.png')

# Normal

    normal_path = os.path.join(path, 'Train', 'Normal')
    print(f'Reading Normal images from: {normal_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(normal_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# Kidney

    kidney_stone_path = os.path.join(path, 'Train', 'Kidney_stone')
    print(f'Reading Kidney_stone images from: {kidney_stone_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(kidney_stone_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# ...
    
    images = np.array(images)
    image_paths = np.array(image_paths)

    return images, image_paths

# %%
all_X, all_image_paths = read_dataset(path=imgs_path, jpg=True, png=True)
# Out:
# Reading dataset...
#
# Reading Normal images from: Bases/DatasetYildirim/Train/Normal
# Reading Kidney_stone images from: Bases/DatasetYildirim/Train/Kidney_stone

# %%
output_dir_shift = "All_fshift"
os.makedirs(output_dir_shift, exist_ok=True)

output_dir_spectrum = "All_freqs"
os.makedirs(output_dir_spectrum, exist_ok=True)

def freq_spec(image, threshold, add_noise):
    f = np.fft.fft2(image)
    fshift = np.fft.fftshift(f)

#   global image_counter
#
#   magnitude_temp = 20 * np.log(np.abs(fshift) + 1)
#
#   np.save(os.path.join(output_dir_shift, f"fshift_slice_{image_counter}.npy"), fshift)
#   
#   spectrum_path = os.path.join(output_dir_spectrum, f"spectrum_slice_{image_counter}.png")
#   cv2.imwrite(spectrum_path, magnitude_temp)
#
#   image_counter += 1

    if add_noise:
        amplification_factor = 0.5
        rows, cols = image.shape
        noise_size = int(np.sqrt(threshold * rows * cols))

        # Selecionar aleatoriamente um dos quatro cantos
        corner = np.random.randint(0, 4)

        # Aplicar ruído no canto selecionado
        if corner == 0:  # Canto superior esquerdo
            fshift[:noise_size, :noise_size] = 1
        elif corner == 1:  # Canto superior direito
            fshift[:noise_size, cols - noise_size:] = 1
        elif corner == 2:  # Canto inferior esquerdo
            fshift[rows - noise_size:, :noise_size] = 1
        else:  # Canto inferior direito
            fshift[rows - noise_size:, cols - noise_size:] = 1

    magnitude_spectrum_high = 20 * np.log(np.abs(fshift) + 1)

    return magnitude_spectrum_high

# %%
all_specs = []
all_labels = []

for i, img in enumerate(all_X):
    all_specs.append(freq_spec(img, HIGH_FREQ_THRESHOLD/100.0, add_noise=False))
    all_labels.append(0)

for i, img in enumerate(all_X):
    all_specs.append(freq_spec(img, HIGH_FREQ_THRESHOLD/100.0, add_noise=True))
    all_labels.append(1)

all_image_paths = np.concatenate([all_image_paths, all_image_paths])

all_image_paths = np.array(all_image_paths)
all_specs = np.array(all_specs)
all_labels = np.array(all_labels)

# %%
print("Quantidade das imagens:", all_specs.shape)
print("Quantidade dos paths de imagens:", all_image_paths.shape)
print("Exemplo dos labels (False = original, True = com ruído):", all_labels)
# Out:
# Quantidade das imagens: (3598, 224, 224)
# Quantidade dos paths de imagens: (3598,)
# Exemplo dos labels (False = original, True = com ruído): [0 0 0 ... 1 1 1]

# %%
X_train, X_test, y_train, y_test, paths_train, paths_test = train_test_split(
        all_specs, all_labels, all_image_paths,
        test_size=TEST_SIZE, 
        stratify=all_labels,
#       random_state=53
    )

# %%
def plot_specs(specs, title):
    total_images = len(specs)
    imgs_per_figure = 100
    cols = 5
    rows = (imgs_per_figure + cols - 1) // cols

    for start in range(0, total_images, imgs_per_figure):
        plt.figure(figsize=(cols * 3, rows * 3))
        end = min(start + imgs_per_figure, total_images)
        
        for i in range(start, end):
            plt.subplot(rows, cols, i - start + 1)
            plt.imshow(specs[i], cmap='gray')
            plt.title(f"{title} - freq spec: img {i+1}")
            plt.axis('off')
            
        plt.tight_layout()
        plt.show()

# %%
# Plotar todos os espectros de teste
#plot_specs(X_test, title="test")

# %%
#pausa de teste

# %%
# Define as layers do modelo ResNet50
def model_resnet50():
# Camada com tamanho padronizado para imagens em escala de cinza
    inputs = Input(shape=(224, 224, 1))
    
# 1. Conversão para 3 canais
    x = Lambda(
        lambda x: tf.stack([x[..., 0]]*3, axis=-1),
        output_shape=(224, 224, 3)
    )(inputs)
    
# 2. Pré-processamento ResNet
    x = tf.keras.applications.resnet.preprocess_input(x)
    
# 3. Carregar ResNet-50
    base_model = tf.keras.applications.ResNet50(
        weights='imagenet',
        include_top=False,
        input_tensor=x
    )
    
# 4. Topo personalizado
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(150, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    x = Dense(100, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    outputs = Dense(2, activation='softmax')(x)
    
# Compilação
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer='Adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []

# Configurar K-Fold com random_state fixo para reprodutibilidade
#kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=53)
kfold = StratifiedKFold(n_splits=NUM_FOLD, shuffle=True, random_state=53)

# Verificar quais folds já foram completados
completed_folds = []
for f in range(1, NUM_FOLD + 1):
    model_path = output_dir + f'model_{nome}_fold_{f}.keras'
    if os.path.exists(model_path):
        completed_folds.append(f)
print(f"Folds concluídos: {completed_folds}")

fold_no = 1
histories = []
metrics = []

for train_idx, val_idx in kfold.split(X_train, y_train):
# Pular folds já concluídos
    if fold_no in completed_folds:
        print(f"\nPulando fold {fold_no} (já concluído)")
        fold_no += 1
        continue

    print(f'\nTreinando Fold {fold_no}/{NUM_FOLD}')
    
# Split dos dados
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]

# Pré-processamento final
    X_train_fold = np.expand_dims(X_train_fold, axis=-1)
    X_val_fold = np.expand_dims(X_val_fold, axis=-1)
    y_train_fold_cat = to_categorical(y_train_fold, 2)
    y_val_fold_cat = to_categorical(y_val_fold, 2)

# Criar novo modelo para cada fold
    model = model_resnet50()

# Checkpoint com nome do fold
    checkpoint_filepath = output_dir + f'model_{nome}_fold_{fold_no}.keras'
    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss'),
        tf.keras.callbacks.TensorBoard(log_dir='logs'),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=False,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
            verbose=1
        )
    ]

# Calcula tempo (start)
    start_time = time.time()
    
# Treinar modelo
    history = model.fit(
        X_train_fold, y_train_fold_cat,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val_fold, y_val_fold_cat),
        callbacks=callbacks,
        verbose=1
    )

# Calcula tempo (end)
    end_time = time.time()

    training_time = end_time - start_time
    print(f"\nO modelo demorou {training_time:.2f} segundos para treinar.")

# Coletar métricas e salvar modelo
    predictions = model.predict(X_val_fold)
    y_pred = np.argmax(predictions, axis=1)
    
    metrics.append({
        'fold': fold_no,
        'report': classification_report(y_val_fold, y_pred, output_dict=True, zero_division=0),
        'matrix': confusion_matrix(y_val_fold, y_pred)
    })

# Métricas de classificação (por fold)
    acc.append(accuracy_score(y_val_fold, y_pred))
    jacc.append(jaccard_score(y_val_fold, y_pred))
    f1.append(f1_score(y_val_fold, y_pred))
    prec.append(precision_score(y_val_fold, y_pred))
    rec.append(recall_score(y_val_fold, y_pred))

# Salvar métricas em um arquivo .txt
    metrics_filename = os.path.join(output_dir, f'metrics_{nome}_fold_{fold_no}.txt')
    with open(metrics_filename, 'w') as f:
        f.write(f"Fold {fold_no} Metrics:\n")
        f.write(f"Accuracy: {acc[-1]}\n")
        f.write(f"Jaccard Score: {jacc[-1]}\n")
        f.write(f"F1 Score: {f1[-1]}\n")
        f.write(f"Precision: {prec[-1]}\n")
        f.write(f"Recall: {rec[-1]}\n")
        f.write("\nClassification Report:\n")
        f.write(classification_report(y_val_fold, y_pred, zero_division=0))
        f.write("\nConfusion Matrix:\n")
        f.write(np.array2string(confusion_matrix(y_val_fold, y_pred)))

# Limpeza de memória
    del model
    tf.keras.backend.clear_session()
    gc.collect()

# Salvar checkpoint a cada 3 folds
    if fold_no % 3 == 0:
        print(f"\nCheckpoint: Folds {fold_no-2}-{fold_no} concluídos")

    fold_no += 1
# Out:
# Folds concluídos: [1, 2, 3, 4]
#
# Pulando fold 1 (já concluído)
#
# Pulando fold 2 (já concluído)
#
# Pulando fold 3 (já concluído)
#
# Pulando fold 4 (já concluído)
#
# Treinando Fold 5/5
# I0000 00:00:1746880729.680801   15427 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746880729.681051   15427 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746880729.681113   15427 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746880729.952159   15427 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746880729.952286   15427 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-10 09:38:49.952300: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1746880729.952466   15427 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-10 09:38:49.952518: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:10:00.0, compute capability: 8.6
# 2025-05-10 09:38:56.616575: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 520024064 exceeds 10% of free system memory.
# 2025-05-10 09:38:57.050002: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 520024064 exceeds 10% of free system memory.
# Epoch 1/200
# I0000 00:00:1746880754.308939   15495 service.cc:146] XLA service 0x7fa434003cf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746880754.309093   15495 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-05-10 09:39:15.212946: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-05-10 09:39:21.184820: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 2025-05-10 09:39:24.470798: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15572', 196 bytes spill stores, 196 bytes spill loads
#
# I0000 00:00:1746880791.314977   15495 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9512 - loss: 2.9237
# 2025-05-10 09:40:35.349192: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15572', 208 bytes spill stores, 208 bytes spill loads
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.9517 - loss: 2.9110
# 2025-05-10 09:41:27.443769: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1765', 8 bytes spill stores, 8 bytes spill loads
# Epoch 1: val_accuracy improved from -inf to 0.58887, saving model to Results/test-CNN-espectro-ResNet50 new results (0.1%)/model_Yildirim_fold_5.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.9522 - loss: 2.8986 - val_accuracy: 0.5889 - val_loss: 1.3378
# Epoch 2/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 1.0000 - loss: 0.4384
# Epoch 2: val_accuracy improved from 0.58887 to 0.76662, saving model to Results/test-CNN-espectro-ResNet50 new results (0.1%)/model_Yildirim_fold_5.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 227ms/step - accuracy: 1.0000 - loss: 0.4370 - val_accuracy: 0.7666 - val_loss: 0.6257
# Epoch 3/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.1136
# Epoch 3: val_accuracy improved from 0.76662 to 1.00000, saving model to Results/test-CNN-espectro-ResNet50 new results (0.1%)/model_Yildirim_fold_5.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 180ms/step - accuracy: 1.0000 - loss: 0.1133 - val_accuracy: 1.0000 - val_loss: 0.2858
# Epoch 4/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 1.0000 - loss: 0.0419
# Epoch 4: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 195ms/step - accuracy: 1.0000 - loss: 0.0418 - val_accuracy: 1.0000 - val_loss: 0.0690
# Epoch 5/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0202
# Epoch 5: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 1.0000 - loss: 0.0202 - val_accuracy: 1.0000 - val_loss: 0.0247
# Epoch 6/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0120
# Epoch 6: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 195ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 1.0000 - val_loss: 0.0181
# Epoch 7/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9957 - loss: 0.0208
# Epoch 7: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.9954 - loss: 0.0218 - val_accuracy: 0.4992 - val_loss: 16726189.0000
# Epoch 8/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9206 - loss: 0.2573
# Epoch 8: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.9212 - loss: 0.2559 - val_accuracy: 0.4992 - val_loss: 59521.7305
# Epoch 9/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 1.0000 - loss: 0.0332
# Epoch 9: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 194ms/step - accuracy: 1.0000 - loss: 0.0331 - val_accuracy: 0.4992 - val_loss: 53.6040
# Epoch 10/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9991 - loss: 0.0458
# Epoch 10: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.9991 - loss: 0.0459 - val_accuracy: 0.4992 - val_loss: 4.7204
# Epoch 11/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9998 - loss: 0.0182
# Epoch 11: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.9998 - loss: 0.0182 - val_accuracy: 0.9289 - val_loss: 0.1764
# Epoch 12/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 1.0000 - loss: 0.0163
# Epoch 12: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 195ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 13/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 13: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 14/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 14: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 195ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 15/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0063
# Epoch 15: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 16/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 16: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 17/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 17: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 195ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 18/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 18: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 19/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 19: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 20/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 20: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 196ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 21/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 21: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0352
# Epoch 22/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 1.0000 - loss: 0.0211
# Epoch 22: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 196ms/step - accuracy: 1.0000 - loss: 0.0210 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 23/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0091
# Epoch 23: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 24/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 24: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 25/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 25: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 196ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 26/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 26: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 27/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 27: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 28/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9994 - loss: 0.0155
# Epoch 28: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 196ms/step - accuracy: 0.9994 - loss: 0.0156 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 29/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 29: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 30/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9998 - loss: 0.0143
# Epoch 30: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 197ms/step - accuracy: 0.9998 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 31/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 31: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0106
# Epoch 32/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9998 - loss: 0.0167
# Epoch 32: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9998 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 33/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 33: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 34/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9987 - loss: 0.0124
# Epoch 34: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 18s 218ms/step - accuracy: 0.9986 - loss: 0.0128 - val_accuracy: 0.4992 - val_loss: 32545.1465
# Epoch 35/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0467
# Epoch 35: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 1.0000 - loss: 0.0464 - val_accuracy: 0.9799 - val_loss: 0.1182
# Epoch 36/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 36: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 37/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 37: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 191ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 38/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9999 - loss: 0.0045
# Epoch 38: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9999 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0155
# Epoch 39/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 0.0093
# Epoch 39: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 190ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 40/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 40: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 41/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 41: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 42/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 42: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 191ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 43/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 43: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 44/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 44: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 190ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0097
# Epoch 45/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9993 - loss: 0.0205
# Epoch 45: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.9993 - loss: 0.0204 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 46/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 46: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 47/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 47: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 190ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 48/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 48: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 49/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9995 - loss: 0.0104
# Epoch 49: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.9995 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 50/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9989 - loss: 0.0162
# Epoch 50: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 190ms/step - accuracy: 0.9989 - loss: 0.0162 - val_accuracy: 1.0000 - val_loss: 0.0232
# Epoch 51/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 51: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 52/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 52: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 190ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 53/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 53: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 54/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9998 - loss: 0.0121
# Epoch 54: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.9998 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 0.0167
# Epoch 55/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 0.0101
# Epoch 55: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 190ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 56/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 56: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 57/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9985 - loss: 0.0190
# Epoch 57: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 190ms/step - accuracy: 0.9985 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 0.0224
# Epoch 58/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 58: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 59/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 59: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 60/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 60: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 190ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 61/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 61: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 62/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 62: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 63/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9997 - loss: 0.0065
# Epoch 63: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 191ms/step - accuracy: 0.9997 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0490
# Epoch 64/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0296
# Epoch 64: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 1.0000 - loss: 0.0294 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 65/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 65: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 190ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 66/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9985 - loss: 0.0321
# Epoch 66: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.9985 - loss: 0.0320 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 67/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 67: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 68/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 68: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 191ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 69/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 69: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 70/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 70: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 191ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 71/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 71: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 72/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 72: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 73/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 1.0000 - loss: 0.0047
# Epoch 73: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 190ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0035
#
# O modelo demorou 1150.29 segundos para treinar.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step

# %%
print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
print("Dice: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))
# Out:
# Accuracy: 1.0+- 0.0
# Jaccard: 1.0+- 0.0
# Dice: 1.0+- 0.0
# Precision: 1.0+- 0.0
# Recall: 1.0+- 0.0
