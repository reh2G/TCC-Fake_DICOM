# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, jaccard_score, f1_score, precision_score, recall_score
from skimage.metrics import structural_similarity as ssim
from sklearn import preprocessing
from keras.utils import to_categorical
from keras import regularizers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.layers import Input, Dense, Dropout, Lambda, GlobalAveragePooling2D
from keras.src.legacy.preprocessing.image import ImageDataGenerator

import random
import re
import glob
from tqdm import tqdm
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
import gc
# Out:
# 2025-03-27 18:03:13.407377: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-27 18:03:13.496273: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-27 18:03:13.535541: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-27 18:03:14.301139: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs disponíveis: {gpus}")
else:
    print("Nenhuma GPU encontrada.")
# Out:
# GPUs disponíveis: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743109413.210929   51183 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743109415.168232   51183 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743109415.168320   51183 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# nome = 'PACS'
nome = 'Yildirim'
#nome = 'Todos'

imgs_path = 'Bases/Dataset' + nome

output_dir = "12-CNN-espectro-ResNet50 results (2%)/"
os.makedirs(output_dir, exist_ok=True)

TEST_SIZE = 0.1
VALIDATION_SIZE = 0.1

SIMILARITY = 0.75

EPOCHS = 200
BATCH_SIZE = 32

HIGH_FREQ_THRESHOLD = 2

# %%
def get_next_filename(output_folder, base_name, type):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    image_index = 0
    
    while True:
        output_filename = f"{base_name}_{image_index}.{type}"
        output_path = os.path.join(output_folder, output_filename)
        
        if not os.path.exists(output_path):
            return output_filename
            
        image_index += 1

# %%
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else 0

# %%
def sort_files_numerically(file_paths):
    return sorted(file_paths, key=lambda x: extract_number(x))

# %%
def find_groups(images, image_paths, test_size, similarity_threshold):
    def are_similar(img1, img2, threshold):
        similarity = ssim(img1, img2)
        return similarity >= threshold

    groups = []
    current_group = [image_paths[0]]

    for i in range(1, len(images)):
        if are_similar(images[i-1], images[i], similarity_threshold):
            current_group.append(image_paths[i])
        else:
            groups.append(current_group)
            current_group = [image_paths[i]]
    
    if current_group:
        groups.append(current_group)

    all_images = [img_path for group in groups for img_path in group]

    for img_path in image_paths:
        if img_path not in all_images:
            groups.append([img_path])

    random.shuffle(groups)

    train_set = []
    test_set = []
    current_test_size = 0
    
    for i, group in enumerate(groups):
        if current_test_size + len(group) <= test_size:
            test_set.extend(group)
            current_test_size += len(group)
        else:
            train_set.extend(group)

    return train_set, test_set

# %%
output_folder = 'Groups'
type = 'txt'

def save_groups(train_groups, test_groups, base_name):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    output_filename = get_next_filename(output_folder, base_name, type)
    output_path = os.path.join(output_folder, output_filename)

    with open(output_path, 'w') as file:
        file.write('- test:\n')
        for idx, group in enumerate(test_groups, start=1):
            for img in group:
                file.write(f"{img}\n")
        
        file.write('- train:\n')
        for idx, group in enumerate(train_groups, start=1):
            for img in group:
                file.write(f'{img}\n')
    
    print(f'Group information saved in {output_path}')

# %%
def read_dataset(path, jpg, png):
    print(f'Reading dataset...\n')
    
    img_type = []
    images = []
    image_paths = []

    if jpg:
        img_type.append('*.jpg')
    if png:
        img_type.append('*.png')

# Normal

    normal_path = os.path.join(path, 'Train', 'Normal')
    print(f'Reading Normal images from: {normal_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(normal_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# Kidney

    kidney_stone_path = os.path.join(path, 'Train', 'Kidney_stone')
    print(f'Reading Kidney_stone images from: {kidney_stone_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(kidney_stone_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# ...
    
    images = np.array(images)
    image_paths = np.array(image_paths)

    return images, image_paths

# %%
all_X, all_image_paths = read_dataset(path=imgs_path, jpg=True, png=True)
# Out:
# Reading dataset...
#
# Reading Normal images from: Bases/DatasetYildirim/Train/Normal
# Reading Kidney_stone images from: Bases/DatasetYildirim/Train/Kidney_stone

# %%
def freq_spec(image, threshold, add_noise):
    f = np.fft.fft2(image)
    fshift = np.fft.fftshift(f)

    if add_noise:
        amplification_factor = 0.5
        rows, cols = image.shape
        crow, ccol = rows//2, cols//2

        corner = np.random.randint(0, 4)
        
        mask = np.zeros((rows, cols), dtype=bool)
        
        if corner == 0:    # Canto superior esquerdo
            mask[:crow - threshold, :ccol - threshold] = True
        elif corner == 1:  # Canto superior direito
            mask[:crow - threshold, ccol + threshold:] = True
        elif corner == 2:  # Canto inferior esquerdo
            mask[crow + threshold:, :ccol - threshold] = True
        else:              # Canto inferior direito
            mask[crow + threshold:, ccol + threshold:] = True

        fshift[mask] *= amplification_factor

    magnitude_spectrum_high = 20 * np.log(np.abs(fshift) + 1)

    return magnitude_spectrum_high

# %%
def save_specs(images, threshold, add_noise):
    specs = []
    for img in images:
        specs.append(freq_spec(img, threshold, add_noise))
    return specs

# %%
all_specs = []
all_labels = []

half = len(all_X) // 2
for i, img in enumerate(all_X):
    if i < half:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=False))
        all_labels.append(0)
    else:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=True))
        all_labels.append(1)

all_specs = np.array(all_specs)
all_labels = np.array(all_labels)

# %%
print("Quantidade das imagens:", all_specs.shape)
print("Exemplo dos labels (False = original, True = com ruído):", all_labels)
# Out:
# Quantidade das imagens: (1799, 224, 224)
# Exemplo dos labels (False = original, True = com ruído): [0 0 0 ... 1 1 1]

# %%
X_train, X_test, y_train, y_test, paths_train, paths_test = train_test_split(
        all_specs, all_labels, all_image_paths,
        test_size=TEST_SIZE, 
        stratify=all_labels,
#       random_state=53
    )

# %%
def plot_specs(specs, title):
    total_images = len(specs)
    imgs_per_figure = 100
    cols = 5
    rows = (imgs_per_figure + cols - 1) // cols

    for start in range(0, total_images, imgs_per_figure):
        plt.figure(figsize=(cols * 3, rows * 3))
        end = min(start + imgs_per_figure, total_images)
        
        for i in range(start, end):
            plt.subplot(rows, cols, i - start + 1)
            plt.imshow(specs[i], cmap='gray')
            plt.title(f"{title} - freq spec: img {i+1}")
            plt.axis('off')
            
        plt.tight_layout()
        plt.show()

# %%
# Plotar todos os espectros de teste
#plot_specs(X_test, title="test")

# %%
#pausa de teste

# %%
# Defines the model layers (now for ResNet50)
def model_resnet50():  # (Optional: Rename the function for clarity)
    # Camada de entrada para imagens em escala de cinza (mantido igual)
    inputs = Input(shape=(224, 224, 1))
    
    # 1. Conversão para 3 canais (mantido igual)
    x = Lambda(lambda x: tf.repeat(x, 3, axis=-1))(inputs)
    
    # 2. Pré-processamento ResNet (mantido igual)
    x = tf.keras.applications.resnet.preprocess_input(x)
    
    # 3. *** ALTERAÇÃO PRINCIPAL: Carregar ResNet-50 ***
    base_model = tf.keras.applications.ResNet50(
        weights='imagenet',
        include_top=False,
        input_tensor=x
    )
    
    # 4. Topo personalizado (mantido igual)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(150, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    x = Dense(100, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    outputs = Dense(2, activation='softmax')(x)
    
    # Compilação (mantido igual)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer='Adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []

# Configurar K-Fold com random_state fixo para reprodutibilidade
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=53)

# Verificar quais folds já foram completados
completed_folds = []
for f in range(1, 6):
    model_path = output_dir + f'model_{nome}_fold_{f}.keras'
    if os.path.exists(model_path):
        completed_folds.append(f)
print(f"Folds concluídos: {completed_folds}")

fold_no = 1
histories = []
metrics = []

for train_idx, val_idx in kfold.split(X_train, y_train):
    # Pular folds já concluídos
    if fold_no in completed_folds:
        print(f"\nPulando fold {fold_no} (já concluído)")
        fold_no += 1
        continue

    print(f'\nTreinando Fold {fold_no}/5')
    
    # Split dos dados
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]

    # Pré-processamento final
    X_train_fold = np.expand_dims(X_train_fold, axis=-1)
    X_val_fold = np.expand_dims(X_val_fold, axis=-1)
    y_train_fold_cat = to_categorical(y_train_fold, 2)
    y_val_fold_cat = to_categorical(y_val_fold, 2)

    # Criar novo modelo para cada fold
    model = model_resnet50()

    # Checkpoint com nome do fold
    checkpoint_filepath = output_dir + f'model_{nome}_fold_{fold_no}.keras'
    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss'),
        tf.keras.callbacks.TensorBoard(log_dir='logs'),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=False,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
            verbose=1
        )
    ]

    # Calcula tempo (start)
    start_time = time.time()
    
    # Treinar modelo
    history = model.fit(
        X_train_fold, y_train_fold_cat,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val_fold, y_val_fold_cat),
        callbacks=callbacks,
        verbose=1
    )

    # Calcula tempo (end)
    end_time = time.time()

    training_time = end_time - start_time
    print(f"\nO modelo demorou {training_time:.2f} segundos para treinar.")

    # Coletar métricas e salvar modelo
    predictions = model.predict(X_val_fold)
    y_pred = np.argmax(predictions, axis=1)
    
    metrics.append({
        'fold': fold_no,
        'report': classification_report(y_val_fold, y_pred, output_dict=True, zero_division=0),
        'matrix': confusion_matrix(y_val_fold, y_pred)
    })

    # Métricas de classificação (por fold)
    acc.append(accuracy_score(y_val_fold, y_pred))
    jacc.append(jaccard_score(y_val_fold, y_pred))
    f1.append(f1_score(y_val_fold, y_pred))
    prec.append(precision_score(y_val_fold, y_pred))
    rec.append(recall_score(y_val_fold, y_pred))

    # Salvar métricas em um arquivo .txt
    metrics_filename = os.path.join(output_dir, f'metrics_{nome}_fold_{fold_no}.txt')
    with open(metrics_filename, 'w') as f:
        f.write(f"Fold {fold_no} Metrics:\n")
        f.write(f"Accuracy: {acc[-1]}\n")
        f.write(f"Jaccard Score: {jacc[-1]}\n")
        f.write(f"F1 Score: {f1[-1]}\n")
        f.write(f"Precision: {prec[-1]}\n")
        f.write(f"Recall: {rec[-1]}\n")
        f.write("\nClassification Report:\n")
        f.write(classification_report(y_val_fold, y_pred, zero_division=0))
        f.write("\nConfusion Matrix:\n")
        f.write(np.array2string(confusion_matrix(y_val_fold, y_pred)))

    # Limpeza de memória
    del model
    tf.keras.backend.clear_session()
    gc.collect()

    # Salvar checkpoint a cada 3 folds
    if fold_no % 3 == 0:
        print(f"\nCheckpoint: Folds {fold_no-2}-{fold_no} concluídos")

    fold_no += 1
# Out:
# Folds concluídos: [1, 2, 3, 4]
#
# Pulando fold 1 (já concluído)
#
# Pulando fold 2 (já concluído)
#
# Pulando fold 3 (já concluído)
#
# Pulando fold 4 (já concluído)
#
# Treinando Fold 5/5
# I0000 00:00:1743109500.720774   51183 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743109500.720885   51183 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743109500.720937   51183 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743109501.011145   51183 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743109501.011235   51183 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-27 18:05:01.011246: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1743109501.011330   51183 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-27 18:05:01.011352: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:10:00.0, compute capability: 8.6
# Epoch 1/200
# I0000 00:00:1743109528.184902   51253 service.cc:146] XLA service 0x7f22200073f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1743109528.184947   51253 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-03-27 18:05:29.268950: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-27 18:05:31.818959: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 2025-03-27 18:05:35.390083: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15567', 196 bytes spill stores, 196 bytes spill loads
#
# 2025-03-27 18:05:50.972304: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng40{k2=10,k6=0,k12=40,k13=1,k14=0,k15=0,k17=41,k22=3} for conv (f32[64,3,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,224,224]{3,2,1,0}, f32[32,64,112,112]{3,2,1,0}), window={size=7x7 stride=2x2 pad=3_3x3_3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-03-27 18:05:50.973650: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.597785475s
# Trying algorithm eng40{k2=10,k6=0,k12=40,k13=1,k14=0,k15=0,k17=41,k22=3} for conv (f32[64,3,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,224,224]{3,2,1,0}, f32[32,64,112,112]{3,2,1,0}), window={size=7x7 stride=2x2 pad=3_3x3_3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# I0000 00:00:1743109564.760279   51253 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7641 - loss: 3.9061
# 2025-03-27 18:06:26.809915: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng58{k2=7,k12=-1,k13=0,k14=1,k15=0,k17=2,k18=1,k23=0} for conv (f32[256,256,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,256,14,14]{3,2,1,0}, f32[16,256,14,14]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-03-27 18:06:26.810671: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.588005016s
# Trying algorithm eng58{k2=7,k12=-1,k13=0,k14=1,k15=0,k17=2,k18=1,k23=0} for conv (f32[256,256,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,256,14,14]{3,2,1,0}, f32[16,256,14,14]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.7668 - loss: 3.8877
# 2025-03-27 18:06:42.706543: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1760', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-03-27 18:06:43.189192: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1760', 12 bytes spill stores, 12 bytes spill loads
# Epoch 1: val_accuracy improved from -inf to 0.50155, saving model to 12-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.7693 - loss: 3.8703 - val_accuracy: 0.5015 - val_loss: 16459.7988
# Epoch 2/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9926 - loss: 1.5352
# Epoch 2: val_accuracy improved from 0.50155 to 0.64396, saving model to 12-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 207ms/step - accuracy: 0.9926 - loss: 1.5285 - val_accuracy: 0.6440 - val_loss: 2.1569
# Epoch 3/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9987 - loss: 0.6815
# Epoch 3: val_accuracy did not improve from 0.64396
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 0.9987 - loss: 0.6792 - val_accuracy: 0.5294 - val_loss: 2.0283
# Epoch 4/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9904 - loss: 0.3878
# Epoch 4: val_accuracy improved from 0.64396 to 0.71517, saving model to 12-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 206ms/step - accuracy: 0.9904 - loss: 0.3867 - val_accuracy: 0.7152 - val_loss: 0.8398
# Epoch 5/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9962 - loss: 0.2462
# Epoch 5: val_accuracy improved from 0.71517 to 0.82972, saving model to 12-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 205ms/step - accuracy: 0.9962 - loss: 0.2455 - val_accuracy: 0.8297 - val_loss: 0.5621
# Epoch 6/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.1535
# Epoch 6: val_accuracy improved from 0.82972 to 0.87926, saving model to 12-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 205ms/step - accuracy: 1.0000 - loss: 0.1531 - val_accuracy: 0.8793 - val_loss: 0.4521
# Epoch 7/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9998 - loss: 0.1077
# Epoch 7: val_accuracy improved from 0.87926 to 0.95356, saving model to 12-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 293ms/step - accuracy: 0.9998 - loss: 0.1076 - val_accuracy: 0.9536 - val_loss: 0.2358
# Epoch 8/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0802
# Epoch 8: val_accuracy improved from 0.95356 to 0.97523, saving model to 12-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 206ms/step - accuracy: 1.0000 - loss: 0.0801 - val_accuracy: 0.9752 - val_loss: 0.1558
# Epoch 9/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0642
# Epoch 9: val_accuracy improved from 0.97523 to 0.99071, saving model to 12-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 205ms/step - accuracy: 1.0000 - loss: 0.0641 - val_accuracy: 0.9907 - val_loss: 0.0992
# Epoch 10/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9994 - loss: 0.0503
# Epoch 10: val_accuracy did not improve from 0.99071
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 157ms/step - accuracy: 0.9994 - loss: 0.0503 - val_accuracy: 0.9876 - val_loss: 0.0925
# Epoch 11/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9972 - loss: 0.0473
# Epoch 11: val_accuracy did not improve from 0.99071
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 0.9973 - loss: 0.0472 - val_accuracy: 0.9907 - val_loss: 0.0613
# Epoch 12/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0425
# Epoch 12: val_accuracy improved from 0.99071 to 1.00000, saving model to 12-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 206ms/step - accuracy: 1.0000 - loss: 0.0425 - val_accuracy: 1.0000 - val_loss: 0.0370
# Epoch 13/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0298
# Epoch 13: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 157ms/step - accuracy: 1.0000 - loss: 0.0298 - val_accuracy: 1.0000 - val_loss: 0.0288
# Epoch 14/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0232
# Epoch 14: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0231 - val_accuracy: 1.0000 - val_loss: 0.0234
# Epoch 15/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0205
# Epoch 15: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0205 - val_accuracy: 1.0000 - val_loss: 0.0202
# Epoch 16/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 1.0000 - loss: 0.0181
# Epoch 16: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0181 - val_accuracy: 1.0000 - val_loss: 0.0167
# Epoch 17/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0156
# Epoch 17: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 1.0000 - val_loss: 0.0147
# Epoch 18/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0137
# Epoch 18: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 19/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 19: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 1.0000 - val_loss: 0.0129
# Epoch 20/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 20: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 21/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9995 - loss: 0.0133
# Epoch 21: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 0.9995 - loss: 0.0134 - val_accuracy: 0.8978 - val_loss: 0.4618
# Epoch 22/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9883 - loss: 0.0919
# Epoch 22: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 0.9884 - loss: 0.0912 - val_accuracy: 0.9505 - val_loss: 0.3353
# Epoch 23/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9949 - loss: 0.0369
# Epoch 23: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 0.9949 - loss: 0.0369 - val_accuracy: 0.7152 - val_loss: 4.7208
# Epoch 24/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9890 - loss: 0.0515
# Epoch 24: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.9891 - loss: 0.0514 - val_accuracy: 0.5635 - val_loss: 10.0538
# Epoch 25/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9984 - loss: 0.0286
# Epoch 25: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 0.9984 - loss: 0.0285 - val_accuracy: 0.9845 - val_loss: 0.2065
# Epoch 26/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 1.0000 - loss: 0.0200
# Epoch 26: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 1.0000 - loss: 0.0199 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 27/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0136
# Epoch 27: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 28/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0099
# Epoch 28: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 29/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9925 - loss: 0.0506
# Epoch 29: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.9926 - loss: 0.0512 - val_accuracy: 0.9938 - val_loss: 0.1255
# Epoch 30/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9951 - loss: 0.0996
# Epoch 30: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 0.9951 - loss: 0.0993 - val_accuracy: 0.5697 - val_loss: 33.2904
# Epoch 31/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9972 - loss: 0.0470
# Epoch 31: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 0.9972 - loss: 0.0468 - val_accuracy: 0.9876 - val_loss: 0.1185
# Epoch 32/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0203
# Epoch 32: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0202 - val_accuracy: 0.9938 - val_loss: 0.0378
# Epoch 33/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 33: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 34/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 34: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 35/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0090
# Epoch 35: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 36/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 36: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0088
# Epoch 37/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9997 - loss: 0.0097
# Epoch 37: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 0.9997 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 0.0143
# Epoch 38/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9856 - loss: 0.0703
# Epoch 38: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.9857 - loss: 0.0698 - val_accuracy: 0.9907 - val_loss: 0.0379
# Epoch 39/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0138
# Epoch 39: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.9969 - val_loss: 0.0124
# Epoch 40/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9994 - loss: 0.0108
# Epoch 40: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.9994 - loss: 0.0108 - val_accuracy: 0.9969 - val_loss: 0.0151
# Epoch 41/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 41: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.9969 - val_loss: 0.0161
# Epoch 42/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9993 - loss: 0.0086
# Epoch 42: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 0.9993 - loss: 0.0087 - val_accuracy: 0.9938 - val_loss: 0.0168
# Epoch 43/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 43: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.9938 - val_loss: 0.0153
# Epoch 44/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 44: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9938 - val_loss: 0.0124
# Epoch 45/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 45: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9938 - val_loss: 0.0129
# Epoch 46/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 46: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 47/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 47: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 48/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 48: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 49/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 49: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9969 - val_loss: 0.0088
# Epoch 50/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 50: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9938 - val_loss: 0.0129
# Epoch 51/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 51: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 52/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 52: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 53/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 53: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 54/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 54: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 55/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 55: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 56/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 56: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 57/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 57: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 58/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 58: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 59/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0047
# Epoch 59: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 60/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 60: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 61/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9436 - loss: 0.1794
# Epoch 61: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.9408 - loss: 0.1858 - val_accuracy: 0.5015 - val_loss: 10079.1943
# Epoch 62/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.4988 - loss: 0.7744
# Epoch 62: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 0.4990 - loss: 0.7741 - val_accuracy: 0.5015 - val_loss: 35.4463
# Epoch 63/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.4725 - loss: 0.7281
# Epoch 63: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 0.4726 - loss: 0.7280 - val_accuracy: 0.5015 - val_loss: 0.7147
# Epoch 64/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.5030 - loss: 0.7124
# Epoch 64: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 0.5029 - loss: 0.7124 - val_accuracy: 0.4985 - val_loss: 0.7070
# Epoch 65/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.5006 - loss: 0.7115
# Epoch 65: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 249ms/step - accuracy: 0.5001 - loss: 0.7115 - val_accuracy: 0.5015 - val_loss: 0.7078
# Epoch 66/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5130 - loss: 0.7063
# Epoch 66: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 0.5128 - loss: 0.7064 - val_accuracy: 0.5015 - val_loss: 0.7057
# Epoch 67/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.4960 - loss: 0.7093
# Epoch 67: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 0.4961 - loss: 0.7092 - val_accuracy: 0.4985 - val_loss: 0.7036
# Epoch 68/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.4748 - loss: 0.7043
# Epoch 68: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 0.4750 - loss: 0.7043 - val_accuracy: 0.4985 - val_loss: 0.7056
# Epoch 69/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.4600 - loss: 0.7061
# Epoch 69: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 0.4600 - loss: 0.7061 - val_accuracy: 0.4985 - val_loss: 0.7043
# Epoch 70/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.5347 - loss: 0.6980
# Epoch 70: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 250ms/step - accuracy: 0.5345 - loss: 0.6981 - val_accuracy: 0.4985 - val_loss: 0.7834
# Epoch 71/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.4751 - loss: 0.7019
# Epoch 71: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 0.4758 - loss: 0.7019 - val_accuracy: 0.5108 - val_loss: 0.7542
# Epoch 72/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.5453 - loss: 0.6966
# Epoch 72: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 0.5450 - loss: 0.6966 - val_accuracy: 0.5201 - val_loss: 0.7004
# Epoch 73/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.5200 - loss: 0.6993
# Epoch 73: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - accuracy: 0.5199 - loss: 0.6994 - val_accuracy: 0.5015 - val_loss: 0.7027
# Epoch 74/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.5257 - loss: 0.7002
# Epoch 74: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 170ms/step - accuracy: 0.5258 - loss: 0.7002 - val_accuracy: 0.5015 - val_loss: 0.7052
# Epoch 75/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.5885 - loss: 0.6760
# Epoch 75: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 0.5905 - loss: 0.6745 - val_accuracy: 0.8607 - val_loss: 0.4400
# Epoch 76/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9556 - loss: 0.2301
# Epoch 76: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 0.9555 - loss: 0.2296 - val_accuracy: 0.5108 - val_loss: 4.1565
# Epoch 77/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9811 - loss: 0.1206
# Epoch 77: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 0.9812 - loss: 0.1201 - val_accuracy: 0.9907 - val_loss: 0.0612
# Epoch 78/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9995 - loss: 0.0457
# Epoch 78: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - accuracy: 0.9994 - loss: 0.0457 - val_accuracy: 0.9969 - val_loss: 0.0361
# Epoch 79/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0320
# Epoch 79: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - accuracy: 1.0000 - loss: 0.0320 - val_accuracy: 1.0000 - val_loss: 0.0238
#
# O modelo demorou 681.74 segundos para treinar.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 620ms/step

# %%
print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
print("Dice: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))
# Out:
# Accuracy: 1.0+- 0.0
# Jaccard: 1.0+- 0.0
# Dice: 1.0+- 0.0
# Precision: 1.0+- 0.0
# Recall: 1.0+- 0.0

# %%
# GC collect
tf.keras.backend.clear_session()
gc.collect()
# Out:
# 0
