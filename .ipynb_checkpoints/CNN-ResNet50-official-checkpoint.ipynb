# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, jaccard_score, f1_score, precision_score, recall_score
from skimage.metrics import structural_similarity as ssim
from sklearn import preprocessing
from keras.utils import to_categorical
from keras import regularizers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.layers import Input, Dense, Dropout, Lambda, GlobalAveragePooling2D
from keras.src.legacy.preprocessing.image import ImageDataGenerator

import random
import re
import glob
from tqdm import tqdm
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
import gc
# Out:
# 2025-04-21 18:12:14.288880: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-21 18:12:14.299205: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-21 18:12:14.302208: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-21 18:12:14.310871: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs disponíveis: {gpus}")
else:
    print("Nenhuma GPU encontrada.")
# Out:
# GPUs disponíveis: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745269936.330973    1760 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1745269936.372524    1760 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1745269936.372621    1760 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# nome = 'PACS'
nome = 'Yildirim'
#nome = 'Todos'

imgs_path = 'Bases/Dataset' + nome

output_dir = "Results/test-CNN-espectro-ResNet50 new results (1%)/"
os.makedirs(output_dir, exist_ok=True)

TEST_SIZE = 0.1
VALIDATION_SIZE = 0.1

SIMILARITY = 0.75

EPOCHS = 200
BATCH_SIZE = 32

HIGH_FREQ_THRESHOLD = 1
NUM_FOLD = 2

# %%
def get_next_filename(output_folder, base_name, type):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    image_index = 0
    
    while True:
        output_filename = f"{base_name}_{image_index}.{type}"
        output_path = os.path.join(output_folder, output_filename)
        
        if not os.path.exists(output_path):
            return output_filename
            
        image_index += 1

# %%
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else 0

# %%
def sort_files_numerically(file_paths):
    return sorted(file_paths, key=lambda x: extract_number(x))

# %%
def read_dataset(path, jpg, png):
    print(f'Reading dataset...\n')
    
    img_type = []
    images = []
    image_paths = []

    if jpg:
        img_type.append('*.jpg')
    if png:
        img_type.append('*.png')

# Normal

    normal_path = os.path.join(path, 'Train', 'Normal')
    print(f'Reading Normal images from: {normal_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(normal_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# Kidney

    kidney_stone_path = os.path.join(path, 'Train', 'Kidney_stone')
    print(f'Reading Kidney_stone images from: {kidney_stone_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(kidney_stone_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# ...
    
    images = np.array(images)
    image_paths = np.array(image_paths)

    return images, image_paths

# %%
all_X, all_image_paths = read_dataset(path=imgs_path, jpg=True, png=True)
# Out:
# Reading dataset...
#
# Reading Normal images from: Bases/DatasetYildirim/Train/Normal
# Reading Kidney_stone images from: Bases/DatasetYildirim/Train/Kidney_stone

# %%
def freq_spec(image, threshold, add_noise):
    f = np.fft.fft2(image)
    fshift = np.fft.fftshift(f)

    if add_noise:
        amplification_factor = 0.5
        rows, cols = image.shape
        crow, ccol = rows//2, cols//2

        corner = np.random.randint(0, 4)
        
        mask = np.zeros((rows, cols), dtype=bool)
        
        if corner == 0:    # Canto superior esquerdo
            mask[:crow - threshold, :ccol - threshold] = True
        elif corner == 1:  # Canto superior direito
            mask[:crow - threshold, ccol + threshold:] = True
        elif corner == 2:  # Canto inferior esquerdo
            mask[crow + threshold:, :ccol - threshold] = True
        else:              # Canto inferior direito
            mask[crow + threshold:, ccol + threshold:] = True

        fshift[mask] *= amplification_factor

    magnitude_spectrum_high = 20 * np.log(np.abs(fshift) + 1)

    return magnitude_spectrum_high

# %%
def save_specs(images, threshold, add_noise):
    specs = []
    for img in images:
        specs.append(freq_spec(img, threshold, add_noise))
    return specs

# %%
all_specs = []
all_labels = []

for i, img in enumerate(all_X):
    all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=False))
    all_labels.append(0)

for i, img in enumerate(all_X):
    all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=True))
    all_labels.append(1)

all_image_paths = np.concatenate([all_image_paths, all_image_paths])

all_image_paths = np.array(all_image_paths)
all_specs = np.array(all_specs)
all_labels = np.array(all_labels)

# %%
print("Quantidade das imagens:", all_specs.shape)
print("Quantidade dos paths de imagens:", all_image_paths.shape)
print("Exemplo dos labels (False = original, True = com ruído):", all_labels)
# Out:
# Quantidade das imagens: (3598, 224, 224)
# Quantidade dos paths de imagens: (3598,)
# Exemplo dos labels (False = original, True = com ruído): [0 0 0 ... 1 1 1]

# %%
X_train, X_test, y_train, y_test, paths_train, paths_test = train_test_split(
        all_specs, all_labels, all_image_paths,
        test_size=TEST_SIZE, 
        stratify=all_labels,
#       random_state=53
    )

# %%
def plot_specs(specs, title):
    total_images = len(specs)
    imgs_per_figure = 100
    cols = 5
    rows = (imgs_per_figure + cols - 1) // cols

    for start in range(0, total_images, imgs_per_figure):
        plt.figure(figsize=(cols * 3, rows * 3))
        end = min(start + imgs_per_figure, total_images)
        
        for i in range(start, end):
            plt.subplot(rows, cols, i - start + 1)
            plt.imshow(specs[i], cmap='gray')
            plt.title(f"{title} - freq spec: img {i+1}")
            plt.axis('off')
            
        plt.tight_layout()
        plt.show()

# %%
# Plotar todos os espectros de teste
#plot_specs(X_test, title="test")

# %%
#pausa de teste

# %%
# Define as layers do modelo ResNet50
def model_resnet50():
# Camada com tamanho padronizado para imagens em escala de cinza
    inputs = Input(shape=(224, 224, 1))
    
# 1. Conversão para 3 canais
    x = Lambda(
        lambda x: tf.stack([x[..., 0]]*3, axis=-1),
        output_shape=(224, 224, 3)
    )(inputs)
    
# 2. Pré-processamento ResNet
    x = tf.keras.applications.resnet.preprocess_input(x)
    
# 3. Carregar ResNet-50
    base_model = tf.keras.applications.ResNet50(
        weights='imagenet',
        include_top=False,
        input_tensor=x
    )
    
# 4. Topo personalizado
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(150, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    x = Dense(100, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    outputs = Dense(2, activation='softmax')(x)
    
# Compilação
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer='Adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []

# Configurar K-Fold com random_state fixo para reprodutibilidade
#kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=53)
kfold = StratifiedKFold(n_splits=NUM_FOLD, shuffle=True, random_state=53)

# Verificar quais folds já foram completados
completed_folds = []
for f in range(1, NUM_FOLD + 1):
    model_path = output_dir + f'model_{nome}_fold_{f}.keras'
    if os.path.exists(model_path):
        completed_folds.append(f)
print(f"Folds concluídos: {completed_folds}")

fold_no = 1
histories = []
metrics = []

for train_idx, val_idx in kfold.split(X_train, y_train):
    # Pular folds já concluídos
    if fold_no in completed_folds:
        print(f"\nPulando fold {fold_no} (já concluído)")
        fold_no += 1
        continue

    print(f'\nTreinando Fold {fold_no}/{NUM_FOLD}')
    
    # Split dos dados
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]

    # Pré-processamento final
    X_train_fold = np.expand_dims(X_train_fold, axis=-1)
    X_val_fold = np.expand_dims(X_val_fold, axis=-1)
    y_train_fold_cat = to_categorical(y_train_fold, 2)
    y_val_fold_cat = to_categorical(y_val_fold, 2)

    # Criar novo modelo para cada fold
    model = model_resnet50()

    # Checkpoint com nome do fold
    checkpoint_filepath = output_dir + f'model_{nome}_fold_{fold_no}.keras'
    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss'),
        tf.keras.callbacks.TensorBoard(log_dir='logs'),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=False,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
            verbose=1
        )
    ]

    # Calcula tempo (start)
    start_time = time.time()
    
    # Treinar modelo
    history = model.fit(
        X_train_fold, y_train_fold_cat,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val_fold, y_val_fold_cat),
        callbacks=callbacks,
        verbose=1
    )

    # Calcula tempo (end)
    end_time = time.time()

    training_time = end_time - start_time
    print(f"\nO modelo demorou {training_time:.2f} segundos para treinar.")

    # Coletar métricas e salvar modelo
    predictions = model.predict(X_val_fold)
    y_pred = np.argmax(predictions, axis=1)
    
    metrics.append({
        'fold': fold_no,
        'report': classification_report(y_val_fold, y_pred, output_dict=True, zero_division=0),
        'matrix': confusion_matrix(y_val_fold, y_pred)
    })

    # Métricas de classificação (por fold)
    acc.append(accuracy_score(y_val_fold, y_pred))
    jacc.append(jaccard_score(y_val_fold, y_pred))
    f1.append(f1_score(y_val_fold, y_pred))
    prec.append(precision_score(y_val_fold, y_pred))
    rec.append(recall_score(y_val_fold, y_pred))

    # Salvar métricas em um arquivo .txt
    metrics_filename = os.path.join(output_dir, f'metrics_{nome}_fold_{fold_no}.txt')
    with open(metrics_filename, 'w') as f:
        f.write(f"Fold {fold_no} Metrics:\n")
        f.write(f"Accuracy: {acc[-1]}\n")
        f.write(f"Jaccard Score: {jacc[-1]}\n")
        f.write(f"F1 Score: {f1[-1]}\n")
        f.write(f"Precision: {prec[-1]}\n")
        f.write(f"Recall: {rec[-1]}\n")
        f.write("\nClassification Report:\n")
        f.write(classification_report(y_val_fold, y_pred, zero_division=0))
        f.write("\nConfusion Matrix:\n")
        f.write(np.array2string(confusion_matrix(y_val_fold, y_pred)))

    # Limpeza de memória
    del model
    tf.keras.backend.clear_session()
    gc.collect()

    # Salvar checkpoint a cada 3 folds
    if fold_no % 3 == 0:
        print(f"\nCheckpoint: Folds {fold_no-2}-{fold_no} concluídos")

    fold_no += 1
# Out:
# Folds concluídos: []
#
# Treinando Fold 1/5
# I0000 00:00:1745270004.458103    1760 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1745270004.458280    1760 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1745270004.458340    1760 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1745270008.273653    1760 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1745270008.273907    1760 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-21 18:13:28.273927: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1745270008.274094    1760 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-21 18:13:28.274161: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:10:00.0, compute capability: 8.6
# 2025-04-21 18:13:39.694793: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 519823360 exceeds 10% of free system memory.
# 2025-04-21 18:13:42.204498: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 519823360 exceeds 10% of free system memory.
# Epoch 1/200
# I0000 00:00:1745270044.290719    1823 service.cc:146] XLA service 0x7fe510016620 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745270044.290788    1823 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-04-21 18:14:08.516163: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-04-21 18:14:11.256327: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 2025-04-21 18:14:15.040602: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15572', 196 bytes spill stores, 196 bytes spill loads
#
# 2025-04-21 18:14:28.086265: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[32,1024,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,7,7]{3,2,1,0}, f32[512,1024,1,1]{3,2,1,0}), window={size=1x1 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-04-21 18:14:29.582746: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.496639332s
# Trying algorithm eng0{} for conv (f32[32,1024,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,7,7]{3,2,1,0}, f32[512,1024,1,1]{3,2,1,0}), window={size=1x1 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-04-21 18:14:43.165689: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng38{k2=12,k6=1,k13=1,k14=0,k22=3} for conv (f32[1024,512,1,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,28,28]{3,2,1,0}, f32[32,1024,14,14]{3,2,1,0}), window={size=1x1 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-04-21 18:14:43.175760: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.950558175s
# Trying algorithm eng38{k2=12,k6=1,k13=1,k14=0,k22=3} for conv (f32[1024,512,1,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,28,28]{3,2,1,0}, f32[32,1024,14,14]{3,2,1,0}), window={size=1x1 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# I0000 00:00:1745270095.264863    1823 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.6710 - loss: 3.6809
# 2025-04-21 18:15:22.417663: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15572', 208 bytes spill stores, 208 bytes spill loads
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 674ms/step - accuracy: 0.6727 - loss: 3.6680
# 2025-04-21 18:16:01.252992: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1765', 8 bytes spill stores, 8 bytes spill loads
# Epoch 1: val_accuracy improved from -inf to 0.63580, saving model to test-CNN-espectro-ResNet50 new results (1%)/model_Yildirim_fold_1.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 146s 922ms/step - accuracy: 0.6743 - loss: 3.6554 - val_accuracy: 0.6358 - val_loss: 1.6570
# Epoch 2/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9902 - loss: 0.8358
# Epoch 2: val_accuracy improved from 0.63580 to 0.81173, saving model to test-CNN-espectro-ResNet50 new results (1%)/model_Yildirim_fold_1.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 24s 289ms/step - accuracy: 0.9902 - loss: 0.8337 - val_accuracy: 0.8117 - val_loss: 1.2206
# Epoch 3/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9967 - loss: 0.3364
# Epoch 3: val_accuracy improved from 0.81173 to 0.92593, saving model to test-CNN-espectro-ResNet50 new results (1%)/model_Yildirim_fold_1.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 256ms/step - accuracy: 0.9968 - loss: 0.3358 - val_accuracy: 0.9259 - val_loss: 0.4141
# Epoch 4/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9963 - loss: 0.1885
# Epoch 4: val_accuracy improved from 0.92593 to 0.99691, saving model to test-CNN-espectro-ResNet50 new results (1%)/model_Yildirim_fold_1.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 24s 291ms/step - accuracy: 0.9963 - loss: 0.1882 - val_accuracy: 0.9969 - val_loss: 0.1780
# Epoch 5/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9985 - loss: 0.1265
# Epoch 5: val_accuracy did not improve from 0.99691
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 268ms/step - accuracy: 0.9985 - loss: 0.1264 - val_accuracy: 0.9907 - val_loss: 0.1175
# Epoch 6/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9988 - loss: 0.0797
# Epoch 6: val_accuracy did not improve from 0.99691
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 232ms/step - accuracy: 0.9988 - loss: 0.0796 - val_accuracy: 0.9954 - val_loss: 0.0863
# Epoch 7/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 1.0000 - loss: 0.0561
# Epoch 7: val_accuracy improved from 0.99691 to 0.99846, saving model to test-CNN-espectro-ResNet50 new results (1%)/model_Yildirim_fold_1.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 24s 291ms/step - accuracy: 1.0000 - loss: 0.0561 - val_accuracy: 0.9985 - val_loss: 0.0542
# Epoch 8/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 1.0000 - loss: 0.0430
# Epoch 8: val_accuracy did not improve from 0.99846
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 232ms/step - accuracy: 1.0000 - loss: 0.0430 - val_accuracy: 0.9985 - val_loss: 0.0379
# Epoch 9/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9998 - loss: 0.0349
# Epoch 9: val_accuracy improved from 0.99846 to 1.00000, saving model to test-CNN-espectro-ResNet50 new results (1%)/model_Yildirim_fold_1.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 24s 294ms/step - accuracy: 0.9998 - loss: 0.0350 - val_accuracy: 1.0000 - val_loss: 0.0451
# Epoch 10/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 1.0000 - loss: 0.0443
# Epoch 10: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 269ms/step - accuracy: 1.0000 - loss: 0.0442 - val_accuracy: 0.9985 - val_loss: 0.0282
# Epoch 11/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 0.0272
# Epoch 11: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - accuracy: 1.0000 - loss: 0.0271 - val_accuracy: 0.9985 - val_loss: 0.0275
# Epoch 12/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 1.0000 - loss: 0.0206
# Epoch 12: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 269ms/step - accuracy: 1.0000 - loss: 0.0206 - val_accuracy: 0.9985 - val_loss: 0.0351
# Epoch 13/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9833 - loss: 0.1247
# Epoch 13: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 234ms/step - accuracy: 0.9834 - loss: 0.1247 - val_accuracy: 0.7423 - val_loss: 4.0480
# Epoch 14/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9991 - loss: 0.0379
# Epoch 14: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 269ms/step - accuracy: 0.9991 - loss: 0.0378 - val_accuracy: 0.9861 - val_loss: 0.0869
# Epoch 15/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9990 - loss: 0.0235
# Epoch 15: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 270ms/step - accuracy: 0.9990 - loss: 0.0236 - val_accuracy: 0.9306 - val_loss: 0.3155
# Epoch 16/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9964 - loss: 0.0410
# Epoch 16: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 234ms/step - accuracy: 0.9964 - loss: 0.0410 - val_accuracy: 0.9938 - val_loss: 0.0721
# Epoch 17/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9976 - loss: 0.0235
# Epoch 17: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 270ms/step - accuracy: 0.9976 - loss: 0.0235 - val_accuracy: 0.9938 - val_loss: 0.0525
# Epoch 18/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9983 - loss: 0.0190
# Epoch 18: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - accuracy: 0.9983 - loss: 0.0191 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 19/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 19: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 269ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 20/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9985 - loss: 0.0161
# Epoch 20: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - accuracy: 0.9985 - loss: 0.0161 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 21/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 21: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 270ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0088
# Epoch 22/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0096
# Epoch 22: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 270ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 23/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9999 - loss: 0.0084
# Epoch 23: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - accuracy: 0.9999 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0146
# Epoch 24/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 24: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 270ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 25/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 25: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 26/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 26: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 270ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 27/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 27: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 270ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 28/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9997 - loss: 0.0088
# Epoch 28: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - accuracy: 0.9997 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 29/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 29: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 270ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9985 - val_loss: 0.0089
# Epoch 30/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 30: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 31/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 31: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 270ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 32/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 32: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 33/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 33: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 271ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 34/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 34: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 271ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9969 - val_loss: 0.0212
# Epoch 35/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 35: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 234ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 36/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 36: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 270ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 37/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 37: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 38/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 38: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 270ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 39/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 39: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 270ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 40/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9921 - loss: 0.0578
# Epoch 40: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 235ms/step - accuracy: 0.9921 - loss: 0.0579 - val_accuracy: 0.5000 - val_loss: 325.9215
# Epoch 41/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9989 - loss: 0.0220
# Epoch 41: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 272ms/step - accuracy: 0.9989 - loss: 0.0220 - val_accuracy: 0.8349 - val_loss: 1.7856
# Epoch 42/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.9967 - loss: 0.0216
# Epoch 42: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 235ms/step - accuracy: 0.9967 - loss: 0.0216 - val_accuracy: 0.9861 - val_loss: 0.1398
# Epoch 43/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9998 - loss: 0.0091
# Epoch 43: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 271ms/step - accuracy: 0.9998 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 44/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 44: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 271ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9985 - val_loss: 0.0169
# Epoch 45/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.9991 - loss: 0.0092
# Epoch 45: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 235ms/step - accuracy: 0.9991 - loss: 0.0093 - val_accuracy: 0.9969 - val_loss: 0.0593
# Epoch 46/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9976 - loss: 0.0250
# Epoch 46: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 272ms/step - accuracy: 0.9976 - loss: 0.0251 - val_accuracy: 0.9923 - val_loss: 0.0565
# Epoch 47/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9982 - loss: 0.0154
# Epoch 47: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 234ms/step - accuracy: 0.9982 - loss: 0.0154 - val_accuracy: 0.9938 - val_loss: 0.0582
# Epoch 48/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9999 - loss: 0.0075
# Epoch 48: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 271ms/step - accuracy: 0.9999 - loss: 0.0075 - val_accuracy: 0.9954 - val_loss: 0.0558
# Epoch 49/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9999 - loss: 0.0153
# Epoch 49: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 234ms/step - accuracy: 0.9999 - loss: 0.0153 - val_accuracy: 0.9954 - val_loss: 0.0480
# Epoch 50/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9985 - loss: 0.0142
# Epoch 50: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 271ms/step - accuracy: 0.9985 - loss: 0.0143 - val_accuracy: 0.9985 - val_loss: 0.0084
# Epoch 51/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9996 - loss: 0.0118
# Epoch 51: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 271ms/step - accuracy: 0.9996 - loss: 0.0118 - val_accuracy: 0.9985 - val_loss: 0.0280
# Epoch 52/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9990 - loss: 0.0125
# Epoch 52: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 234ms/step - accuracy: 0.9990 - loss: 0.0125 - val_accuracy: 0.9985 - val_loss: 0.0114
# Epoch 53/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 53: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 271ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.9985 - val_loss: 0.0062
# Epoch 54/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9998 - loss: 0.0056
# Epoch 54: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 234ms/step - accuracy: 0.9998 - loss: 0.0056 - val_accuracy: 0.9985 - val_loss: 0.0148
# Epoch 55/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9998 - loss: 0.0089
# Epoch 55: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 271ms/step - accuracy: 0.9998 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 56/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9998 - loss: 0.0059
# Epoch 56: val_accuracy did not improve from 1.00000
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 271ms/step - accuracy: 0.9998 - loss: 0.0059 - val_accuracy: 0.9985 - val_loss: 0.0077
#
# O modelo demorou 1299.11 segundos para treinar.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step
#
# Treinando Fold 2/5

# %%
print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
print("Dice: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))
