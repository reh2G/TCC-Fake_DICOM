# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from skimage.metrics import structural_similarity as ssim
from sklearn import preprocessing
from keras.utils import to_categorical
from keras import regularizers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.layers import Input, Dense, Dropout, Lambda, GlobalAveragePooling2D
from keras.src.legacy.preprocessing.image import ImageDataGenerator

import random
import re
import glob
from tqdm import tqdm
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
import gc
# Out:
# 2025-03-14 01:33:41.503270: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-14 01:33:41.517938: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-14 01:33:41.522354: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-14 01:33:41.536650: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs disponíveis: {gpus}")
else:
    print("Nenhuma GPU encontrada.")
# Out:
# GPUs disponíveis: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741926827.642690   35215 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741926827.732750   35215 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741926827.732840   35215 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# nome = 'PACS'
nome = 'Yildirim'
#nome = 'Todos'

imgs_path = 'Bases/Dataset' + nome

TEST_SIZE = 0.1
VALIDATION_SIZE = 0.1

SIMILARITY = 0.75

EPOCHS = 100
BATCH_SIZE = 32

HIGH_FREQ_THRESHOLD = 12

# %%
def get_next_filename(output_folder, base_name, type):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    image_index = 0
    
    while True:
        output_filename = f"{base_name}_{image_index}.{type}"
        output_path = os.path.join(output_folder, output_filename)
        
        if not os.path.exists(output_path):
            return output_filename
            
        image_index += 1

# %%
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else 0

# %%
def sort_files_numerically(file_paths):
    return sorted(file_paths, key=lambda x: extract_number(x))

# %%
def find_groups(images, image_paths, test_size, similarity_threshold):
    def are_similar(img1, img2, threshold):
        similarity = ssim(img1, img2)
        return similarity >= threshold

    groups = []
    current_group = [image_paths[0]]

    for i in range(1, len(images)):
        if are_similar(images[i-1], images[i], similarity_threshold):
            current_group.append(image_paths[i])
        else:
            groups.append(current_group)
            current_group = [image_paths[i]]
    
    if current_group:
        groups.append(current_group)

    all_images = [img_path for group in groups for img_path in group]

    for img_path in image_paths:
        if img_path not in all_images:
            groups.append([img_path])

    random.shuffle(groups)

    train_set = []
    test_set = []
    current_test_size = 0
    
    for i, group in enumerate(groups):
        if current_test_size + len(group) <= test_size:
            test_set.extend(group)
            current_test_size += len(group)
        else:
            train_set.extend(group)

    return train_set, test_set

# %%
output_folder = 'Groups'
type = 'txt'

def save_groups(train_groups, test_groups, base_name):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    output_filename = get_next_filename(output_folder, base_name, type)
    output_path = os.path.join(output_folder, output_filename)

    with open(output_path, 'w') as file:
        file.write('- test:\n')
        for idx, group in enumerate(test_groups, start=1):
            for img in group:
                file.write(f"{img}\n")
        
        file.write('- train:\n')
        for idx, group in enumerate(train_groups, start=1):
            for img in group:
                file.write(f'{img}\n')
    
    print(f'Group information saved in {output_path}')

# %%
def read_dataset(path, jpg, png):
    print(f'Reading dataset...\n')
    
    img_type = []
    images = []
    image_paths = []

    if jpg:
        img_type.append('*.jpg')
    if png:
        img_type.append('*.png')

# Normal

    normal_path = os.path.join(path, 'Train', 'Normal')
    print(f'Reading Normal images from: {normal_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(normal_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# Kidney

    kidney_stone_path = os.path.join(path, 'Train', 'Kidney_stone')
    print(f'Reading Kidney_stone images from: {kidney_stone_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(kidney_stone_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# ...
    
    images = np.array(images)
    image_paths = np.array(image_paths)

    return images, image_paths

# %%
all_X, all_image_paths = read_dataset(path=imgs_path, jpg=True, png=True)
# Out:
# Reading dataset...
#
# Reading Normal images from: Bases/DatasetYildirim/Train/Normal
# Reading Kidney_stone images from: Bases/DatasetYildirim/Train/Kidney_stone

# %%
def freq_spec(image, threshold, add_noise):
    f = np.fft.fft2(image)
    fshift = np.fft.fftshift(f)

    if add_noise:
        amplification_factor = 0.5
        
        rows, cols = image.shape
        crow, ccol = rows//2, cols//2

        mask = np.zeros((rows, cols), dtype=bool)
        mask[crow-threshold:crow+threshold, ccol-threshold:ccol+threshold] = True
        high_freq_mask = ~mask

        fshift[high_freq_mask] *= amplification_factor

    magnitude_spectrum_high = 20 * np.log(np.abs(fshift) + 1)

    return magnitude_spectrum_high

# %%
def save_specs(images, threshold, add_noise):
    specs = []
    for img in images:
        specs.append(freq_spec(img, threshold, add_noise))
    return specs

# %%
# Processar todas as imagens e criar labels
all_specs = []
all_labels = []

# Processar metade normal e metade hackeada
half = len(all_X) // 2
for i, img in enumerate(all_X):
    if i < half:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=False))
        all_labels.append(0)
    else:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=True))
        all_labels.append(1)

all_specs = np.array(all_specs)
all_labels = np.array(all_labels)

# %%
#len_normal_specs = int(len(all_X) / 2)

# %%
#normal_specs = all_X[0:len_normal_specs]

# %%
#normal_specs = save_specs(normal_specs, 100 - HIGH_FREQ_THRESHOLD, add_noise = False)

# %%
#print(len(normal_specs))

# %%
#hacked_specs = all_X[len_normal_specs:len(all_X)]

# %%
#hacked_specs = save_specs(hacked_specs, 100 - HIGH_FREQ_THRESHOLD, add_noise = True)

# %%
#print(len(hacked_specs))

# %%
print("Quantidade das imagens:", all_specs.shape)
print("Exemplo dos labels (False = original, True = com ruído):", all_labels)
# Out:
# Quantidade das imagens: (1799, 224, 224)
# Exemplo dos labels (False = original, True = com ruído): [0 0 0 ... 1 1 1]

# %%
X_train, X_test, y_train, y_test, paths_train, paths_test = train_test_split(
        all_specs, all_labels, all_image_paths,
        test_size=TEST_SIZE, 
        stratify=all_labels,
#       random_state=53
    )

# %%
def plot_specs(specs, title):
    total_images = len(specs)
    imgs_per_figure = 100
    cols = 5
    rows = (imgs_per_figure + cols - 1) // cols

    for start in range(0, total_images, imgs_per_figure):
        plt.figure(figsize=(cols * 3, rows * 3))
        end = min(start + imgs_per_figure, total_images)
        
        for i in range(start, end):
            plt.subplot(rows, cols, i - start + 1)
            plt.imshow(specs[i], cmap='gray')
            plt.title(f"{title} - freq spec: img {i+1}")
            plt.axis('off')
            
        plt.tight_layout()
        plt.show()

# %%
# Plotar todos os espectros de teste
#plot_specs(X_test, title="test")

# %%
#pausa de teste

# %%
# Defines the model layers (now for ResNet50)
def model_resnet50():  # (Optional: Rename the function for clarity)
    # Camada de entrada para imagens em escala de cinza (mantido igual)
    inputs = Input(shape=(224, 224, 1))
    
    # 1. Conversão para 3 canais (mantido igual)
    x = Lambda(lambda x: tf.repeat(x, 3, axis=-1))(inputs)
    
    # 2. Pré-processamento ResNet (mantido igual)
    x = tf.keras.applications.resnet.preprocess_input(x)
    
    # 3. *** ALTERAÇÃO PRINCIPAL: Carregar ResNet-50 ***
    base_model = tf.keras.applications.ResNet50(
        weights='imagenet',
        include_top=False,
        input_tensor=x
    )
    
    # 4. Topo personalizado (mantido igual)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(150, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    x = Dense(100, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    outputs = Dense(2, activation='softmax')(x)
    
    # Compilação (mantido igual)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer='Adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
# Configurar K-Fold
kfold = StratifiedKFold(n_splits=5, shuffle=True)
#kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=53)
fold_no = 1
histories = []
metrics = []

for train_idx, val_idx in kfold.split(X_train, y_train):
    print(f'\nTraining Fold {fold_no}/5')
    
# Split dos dados
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]
    
# Pré-processamento final
    X_train_fold = np.expand_dims(X_train_fold, axis=-1)
    X_val_fold = np.expand_dims(X_val_fold, axis=-1)
    y_train_fold_cat = to_categorical(y_train_fold, 2)
    y_val_fold_cat = to_categorical(y_val_fold, 2)

# Criar novo modelo para cada fold
    model = model_resnet50()

# Checkpoint com nome do fold
    output_folder = 'Models_saves'
    base_name = 'model_' + nome
    type = 'keras'
    model_filepath = os.path.join(output_folder, get_next_filename(output_folder, base_name, type))
    
    checkpoint = ModelCheckpoint(
        f'model_{nome}_fold_{fold_no}.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1,
        mode='max'
    )

# Calcula tempo
    start_time = time.time()
    
# Treinar modelo
    history = model.fit(
        X_train_fold, y_train_fold_cat,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val_fold, y_val_fold_cat),
        callbacks=[checkpoint],
        verbose=1
    )

# Calcula tempo
    end_time = time.time()

    training_time = end_time - start_time
    print(f"\nO modelo demorou {training_time:.2f} segundos para treinar.")
    
# Coletar métricas
    histories.append(history)
    predictions = model.predict(X_val_fold)
    y_pred = np.argmax(predictions, axis=1)
    metrics.append({
        'fold': fold_no,
        'report': classification_report(y_val_fold, y_pred, output_dict=True, zero_division=0),
        'matrix': confusion_matrix(y_val_fold, y_pred)
    })
    
    fold_no += 1

    del model  # Liberar memória do modelo
    tf.keras.backend.clear_session()  # Limpar sessão do TensorFlow
    gc.collect()  # Forçar coleta de lixo
# Out:
# Training Fold 1/5
# I0000 00:00:1741926915.369157   35215 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741926915.369267   35215 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741926915.369317   35215 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741926915.544851   35215 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741926915.544953   35215 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-14 01:35:15.544963: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1741926915.545047   35215 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-14 01:35:15.545072: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:10:00.0, compute capability: 8.6
# Epoch 1/100
# I0000 00:00:1741926938.849371   35274 service.cc:146] XLA service 0x7fd220002f80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741926938.849418   35274 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-03-14 01:35:39.646485: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-14 01:35:41.768637: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 2025-03-14 01:35:45.554321: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15567', 196 bytes spill stores, 196 bytes spill loads
#
# I0000 00:00:1741926969.508388   35274 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.8419 - loss: 3.7639
# 2025-03-14 01:36:48.004998: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1760', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-03-14 01:36:48.300285: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1760', 8 bytes spill stores, 8 bytes spill loads
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.8443 - loss: 3.7460 - val_accuracy: 0.5000 - val_loss: 310.8854
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 1.4700
# Epoch 2: val_accuracy improved from 0.50000 to 0.50617, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 201ms/step - accuracy: 1.0000 - loss: 1.4640 - val_accuracy: 0.5062 - val_loss: 2.2383
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.6592
# Epoch 3: val_accuracy improved from 0.50617 to 1.00000, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 204ms/step - accuracy: 1.0000 - loss: 0.6568 - val_accuracy: 1.0000 - val_loss: 0.7569
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.3296
# Epoch 4: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 155ms/step - accuracy: 1.0000 - loss: 0.3286 - val_accuracy: 1.0000 - val_loss: 0.5160
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 1.0000 - loss: 0.1843
# Epoch 5: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 244ms/step - accuracy: 1.0000 - loss: 0.1838 - val_accuracy: 1.0000 - val_loss: 0.3908
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.1102
# Epoch 6: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.1100 - val_accuracy: 1.0000 - val_loss: 0.2686
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0720
# Epoch 7: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0719 - val_accuracy: 1.0000 - val_loss: 0.1208
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0500
# Epoch 8: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0499 - val_accuracy: 1.0000 - val_loss: 0.0902
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0359
# Epoch 9: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0359 - val_accuracy: 1.0000 - val_loss: 0.0497
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 1.0000 - loss: 0.0267
# Epoch 10: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 1.0000 - val_loss: 0.0253
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0207
# Epoch 11: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0206 - val_accuracy: 1.0000 - val_loss: 0.0169
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0166
# Epoch 12: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 13: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 1.0000 - val_loss: 0.0109
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 14: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 15: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0073
# Epoch 16: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 17: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 18: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 19: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 20: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 21: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 22: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 23: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 24: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 25: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 26: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 27: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 28: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 29: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 30: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 31: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 32: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 33: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 34: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 35: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 36: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 37: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 38: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 39: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 170ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 40: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 41: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 42: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 43: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 44: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 45: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 46: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 47: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 48: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 49: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 50: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 51: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 52: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 53: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 54: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 55: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 56: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 57: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 58: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 59: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 60: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 61: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 62: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 63: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 64: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 65/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 65: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 253ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 66: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 67: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 169ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 68/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 68: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 166ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 69/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 69: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 249ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 70/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 70: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 71/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 71: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 72/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 72: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 73/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 73: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 74/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 74: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 75/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 75: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 76/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 76: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 77/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 77: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 78/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 78: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 79/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 79: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 80/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 80: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 81/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9992 - loss: 0.0182
# Epoch 81: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 0.9992 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 0.2436
# Epoch 82/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.2206
# Epoch 82: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.2195 - val_accuracy: 1.0000 - val_loss: 0.0758
# Epoch 83/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0598
# Epoch 83: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 1.0000 - loss: 0.0594 - val_accuracy: 1.0000 - val_loss: 0.0249
# Epoch 84/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0212
# Epoch 84: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0211 - val_accuracy: 1.0000 - val_loss: 0.0299
# Epoch 85/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0144
# Epoch 85: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 86/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 86: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 87/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 87: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 88/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 88: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 89/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 89: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 90/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 90: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 91/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 91: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 92/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 92: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 93/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 93: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 94/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 94: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 95/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 95: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 96/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 96: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 97/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 97: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 98/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 98: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 99/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 99: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 100/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 100: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0015
#
# O modelo demorou 810.37 segundos para treinar.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 255ms/step
#
# Training Fold 2/5
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - accuracy: 0.8895 - loss: 3.6220
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.8912 - loss: 3.6038 - val_accuracy: 0.5000 - val_loss: 80.7357
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 1.3053
# Epoch 2: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 1.0000 - loss: 1.2995 - val_accuracy: 0.5000 - val_loss: 1.6849
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.5391
# Epoch 3: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.5370 - val_accuracy: 0.5000 - val_loss: 0.8182
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.2538
# Epoch 4: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.2529 - val_accuracy: 0.5000 - val_loss: 0.5751
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.1306
# Epoch 5: val_accuracy improved from 0.50000 to 0.58333, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 220ms/step - accuracy: 1.0000 - loss: 0.1303 - val_accuracy: 0.5833 - val_loss: 0.4656
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0733
# Epoch 6: val_accuracy improved from 0.58333 to 0.87963, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 215ms/step - accuracy: 1.0000 - loss: 0.0731 - val_accuracy: 0.8796 - val_loss: 0.2897
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0442
# Epoch 7: val_accuracy improved from 0.87963 to 1.00000, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 13s 307ms/step - accuracy: 1.0000 - loss: 0.0441 - val_accuracy: 1.0000 - val_loss: 0.0614
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0283
# Epoch 8: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 157ms/step - accuracy: 1.0000 - loss: 0.0283 - val_accuracy: 1.0000 - val_loss: 0.0220
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0197
# Epoch 9: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0197 - val_accuracy: 1.0000 - val_loss: 0.0168
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0145
# Epoch 10: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0108
# Epoch 11: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 12: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 13: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 14: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 15: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0047
# Epoch 16: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 17: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 18: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9597 - loss: 0.1904
# Epoch 19: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.9599 - loss: 0.1906 - val_accuracy: 0.5000 - val_loss: 488606272.0000
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0666
# Epoch 20: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0663 - val_accuracy: 0.5000 - val_loss: 54476.2578
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0257
# Epoch 21: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0256 - val_accuracy: 0.5000 - val_loss: 1962.8530
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 1.0000 - loss: 0.0348
# Epoch 22: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0347 - val_accuracy: 0.5000 - val_loss: 45.6529
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0160
# Epoch 23: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0160 - val_accuracy: 0.6235 - val_loss: 0.7025
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0108
# Epoch 24: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.8272 - val_loss: 0.2729
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 25: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.9907 - val_loss: 0.2423
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9239 - loss: 0.2165
# Epoch 26: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.9218 - loss: 0.2222 - val_accuracy: 0.5000 - val_loss: 72138.2109
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 1.0000 - loss: 0.2103
# Epoch 27: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.2091 - val_accuracy: 0.5000 - val_loss: 536.9849
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0736
# Epoch 28: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0733 - val_accuracy: 0.5617 - val_loss: 0.8459
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9989 - loss: 0.0597
# Epoch 29: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 0.9989 - loss: 0.0596 - val_accuracy: 1.0000 - val_loss: 0.1413
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0314
# Epoch 30: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0313 - val_accuracy: 1.0000 - val_loss: 0.1197
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0215
# Epoch 31: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 0.0868
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0174
# Epoch 32: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 1.0000 - val_loss: 0.0650
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0146
# Epoch 33: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 1.0000 - val_loss: 0.0536
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 34: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 1.0000 - val_loss: 0.0466
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 35: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 0.0416
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 36: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 0.0392
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 37: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 0.0324
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 38: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0342
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 39: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0335
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 40: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 0.0366
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 41: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0356
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 42: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 0.0362
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 43: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 0.0307
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 44: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 0.0256
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 45: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 0.0208
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0096
# Epoch 46: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0248
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 47: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 0.0222
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 48: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 0.0207
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 49: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0214
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 50: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0196
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 51: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0187
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 52: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0199
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 53: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0210
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 54: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0191
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 55: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0168
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 56: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0173
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 57: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0159
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0047
# Epoch 58: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0170
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 59: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0286
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 60: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0235
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 61: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0194
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 62: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0189
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 63: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0175
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 64: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0154
# Epoch 65/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 65: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0158
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 66: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0142
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 67: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0150
# Epoch 68/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 68: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 69/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 69: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0124
# Epoch 70/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 70: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 71/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 71: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0145
# Epoch 72/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 72: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 73/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 73: val_accuracy did not improve from 1.00000
# ...
# Epoch 39: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 40: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 41: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 42: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 43: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 1.0000 - loss: 0.0073
# Epoch 44: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 250ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 45: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 46: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 47: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 48: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 49: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 250ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 50: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 51: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 52: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 53: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 54: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 55: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 56: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 57: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 58: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 59: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 60: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 61: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 62: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 63: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 64: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 65/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 65: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 66: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 67: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 68/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 68: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 69/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 69: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 70/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 70: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 71/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 71: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 72/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 72: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 73/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 73: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 74/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 74: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 255ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0123
# Epoch 75/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9837 - loss: 0.1256
# Epoch 75: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.9835 - loss: 0.1292 - val_accuracy: 0.5000 - val_loss: 4953375.5000
# Epoch 76/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9997 - loss: 0.3516
# Epoch 76: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 0.9997 - loss: 0.3507 - val_accuracy: 0.9969 - val_loss: 0.2910
# Epoch 77/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.1994
# Epoch 77: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 1.0000 - loss: 0.1989 - val_accuracy: 1.0000 - val_loss: 0.1362
# Epoch 78/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.1243
# Epoch 78: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.1240 - val_accuracy: 1.0000 - val_loss: 0.0931
# Epoch 79/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 1.0000 - loss: 0.0854
# Epoch 79: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 1.0000 - loss: 0.0852 - val_accuracy: 1.0000 - val_loss: 0.0751
# Epoch 80/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9994 - loss: 0.0633
# Epoch 80: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.9994 - loss: 0.0632 - val_accuracy: 0.9969 - val_loss: 0.1119
# Epoch 81/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0479
# Epoch 81: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0478 - val_accuracy: 0.9877 - val_loss: 0.1968
# Epoch 82/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0381
# Epoch 82: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0381 - val_accuracy: 1.0000 - val_loss: 0.0358
# Epoch 83/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0304
# Epoch 83: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 0.0335
# Epoch 84/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 1.0000 - loss: 0.0249
# Epoch 84: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 251ms/step - accuracy: 1.0000 - loss: 0.0249 - val_accuracy: 1.0000 - val_loss: 0.0259
# Epoch 85/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0209
# Epoch 85: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0209 - val_accuracy: 1.0000 - val_loss: 0.0239
# Epoch 86/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0179
# Epoch 86: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0179 - val_accuracy: 1.0000 - val_loss: 0.0362
# Epoch 87/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0157
# Epoch 87: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 1.0000 - val_loss: 0.0148
# Epoch 88/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0169
# Epoch 88: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 1.0000 - val_loss: 0.0142
# Epoch 89/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 89: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 90/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 90: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 0.0125
# Epoch 91/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0104
# Epoch 91: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 92/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 92: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 93/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 93: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 94/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 94: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 95/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 95: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 96/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0147
# Epoch 96: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.5494 - val_loss: 0.4382
# Epoch 97/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0144
# Epoch 97: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 0.0120
# Epoch 98/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0090
# Epoch 98: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0105
# Epoch 99/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 99: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9969 - val_loss: 0.0125
# Epoch 100/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 100: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.5000 - val_loss: 273.3755
#
# O modelo demorou 790.20 segundos para treinar.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 243ms/step
#
# Training Fold 4/5
# Epoch 1/100

# %%
print('\n\nCross-Validation Results:')
for metric in metrics:
    print(f'\nFold {metric["fold"]}:')
    print(classification_report(y_val_fold, y_pred, target_names=cm_plot_labels))

# Treinar modelo final com todos os dados de treino
final_model = model_resnet50()
final_model.fit(
    np.expand_dims(all_train_specs, axis=-1),
    to_categorical(all_train_labels, 2),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    verbose=1
)

# Avaliar no teste final
test_loss, test_acc = final_model.evaluate(
    np.expand_dims(X_test, axis=-1),
    to_categorical(y_test, 2),
    verbose=0
)
print(f'\nFinal Test Accuracy: {test_acc:.4f}')

# Gerar gráficos finais (substituir)
y_pred_test = np.argmax(final_model.predict(np.expand_dims(X_test, axis=-1)), axis=1)
plot_and_save_report(y_test, y_pred_test)
plot_and_matrix(y_test, y_pred_test, cm_plot_labels)

cm_plot_labels = ['Normal', 'Hacked']

# %%
# GC collect
tf.keras.backend.clear_session()
gc.collect()
