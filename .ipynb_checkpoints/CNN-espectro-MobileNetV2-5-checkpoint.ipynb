# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from skimage.metrics import structural_similarity as ssim
from sklearn import preprocessing
from keras.utils import to_categorical
from keras import regularizers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.layers import Input, Dense, Dropout, Lambda, GlobalAveragePooling2D
from keras.src.legacy.preprocessing.image import ImageDataGenerator

import random
import re
import glob
from tqdm import tqdm
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
import gc
# Out:
# 2025-03-14 14:47:24.843847: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-14 14:47:24.963134: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-14 14:47:24.994682: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-14 14:47:25.752124: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
policy = tf.keras.mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy)

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)
else:
    print("Nenhuma GPU encontrada.")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741974460.642553   12255 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741974462.381988   12255 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741974462.382078   12255 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# nome = 'PACS'
nome = 'Yildirim'
#nome = 'Todos'

imgs_path = 'Bases/Dataset' + nome

TEST_SIZE = 0.1
VALIDATION_SIZE = 0.1

SIMILARITY = 0.75

EPOCHS = 100
BATCH_SIZE = 32

HIGH_FREQ_THRESHOLD = 12

# %%
def get_next_filename(output_folder, base_name, type):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    image_index = 0
    
    while True:
        output_filename = f"{base_name}_{image_index}.{type}"
        output_path = os.path.join(output_folder, output_filename)
        
        if not os.path.exists(output_path):
            return output_filename
            
        image_index += 1

# %%
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else 0

# %%
def sort_files_numerically(file_paths):
    return sorted(file_paths, key=lambda x: extract_number(x))

# %%
def find_groups(images, image_paths, test_size, similarity_threshold):
    def are_similar(img1, img2, threshold):
        similarity = ssim(img1, img2)
        return similarity >= threshold

    groups = []
    current_group = [image_paths[0]]

    for i in range(1, len(images)):
        if are_similar(images[i-1], images[i], similarity_threshold):
            current_group.append(image_paths[i])
        else:
            groups.append(current_group)
            current_group = [image_paths[i]]
    
    if current_group:
        groups.append(current_group)

    all_images = [img_path for group in groups for img_path in group]

    for img_path in image_paths:
        if img_path not in all_images:
            groups.append([img_path])

    random.shuffle(groups)

    train_set = []
    test_set = []
    current_test_size = 0
    
    for i, group in enumerate(groups):
        if current_test_size + len(group) <= test_size:
            test_set.extend(group)
            current_test_size += len(group)
        else:
            train_set.extend(group)

    return train_set, test_set

# %%
output_folder = 'Groups'
type = 'txt'

def save_groups(train_groups, test_groups, base_name):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    output_filename = get_next_filename(output_folder, base_name, type)
    output_path = os.path.join(output_folder, output_filename)

    with open(output_path, 'w') as file:
        file.write('- test:\n')
        for idx, group in enumerate(test_groups, start=1):
            for img in group:
                file.write(f"{img}\n")
        
        file.write('- train:\n')
        for idx, group in enumerate(train_groups, start=1):
            for img in group:
                file.write(f'{img}\n')
    
    print(f'Group information saved in {output_path}')

# %%
def read_dataset(path, jpg, png):
    print(f'Reading dataset...\n')
    
    img_type = []
    images = []
    image_paths = []

    if jpg:
        img_type.append('*.jpg')
    if png:
        img_type.append('*.png')

# Normal

    normal_path = os.path.join(path, 'Train', 'Normal')
    print(f'Reading Normal images from: {normal_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(normal_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# Kidney

    kidney_stone_path = os.path.join(path, 'Train', 'Kidney_stone')
    print(f'Reading Kidney_stone images from: {kidney_stone_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(kidney_stone_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# ...
    
    images = np.array(images)
    image_paths = np.array(image_paths)

    return images, image_paths

# %%
all_X, all_image_paths = read_dataset(path=imgs_path, jpg=True, png=True)
# Out:
# Reading dataset...
#
# Reading Normal images from: Bases/DatasetYildirim/Train/Normal
# Reading Kidney_stone images from: Bases/DatasetYildirim/Train/Kidney_stone

# %%
def freq_spec(image, threshold, add_noise):
    f = np.fft.fft2(image)
    fshift = np.fft.fftshift(f)

    if add_noise:
        amplification_factor = 0.5
        
        rows, cols = image.shape
        crow, ccol = rows//2, cols//2

        mask = np.zeros((rows, cols), dtype=bool)
        mask[crow-threshold:crow+threshold, ccol-threshold:ccol+threshold] = True
        high_freq_mask = ~mask

        fshift[high_freq_mask] *= amplification_factor

    magnitude_spectrum_high = 20 * np.log(np.abs(fshift) + 1)

    return magnitude_spectrum_high

# %%
def save_specs(images, threshold, add_noise):
    specs = []
    for img in images:
        specs.append(freq_spec(img, threshold, add_noise))
    return specs

# %%
# Processar todas as imagens e criar labels
all_specs = []
all_labels = []

# Processar metade normal e metade hackeada
half = len(all_X) // 2
for i, img in enumerate(all_X):
    if i < half:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=False))
        all_labels.append(0)
    else:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=True))
        all_labels.append(1)

all_specs = np.array(all_specs)
all_labels = np.array(all_labels)

# %%
#len_normal_specs = int(len(all_X) / 2)

# %%
#normal_specs = all_X[0:len_normal_specs]

# %%
#normal_specs = save_specs(normal_specs, 100 - HIGH_FREQ_THRESHOLD, add_noise = False)

# %%
#print(len(normal_specs))

# %%
#hacked_specs = all_X[len_normal_specs:len(all_X)]

# %%
#hacked_specs = save_specs(hacked_specs, 100 - HIGH_FREQ_THRESHOLD, add_noise = True)

# %%
#print(len(hacked_specs))

# %%
print("Quantidade das imagens:", all_specs.shape)
print("Exemplo dos labels (False = original, True = com ruído):", all_labels)
# Out:
# Quantidade das imagens: (1799, 224, 224)
# Exemplo dos labels (False = original, True = com ruído): [0 0 0 ... 1 1 1]

# %%
X_train, X_test, y_train, y_test, paths_train, paths_test = train_test_split(
        all_specs, all_labels, all_image_paths,
        test_size=TEST_SIZE, 
        stratify=all_labels,
#       random_state=53
    )

# %%
def plot_specs(specs, title):
    total_images = len(specs)
    imgs_per_figure = 100
    cols = 5
    rows = (imgs_per_figure + cols - 1) // cols

    for start in range(0, total_images, imgs_per_figure):
        plt.figure(figsize=(cols * 3, rows * 3))
        end = min(start + imgs_per_figure, total_images)
        
        for i in range(start, end):
            plt.subplot(rows, cols, i - start + 1)
            plt.imshow(specs[i], cmap='gray')
            plt.title(f"{title} - freq spec: img {i+1}")
            plt.axis('off')
            
        plt.tight_layout()
        plt.show()

# %%
# Plotar todos os espectros de teste
#plot_specs(X_test, title="test")

# %%
#pausa de teste

# %%
# Defines the model layers (now for ResNet50)
def model_mobilenetv2():
    inputs = Input(shape=(224, 224, 1))
    
    # 1. Conversão para 3 canais (igual ao anterior)
    x = Lambda(lambda x: tf.repeat(x, 3, axis=-1))(inputs)
    
    # 2. Pré-processamento específico do MobileNetV2
    x = tf.keras.applications.mobilenet_v2.preprocess_input(x)
    
    # 3. Carregar MobileNetV2
    base_model = tf.keras.applications.MobileNetV2(
        weights='imagenet',
        include_top=False,
        input_tensor=x,
        alpha=1.0  # Controla a largura da rede (1.0 = 224x224)
    )
    
    # 4. Topo personalizado (ajustar camadas se necessário)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    
    # Reduzir unidades para melhor compatibilidade
    x = Dense(128, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.3)(x)
    
    x = Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.3)(x)
    
    outputs = Dense(2, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
# Configurar K-Fold
kfold = StratifiedKFold(n_splits=5, shuffle=True)
#kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=53)
fold_no = 1
histories = []
metrics = []

for train_idx, val_idx in kfold.split(X_train, y_train):
    print(f'\nTraining Fold {fold_no}/5')
    
# Split dos dados
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]
    
# Pré-processamento final
    X_train_fold = np.expand_dims(X_train_fold, axis=-1)
    X_val_fold = np.expand_dims(X_val_fold, axis=-1)
    y_train_fold_cat = to_categorical(y_train_fold, 2)
    y_val_fold_cat = to_categorical(y_val_fold, 2)

# Criar novo modelo para cada fold
    model = model_mobilenetv2()

# Checkpoint com nome do fold
    output_folder = 'Models_saves'
    base_name = 'model_' + nome
    type = 'keras'
    model_filepath = os.path.join(output_folder, get_next_filename(output_folder, base_name, type))
    
    checkpoint = ModelCheckpoint(
        f'model_{nome}_fold_{fold_no}.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1,
        mode='max'
    )

# Calcula tempo
    start_time = time.time()
    
# Treinar modelo
    history = model.fit(
        X_train_fold, y_train_fold_cat,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val_fold, y_val_fold_cat),
        callbacks=[checkpoint],
        verbose=1
    )

# Calcula tempo
    end_time = time.time()

    training_time = end_time - start_time
    print(f"\nO modelo demorou {training_time:.2f} segundos para treinar.")
    
# Coletar métricas
    histories.append(history)
    predictions = model.predict(X_val_fold)
    y_pred = np.argmax(predictions, axis=1)
    metrics.append({
        'fold': fold_no,
        'report': classification_report(y_val_fold, y_pred, output_dict=True, zero_division=0),
        'matrix': confusion_matrix(y_val_fold, y_pred)
    })
    
    fold_no += 1

    del model  # Liberar memória do modelo
    tf.keras.backend.clear_session()  # Limpar sessão do TensorFlow
    gc.collect()  # Forçar coleta de lixo
# Out:
# Training Fold 1/5
# /tmp/ipykernel_12255/1359235689.py:12: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(
# I0000 00:00:1741974531.934824   12255 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741974531.934960   12255 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741974531.935034   12255 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741974532.254494   12255 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1741974532.254620   12255 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-14 14:48:52.254635: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1741974532.254773   12255 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-14 14:48:52.254843: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:10:00.0, compute capability: 8.6
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/100
# I0000 00:00:1741974556.329199   12327 service.cc:146] XLA service 0x7f1854016da0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741974556.329273   12327 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-03-14 14:49:16.925581: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-14 14:49:19.464955: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# I0000 00:00:1741974589.109818   12327 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 674ms/step - accuracy: 0.7096 - loss: 3.7535
# Epoch 1: val_accuracy improved from -inf to 0.72840, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 91s 987ms/step - accuracy: 0.7127 - loss: 3.7478 - val_accuracy: 0.7284 - val_loss: 3.6456
# Epoch 2/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9967 - loss: 3.0834
# Epoch 2: val_accuracy did not improve from 0.72840
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9967 - loss: 3.0813 - val_accuracy: 0.6574 - val_loss: 3.4368
# Epoch 3/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9991 - loss: 2.9093
# Epoch 3: val_accuracy improved from 0.72840 to 0.73148, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9991 - loss: 2.9073 - val_accuracy: 0.7315 - val_loss: 3.2135
# Epoch 4/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 2.7378
# Epoch 4: val_accuracy improved from 0.73148 to 0.95988, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 1.0000 - loss: 2.7358 - val_accuracy: 0.9599 - val_loss: 2.9007
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9994 - loss: 2.5620
# Epoch 5: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9994 - loss: 2.5610 - val_accuracy: 0.7222 - val_loss: 2.8680
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 2.3843
# Epoch 6: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 2.3833 - val_accuracy: 0.7407 - val_loss: 2.6748
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 2.2120
# Epoch 7: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 2.2111 - val_accuracy: 0.9228 - val_loss: 2.4374
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 2.0447
# Epoch 8: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 2.0438 - val_accuracy: 0.7623 - val_loss: 2.3484
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.8853
# Epoch 9: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 1.8844 - val_accuracy: 0.6420 - val_loss: 2.2809
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.7357
# Epoch 10: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 1.7349 - val_accuracy: 0.6821 - val_loss: 2.0983
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.5912
# Epoch 11: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 1.5905 - val_accuracy: 0.7685 - val_loss: 1.9192
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.4580
# Epoch 12: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9999 - loss: 1.4574 - val_accuracy: 0.7315 - val_loss: 1.8143
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.3364
# Epoch 13: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 1.3358 - val_accuracy: 0.8333 - val_loss: 1.6490
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.2202
# Epoch 14: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 1.0000 - loss: 1.2196 - val_accuracy: 0.8858 - val_loss: 1.5235
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.1135
# Epoch 15: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 1.1129 - val_accuracy: 0.7315 - val_loss: 1.4995
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.0132
# Epoch 16: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 1.0126 - val_accuracy: 0.7284 - val_loss: 1.4061
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.9215
# Epoch 17: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.9210 - val_accuracy: 0.8704 - val_loss: 1.2645
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9993 - loss: 0.8411
# Epoch 18: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9993 - loss: 0.8407 - val_accuracy: 0.5000 - val_loss: 2.5133
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9989 - loss: 0.7678
# Epoch 19: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9989 - loss: 0.7675 - val_accuracy: 0.5000 - val_loss: 3.6047
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9975 - loss: 0.6993
# Epoch 20: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9975 - loss: 0.6989 - val_accuracy: 0.5000 - val_loss: 1.9001
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.6324
# Epoch 21: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.6321 - val_accuracy: 0.5617 - val_loss: 1.2722
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.5757
# Epoch 22: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9999 - loss: 0.5755 - val_accuracy: 0.5926 - val_loss: 1.1433
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.5259
# Epoch 23: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.5256 - val_accuracy: 0.8889 - val_loss: 0.8653
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.4793
# Epoch 24: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.4790 - val_accuracy: 0.7006 - val_loss: 0.9326
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.4356
# Epoch 25: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.4354 - val_accuracy: 0.8241 - val_loss: 0.8123
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9983 - loss: 0.4014
# Epoch 26: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9983 - loss: 0.4012 - val_accuracy: 0.5000 - val_loss: 1.4307
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.3657
# Epoch 27: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.3654 - val_accuracy: 0.5000 - val_loss: 1.4057
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.3310
# Epoch 28: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.3308 - val_accuracy: 0.5000 - val_loss: 1.3072
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9998 - loss: 0.3021
# Epoch 29: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9998 - loss: 0.3020 - val_accuracy: 0.5000 - val_loss: 1.2238
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.2769
# Epoch 30: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.2768 - val_accuracy: 0.5062 - val_loss: 1.1624
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.2519
# Epoch 31: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.2517 - val_accuracy: 0.5154 - val_loss: 1.0879
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.2303
# Epoch 32: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.2301 - val_accuracy: 0.5216 - val_loss: 1.0254
# Epoch 33/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.2111
# Epoch 33: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 1.0000 - loss: 0.2109 - val_accuracy: 0.5247 - val_loss: 0.9820
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.1929
# Epoch 34: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.1928 - val_accuracy: 0.5494 - val_loss: 0.9006
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.1765
# Epoch 35: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.1764 - val_accuracy: 0.5370 - val_loss: 0.8922
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.1615
# Epoch 36: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.1614 - val_accuracy: 0.5617 - val_loss: 0.8194
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.1484
# Epoch 37: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.1483 - val_accuracy: 0.5648 - val_loss: 0.8058
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.1358
# Epoch 38: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.1358 - val_accuracy: 0.5679 - val_loss: 0.7979
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.1246
# Epoch 39: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.1246 - val_accuracy: 0.5586 - val_loss: 0.7850
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.1145
# Epoch 40: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.1145 - val_accuracy: 0.5401 - val_loss: 0.8140
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.1049
# Epoch 41: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.1048 - val_accuracy: 0.5463 - val_loss: 0.7656
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0968
# Epoch 42: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.0968 - val_accuracy: 0.5586 - val_loss: 0.7265
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0889
# Epoch 43: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0889 - val_accuracy: 0.5772 - val_loss: 0.6659
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0821
# Epoch 44: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0821 - val_accuracy: 0.5926 - val_loss: 0.6361
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0769
# Epoch 45: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.0768 - val_accuracy: 0.6204 - val_loss: 0.6156
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0696
# Epoch 46: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0695 - val_accuracy: 0.6235 - val_loss: 0.6015
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0647
# Epoch 47: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.0647 - val_accuracy: 0.6235 - val_loss: 0.6007
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0596
# Epoch 48: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.0596 - val_accuracy: 0.6451 - val_loss: 0.5794
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0550
# Epoch 49: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0549 - val_accuracy: 0.6667 - val_loss: 0.5544
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9967 - loss: 0.0548
# Epoch 50: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9968 - loss: 0.0547 - val_accuracy: 0.7593 - val_loss: 0.4766
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0475
# Epoch 51: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 1.0000 - loss: 0.0475 - val_accuracy: 0.7253 - val_loss: 0.5039
# Epoch 52/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0439
# Epoch 52: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 1.0000 - loss: 0.0439 - val_accuracy: 0.7346 - val_loss: 0.4959
# Epoch 53/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0419
# Epoch 53: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0419 - val_accuracy: 0.7531 - val_loss: 0.4778
# Epoch 54/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0382
# Epoch 54: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 1.0000 - loss: 0.0381 - val_accuracy: 0.7840 - val_loss: 0.4407
# Epoch 55/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0363
# Epoch 55: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 1.0000 - loss: 0.0363 - val_accuracy: 0.6883 - val_loss: 0.5481
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0337
# Epoch 56: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0337 - val_accuracy: 0.7531 - val_loss: 0.4589
# Epoch 57/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0308
# Epoch 57: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 1.0000 - loss: 0.0308 - val_accuracy: 0.7716 - val_loss: 0.4302
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0288
# Epoch 58: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 0.7963 - val_loss: 0.3846
# Epoch 59/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0267
# Epoch 59: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 1.0000 - loss: 0.0266 - val_accuracy: 0.8426 - val_loss: 0.3541
# Epoch 60/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0250
# Epoch 60: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 1.0000 - loss: 0.0250 - val_accuracy: 0.8549 - val_loss: 0.3401
# Epoch 61/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0234
# Epoch 61: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 1.0000 - loss: 0.0234 - val_accuracy: 0.8796 - val_loss: 0.3256
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0220
# Epoch 62: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 1.0000 - loss: 0.0220 - val_accuracy: 0.9012 - val_loss: 0.2819
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0208
# Epoch 63: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 1.0000 - loss: 0.0208 - val_accuracy: 0.8951 - val_loss: 0.2805
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0197
# Epoch 64: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 0.9228 - val_loss: 0.2634
# Epoch 65/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0187
# Epoch 65: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 0.9414 - val_loss: 0.2473
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0175
# Epoch 66: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 1.0000 - loss: 0.0175 - val_accuracy: 0.9383 - val_loss: 0.2412
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0161
# Epoch 67: val_accuracy did not improve from 0.95988
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 1.0000 - loss: 0.0161 - val_accuracy: 0.9568 - val_loss: 0.2235
# Epoch 68/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9991 - loss: 0.0195
# Epoch 68: val_accuracy improved from 0.95988 to 1.00000, saving model to model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9991 - loss: 0.0195 - val_accuracy: 1.0000 - val_loss: 0.0495
# Epoch 69/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0170
# Epoch 69: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0170 - val_accuracy: 1.0000 - val_loss: 0.0647
# Epoch 70/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0154
# Epoch 70: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 1.0000 - val_loss: 0.0617
# Epoch 71/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0143
# Epoch 71: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 0.0534
# Epoch 72/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0137
# Epoch 72: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 1.0000 - val_loss: 0.0479
# Epoch 73/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0130
# Epoch 73: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 0.0456
# Epoch 74/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0120
# Epoch 74: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 0.0416
# Epoch 75/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 75: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 0.0365
# Epoch 76/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0110
# Epoch 76: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 1.0000 - val_loss: 0.0319
# Epoch 77/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 77: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 0.0267
# Epoch 78/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 78: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 0.0258
# Epoch 79/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 79: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0235
# Epoch 80/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0093
# Epoch 80: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 1.0000 - val_loss: 0.0234
# Epoch 81/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 81: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0205
# Epoch 82/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 82: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 1.0000 - val_loss: 0.0205
# Epoch 83/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 83: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0189
# Epoch 84/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 84: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0183
# Epoch 85/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 85: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0177
# Epoch 86/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 86: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 0.0165
# Epoch 87/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 87: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 0.0156
# Epoch 88/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 88: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 0.0142
# Epoch 89/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 89: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 0.0139
# Epoch 90/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 90: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 0.0123
# Epoch 91/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 91: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0119
# Epoch 92/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 92: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 93/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 93: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0095
# Epoch 94/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 94: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 95/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 95: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 96/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 96: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 97/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 97: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 98/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 98: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 99/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 99: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 100/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 100: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0060
#
# O modelo demorou 293.48 segundos para treinar.
# 2025-03-14 14:53:52.274238: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1335', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-03-14 14:53:52.541616: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1328', 164 bytes spill stores, 164 bytes spill loads
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 246ms/step
#
# Training Fold 2/5
# /tmp/ipykernel_12255/1359235689.py:12: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(
# Epoch 1/100
# 2025-03-14 14:54:18.720411: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_8073', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-03-14 14:54:18.844651: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15109', 36 bytes spill stores, 40 bytes spill loads
#
# 2025-03-14 14:54:19.001204: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_8073', 148 bytes spill stores, 148 bytes spill loads
#
# 2025-03-14 14:54:19.011530: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15109', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-03-14 14:54:32.628833: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=0} for conv (f32[192,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,28,28]{3,2,1,0}, f32[32,192,28,28]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=192, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-03-14 14:54:32.997346: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.952585901s
# Trying algorithm eng18{k11=0} for conv (f32[192,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,28,28]{3,2,1,0}, f32[32,192,28,28]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=192, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7375 - loss: 3.6851
# 2025-03-14 14:54:47.979963: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_8073', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-03-14 14:55:03.960874: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_divide_multiply_subtract_fusion_29', 8 bytes spill stores, 8 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_divide_multiply_subtract_fusion_8', 8 bytes spill stores, 8 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_divide_multiply_subtract_fusion_7', 8 bytes spill stores, 8 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_divide_multiply_subtract_fusion', 8 bytes spill stores, 8 bytes spill loads
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.7407 - loss: 3.6790
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 75s 873ms/step - accuracy: 0.7437 - loss: 3.6732 - val_accuracy: 0.5000 - val_loss: 5.7801
# Epoch 2/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9995 - loss: 3.0439
# Epoch 2: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9995 - loss: 3.0417 - val_accuracy: 0.5000 - val_loss: 6.8673
# Epoch 3/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9991 - loss: 2.8621
# Epoch 3: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9991 - loss: 2.8600 - val_accuracy: 0.5000 - val_loss: 6.0752
# Epoch 4/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9984 - loss: 2.6751
# Epoch 4: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9984 - loss: 2.6729 - val_accuracy: 0.5000 - val_loss: 5.5342
# Epoch 5/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 2.4870
# Epoch 5: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 2.4848 - val_accuracy: 0.5000 - val_loss: 5.5691
# Epoch 6/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 2.3006
# Epoch 6: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 2.2985 - val_accuracy: 0.5000 - val_loss: 5.3733
# Epoch 7/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 2.1218
# Epoch 7: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 1.0000 - loss: 2.1198 - val_accuracy: 0.5000 - val_loss: 4.7655
# Epoch 8/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9992 - loss: 1.9521
# Epoch 8: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9992 - loss: 1.9502 - val_accuracy: 0.5000 - val_loss: 4.7187
# Epoch 9/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9974 - loss: 1.7939
# Epoch 9: val_accuracy improved from 0.50000 to 0.50309, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9975 - loss: 1.7920 - val_accuracy: 0.5031 - val_loss: 2.7760
# Epoch 10/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 1.6371
# Epoch 10: val_accuracy improved from 0.50309 to 0.50617, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 1.0000 - loss: 1.6354 - val_accuracy: 0.5062 - val_loss: 2.4926
# Epoch 11/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 1.4967
# Epoch 11: val_accuracy improved from 0.50617 to 0.55247, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - accuracy: 1.0000 - loss: 1.4951 - val_accuracy: 0.5525 - val_loss: 2.0775
# Epoch 12/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 1.3646
# Epoch 12: val_accuracy improved from 0.55247 to 0.61728, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 1.0000 - loss: 1.3631 - val_accuracy: 0.6173 - val_loss: 1.8082
# Epoch 13/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 1.2416
# Epoch 13: val_accuracy improved from 0.61728 to 0.68827, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 1.0000 - loss: 1.2402 - val_accuracy: 0.6883 - val_loss: 1.6450
# Epoch 14/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 1.1285
# Epoch 14: val_accuracy improved from 0.68827 to 0.73765, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 1.0000 - loss: 1.1273 - val_accuracy: 0.7377 - val_loss: 1.5146
# Epoch 15/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 1.0246
# Epoch 15: val_accuracy did not improve from 0.73765
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 1.0235 - val_accuracy: 0.5833 - val_loss: 1.5337
# Epoch 16/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.9296
# Epoch 16: val_accuracy did not improve from 0.73765
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.9286 - val_accuracy: 0.6296 - val_loss: 1.4123
# Epoch 17/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.8429
# Epoch 17: val_accuracy did not improve from 0.73765
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.8420 - val_accuracy: 0.5741 - val_loss: 1.3801
# Epoch 18/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.7645
# Epoch 18: val_accuracy did not improve from 0.73765
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.7636 - val_accuracy: 0.5154 - val_loss: 1.4713
# Epoch 19/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.6919
# Epoch 19: val_accuracy did not improve from 0.73765
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.6911 - val_accuracy: 0.6142 - val_loss: 1.2160
# Epoch 20/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.6272
# Epoch 20: val_accuracy did not improve from 0.73765
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.6265 - val_accuracy: 0.6049 - val_loss: 1.1541
# Epoch 21/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.5672
# Epoch 21: val_accuracy did not improve from 0.73765
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.5666 - val_accuracy: 0.7068 - val_loss: 1.0135
# Epoch 22/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.5141
# Epoch 22: val_accuracy improved from 0.73765 to 0.74383, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.5135 - val_accuracy: 0.7438 - val_loss: 0.9414
# Epoch 23/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9991 - loss: 0.4664
# Epoch 23: val_accuracy did not improve from 0.74383
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9991 - loss: 0.4658 - val_accuracy: 0.5309 - val_loss: 1.1042
# Epoch 24/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.4213
# Epoch 24: val_accuracy did not improve from 0.74383
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.4208 - val_accuracy: 0.6080 - val_loss: 0.9639
# Epoch 25/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.3818
# Epoch 25: val_accuracy did not improve from 0.74383
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.3814 - val_accuracy: 0.7160 - val_loss: 0.8438
# Epoch 26/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.3459
# Epoch 26: val_accuracy did not improve from 0.74383
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 1.0000 - loss: 0.3455 - val_accuracy: 0.6759 - val_loss: 0.8212
# Epoch 27/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.3146
# Epoch 27: val_accuracy did not improve from 0.74383
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.3143 - val_accuracy: 0.6080 - val_loss: 0.8744
# Epoch 28/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.2861
# Epoch 28: val_accuracy did not improve from 0.74383
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.2858 - val_accuracy: 0.6420 - val_loss: 0.7994
# Epoch 29/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.2589
# Epoch 29: val_accuracy did not improve from 0.74383
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.2586 - val_accuracy: 0.6389 - val_loss: 0.7826
# Epoch 30/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.2353
# Epoch 30: val_accuracy did not improve from 0.74383
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.2351 - val_accuracy: 0.6111 - val_loss: 0.8276
# Epoch 31/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.2136
# Epoch 31: val_accuracy did not improve from 0.74383
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.2134 - val_accuracy: 0.6111 - val_loss: 0.7930
# Epoch 32/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1953
# Epoch 32: val_accuracy did not improve from 0.74383
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 1.0000 - loss: 0.1951 - val_accuracy: 0.7284 - val_loss: 0.6494
# Epoch 33/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9967 - loss: 0.1860
# Epoch 33: val_accuracy did not improve from 0.74383
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9968 - loss: 0.1855 - val_accuracy: 0.5463 - val_loss: 0.8444
# Epoch 34/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.1624
# Epoch 34: val_accuracy did not improve from 0.74383
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.1622 - val_accuracy: 0.6358 - val_loss: 0.6898
# Epoch 35/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1484
# Epoch 35: val_accuracy did not improve from 0.74383
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 1.0000 - loss: 0.1483 - val_accuracy: 0.6728 - val_loss: 0.6340
# Epoch 36/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1361
# Epoch 36: val_accuracy improved from 0.74383 to 0.78395, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 1.0000 - loss: 0.1359 - val_accuracy: 0.7840 - val_loss: 0.5595
# Epoch 37/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1245
# Epoch 37: val_accuracy improved from 0.78395 to 0.95679, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.1244 - val_accuracy: 0.9568 - val_loss: 0.4614
# Epoch 38/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1139
# Epoch 38: val_accuracy improved from 0.95679 to 0.97531, saving model to model_Yildirim_fold_2.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 1.0000 - loss: 0.1138 - val_accuracy: 0.9753 - val_loss: 0.4241
# Epoch 39/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1041
# Epoch 39: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.1040 - val_accuracy: 0.9660 - val_loss: 0.3873
# Epoch 40/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0955
# Epoch 40: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0954 - val_accuracy: 0.9691 - val_loss: 0.3577
# Epoch 41/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0882
# Epoch 41: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0881 - val_accuracy: 0.9722 - val_loss: 0.3154
# Epoch 42/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0813
# Epoch 42: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0813 - val_accuracy: 0.9660 - val_loss: 0.3023
# Epoch 43/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0745
# Epoch 43: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0744 - val_accuracy: 0.9660 - val_loss: 0.2857
# Epoch 44/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0685
# Epoch 44: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0684 - val_accuracy: 0.9630 - val_loss: 0.2761
# Epoch 45/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0632
# Epoch 45: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0632 - val_accuracy: 0.9722 - val_loss: 0.2425
# Epoch 46/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0585
# Epoch 46: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - accuracy: 1.0000 - loss: 0.0585 - val_accuracy: 0.9691 - val_loss: 0.2267
# Epoch 47/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0540
# Epoch 47: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 1.0000 - loss: 0.0540 - val_accuracy: 0.9599 - val_loss: 0.2149
# Epoch 48/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0498
# Epoch 48: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0498 - val_accuracy: 0.9568 - val_loss: 0.2134
# Epoch 49/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0463
# Epoch 49: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0463 - val_accuracy: 0.9568 - val_loss: 0.2003
# Epoch 50/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0425
# Epoch 50: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0425 - val_accuracy: 0.9568 - val_loss: 0.1883
# Epoch 51/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0398
# Epoch 51: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0398 - val_accuracy: 0.9599 - val_loss: 0.1663
# Epoch 52/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0371
# Epoch 52: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0371 - val_accuracy: 0.9691 - val_loss: 0.1434
# Epoch 53/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0341
# Epoch 53: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0340 - val_accuracy: 0.9630 - val_loss: 0.1492
# Epoch 54/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0317
# Epoch 54: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0317 - val_accuracy: 0.9599 - val_loss: 0.1493
# Epoch 55/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0294
# Epoch 55: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0294 - val_accuracy: 0.9660 - val_loss: 0.1439
# Epoch 56/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0275
# Epoch 56: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0275 - val_accuracy: 0.9660 - val_loss: 0.1343
# Epoch 57/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0260
# Epoch 57: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 0.9722 - val_loss: 0.1049
# Epoch 58/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0243
# Epoch 58: val_accuracy did not improve from 0.97531
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0243 - val_accuracy: 0.9660 - val_loss: 0.1087
# Epoch 59/100
# ...
# Epoch 45/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0533
# Epoch 45: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0532 - val_accuracy: 0.5000 - val_loss: 1.0514
# Epoch 46/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0493
# Epoch 46: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0493 - val_accuracy: 0.5000 - val_loss: 1.0148
# Epoch 47/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9995 - loss: 0.0470
# Epoch 47: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9995 - loss: 0.0470 - val_accuracy: 0.5000 - val_loss: 1.4128
# Epoch 48/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0447
# Epoch 48: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0446 - val_accuracy: 0.5000 - val_loss: 1.3559
# Epoch 49/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0394
# Epoch 49: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0394 - val_accuracy: 0.5000 - val_loss: 1.2735
# Epoch 50/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0361
# Epoch 50: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0361 - val_accuracy: 0.5000 - val_loss: 1.2929
# Epoch 51/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0331
# Epoch 51: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0331 - val_accuracy: 0.5000 - val_loss: 1.1464
# Epoch 52/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0306
# Epoch 52: val_accuracy improved from 0.50000 to 0.50309, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 1.0000 - loss: 0.0306 - val_accuracy: 0.5031 - val_loss: 1.0435
# Epoch 53/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0284
# Epoch 53: val_accuracy improved from 0.50309 to 0.50926, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0283 - val_accuracy: 0.5093 - val_loss: 0.9392
# Epoch 54/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0265
# Epoch 54: val_accuracy improved from 0.50926 to 0.52160, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0265 - val_accuracy: 0.5216 - val_loss: 0.8672
# Epoch 55/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0250
# Epoch 55: val_accuracy did not improve from 0.52160
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0250 - val_accuracy: 0.5216 - val_loss: 0.8800
# Epoch 56/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0228
# Epoch 56: val_accuracy improved from 0.52160 to 0.54012, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0228 - val_accuracy: 0.5401 - val_loss: 0.7300
# Epoch 57/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0215
# Epoch 57: val_accuracy improved from 0.54012 to 0.54321, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 1.0000 - loss: 0.0215 - val_accuracy: 0.5432 - val_loss: 0.7106
# Epoch 58/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0201
# Epoch 58: val_accuracy improved from 0.54321 to 0.56790, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0201 - val_accuracy: 0.5679 - val_loss: 0.6420
# Epoch 59/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0182
# Epoch 59: val_accuracy improved from 0.56790 to 0.58642, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 1.0000 - loss: 0.0182 - val_accuracy: 0.5864 - val_loss: 0.5649
# Epoch 60/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0173
# Epoch 60: val_accuracy did not improve from 0.58642
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0173 - val_accuracy: 0.5833 - val_loss: 0.5592
# Epoch 61/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0167
# Epoch 61: val_accuracy improved from 0.58642 to 0.60802, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 0.6080 - val_loss: 0.5204
# Epoch 62/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0152
# Epoch 62: val_accuracy improved from 0.60802 to 0.61420, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.6142 - val_loss: 0.5110
# Epoch 63/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0149
# Epoch 63: val_accuracy improved from 0.61420 to 0.66975, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.6698 - val_loss: 0.4588
# Epoch 64/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0136
# Epoch 64: val_accuracy improved from 0.66975 to 0.73148, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.7315 - val_loss: 0.4077
# Epoch 65/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 65: val_accuracy improved from 0.73148 to 0.75926, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.7593 - val_loss: 0.3806
# Epoch 66/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0124
# Epoch 66: val_accuracy improved from 0.75926 to 0.79321, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.7932 - val_loss: 0.3552
# Epoch 67/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 67: val_accuracy improved from 0.79321 to 0.80556, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.8056 - val_loss: 0.3330
# Epoch 68/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0110
# Epoch 68: val_accuracy improved from 0.80556 to 0.84877, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.8488 - val_loss: 0.2927
# Epoch 69/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0104
# Epoch 69: val_accuracy improved from 0.84877 to 0.88889, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.8889 - val_loss: 0.2657
# Epoch 70/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 70: val_accuracy improved from 0.88889 to 0.89815, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.8981 - val_loss: 0.2527
# Epoch 71/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0096
# Epoch 71: val_accuracy improved from 0.89815 to 0.94136, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.9414 - val_loss: 0.2098
# Epoch 72/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0091
# Epoch 72: val_accuracy improved from 0.94136 to 0.95370, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.9537 - val_loss: 0.1905
# Epoch 73/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 73: val_accuracy improved from 0.95370 to 0.95679, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9568 - val_loss: 0.1781
# Epoch 74/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 74: val_accuracy improved from 0.95679 to 0.98148, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.9815 - val_loss: 0.1501
# Epoch 75/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 75: val_accuracy improved from 0.98148 to 0.98457, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9846 - val_loss: 0.1462
# Epoch 76/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 76: val_accuracy improved from 0.98457 to 0.98765, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9877 - val_loss: 0.1373
# Epoch 77/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 77: val_accuracy improved from 0.98765 to 0.99074, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9907 - val_loss: 0.1196
# Epoch 78/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 78: val_accuracy did not improve from 0.99074
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9907 - val_loss: 0.1094
# Epoch 79/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 79: val_accuracy did not improve from 0.99074
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.9907 - val_loss: 0.1003
# Epoch 80/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 80: val_accuracy did not improve from 0.99074
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9784 - val_loss: 0.1246
# Epoch 81/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 81: val_accuracy did not improve from 0.99074
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9907 - val_loss: 0.0912
# Epoch 82/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 82: val_accuracy did not improve from 0.99074
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9907 - val_loss: 0.0710
# Epoch 83/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 83: val_accuracy improved from 0.99074 to 0.99383, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9938 - val_loss: 0.0617
# Epoch 84/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 84: val_accuracy improved from 0.99383 to 0.99691, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9969 - val_loss: 0.0557
# Epoch 85/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0063
# Epoch 85: val_accuracy did not improve from 0.99691
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9969 - val_loss: 0.0412
# Epoch 86/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 86: val_accuracy did not improve from 0.99691
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9969 - val_loss: 0.0368
# Epoch 87/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 87: val_accuracy improved from 0.99691 to 1.00000, saving model to model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0331
# Epoch 88/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 88: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0255
# Epoch 89/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 89: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0239
# Epoch 90/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 90: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 91/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 91: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 92/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 92: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0089
# Epoch 93/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 93: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0095
# Epoch 94/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 94: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 95/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 95: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 96/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 96: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 97/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 97: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 98/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 98: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 99/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 99: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 100/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 100: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 0.0056
#
# O modelo demorou 360.27 segundos para treinar.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step
#
# Training Fold 4/5
# /tmp/ipykernel_12255/1359235689.py:12: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(

# %%
print('\n\nCross-Validation Results:')
for metric in metrics:
    print(f'\nFold {metric["fold"]}:')
    print(classification_report(y_val_fold, y_pred, target_names=cm_plot_labels))

# Treinar modelo final com todos os dados de treino
final_model = model_resnet50()
final_model.fit(
    np.expand_dims(all_train_specs, axis=-1),
    to_categorical(all_train_labels, 2),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    verbose=1
)

# Avaliar no teste final
test_loss, test_acc = final_model.evaluate(
    np.expand_dims(X_test, axis=-1),
    to_categorical(y_test, 2),
    verbose=0
)
print(f'\nFinal Test Accuracy: {test_acc:.4f}')

# Gerar gráficos finais (substituir)
y_pred_test = np.argmax(final_model.predict(np.expand_dims(X_test, axis=-1)), axis=1)
plot_and_save_report(y_test, y_pred_test)
plot_and_matrix(y_test, y_pred_test, cm_plot_labels)

cm_plot_labels = ['Normal', 'Hacked']

# %%
# GC collect
tf.keras.backend.clear_session()
gc.collect()
