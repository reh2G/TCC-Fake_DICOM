# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, jaccard_score, f1_score, precision_score, recall_score
from skimage.metrics import structural_similarity as ssim
from sklearn import preprocessing
from keras.utils import to_categorical
from keras import regularizers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.layers import Input, Dense, Dropout, Lambda, GlobalAveragePooling2D
from keras.src.legacy.preprocessing.image import ImageDataGenerator

import random
import re
import glob
from tqdm import tqdm
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
import gc
# Out:
# 2025-03-25 16:54:54.474526: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-25 16:54:54.549682: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-25 16:54:54.589759: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-25 16:54:55.300240: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs disponíveis: {gpus}")
else:
    print("Nenhuma GPU encontrada.")
# Out:
# GPUs disponíveis: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742932513.211201     944 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1742932515.185704     944 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1742932515.185862     944 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# nome = 'PACS'
nome = 'Yildirim'
#nome = 'Todos'

imgs_path = 'Bases/Dataset' + nome

output_dir = "8-CNN-espectro-ResNet50 results (10%)/"
os.makedirs(output_dir, exist_ok=True)

TEST_SIZE = 0.1
VALIDATION_SIZE = 0.1

SIMILARITY = 0.75

EPOCHS = 200
BATCH_SIZE = 32

HIGH_FREQ_THRESHOLD = 10

# %%
def get_next_filename(output_folder, base_name, type):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    image_index = 0
    
    while True:
        output_filename = f"{base_name}_{image_index}.{type}"
        output_path = os.path.join(output_folder, output_filename)
        
        if not os.path.exists(output_path):
            return output_filename
            
        image_index += 1

# %%
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else 0

# %%
def sort_files_numerically(file_paths):
    return sorted(file_paths, key=lambda x: extract_number(x))

# %%
def find_groups(images, image_paths, test_size, similarity_threshold):
    def are_similar(img1, img2, threshold):
        similarity = ssim(img1, img2)
        return similarity >= threshold

    groups = []
    current_group = [image_paths[0]]

    for i in range(1, len(images)):
        if are_similar(images[i-1], images[i], similarity_threshold):
            current_group.append(image_paths[i])
        else:
            groups.append(current_group)
            current_group = [image_paths[i]]
    
    if current_group:
        groups.append(current_group)

    all_images = [img_path for group in groups for img_path in group]

    for img_path in image_paths:
        if img_path not in all_images:
            groups.append([img_path])

    random.shuffle(groups)

    train_set = []
    test_set = []
    current_test_size = 0
    
    for i, group in enumerate(groups):
        if current_test_size + len(group) <= test_size:
            test_set.extend(group)
            current_test_size += len(group)
        else:
            train_set.extend(group)

    return train_set, test_set

# %%
output_folder = 'Groups'
type = 'txt'

def save_groups(train_groups, test_groups, base_name):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    output_filename = get_next_filename(output_folder, base_name, type)
    output_path = os.path.join(output_folder, output_filename)

    with open(output_path, 'w') as file:
        file.write('- test:\n')
        for idx, group in enumerate(test_groups, start=1):
            for img in group:
                file.write(f"{img}\n")
        
        file.write('- train:\n')
        for idx, group in enumerate(train_groups, start=1):
            for img in group:
                file.write(f'{img}\n')
    
    print(f'Group information saved in {output_path}')

# %%
def read_dataset(path, jpg, png):
    print(f'Reading dataset...\n')
    
    img_type = []
    images = []
    image_paths = []

    if jpg:
        img_type.append('*.jpg')
    if png:
        img_type.append('*.png')

# Normal

    normal_path = os.path.join(path, 'Train', 'Normal')
    print(f'Reading Normal images from: {normal_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(normal_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# Kidney

    kidney_stone_path = os.path.join(path, 'Train', 'Kidney_stone')
    print(f'Reading Kidney_stone images from: {kidney_stone_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(kidney_stone_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# ...
    
    images = np.array(images)
    image_paths = np.array(image_paths)

    return images, image_paths

# %%
all_X, all_image_paths = read_dataset(path=imgs_path, jpg=True, png=True)
# Out:
# Reading dataset...
#
# Reading Normal images from: Bases/DatasetYildirim/Train/Normal
# Reading Kidney_stone images from: Bases/DatasetYildirim/Train/Kidney_stone

# %%
def freq_spec(image, threshold, add_noise):
    f = np.fft.fft2(image)
    fshift = np.fft.fftshift(f)

    if add_noise:
        amplification_factor = 0.5
        rows, cols = image.shape
        crow, ccol = rows//2, cols//2

        corner = np.random.randint(0, 4)
        
        mask = np.zeros((rows, cols), dtype=bool)
        
        if corner == 0:    # Canto superior esquerdo
            mask[:crow - threshold, :ccol - threshold] = True
        elif corner == 1:  # Canto superior direito
            mask[:crow - threshold, ccol + threshold:] = True
        elif corner == 2:  # Canto inferior esquerdo
            mask[crow + threshold:, :ccol - threshold] = True
        else:              # Canto inferior direito
            mask[crow + threshold:, ccol + threshold:] = True

        fshift[mask] *= amplification_factor

    magnitude_spectrum_high = 20 * np.log(np.abs(fshift) + 1)

    return magnitude_spectrum_high

# %%
def save_specs(images, threshold, add_noise):
    specs = []
    for img in images:
        specs.append(freq_spec(img, threshold, add_noise))
    return specs

# %%
all_specs = []
all_labels = []

half = len(all_X) // 2
for i, img in enumerate(all_X):
    if i < half:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=False))
        all_labels.append(0)
    else:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=True))
        all_labels.append(1)

all_specs = np.array(all_specs)
all_labels = np.array(all_labels)

# %%
print("Quantidade das imagens:", all_specs.shape)
print("Exemplo dos labels (False = original, True = com ruído):", all_labels)
# Out:
# Quantidade das imagens: (1799, 224, 224)
# Exemplo dos labels (False = original, True = com ruído): [0 0 0 ... 1 1 1]

# %%
X_train, X_test, y_train, y_test, paths_train, paths_test = train_test_split(
        all_specs, all_labels, all_image_paths,
        test_size=TEST_SIZE, 
        stratify=all_labels,
#       random_state=53
    )

# %%
def plot_specs(specs, title):
    total_images = len(specs)
    imgs_per_figure = 100
    cols = 5
    rows = (imgs_per_figure + cols - 1) // cols

    for start in range(0, total_images, imgs_per_figure):
        plt.figure(figsize=(cols * 3, rows * 3))
        end = min(start + imgs_per_figure, total_images)
        
        for i in range(start, end):
            plt.subplot(rows, cols, i - start + 1)
            plt.imshow(specs[i], cmap='gray')
            plt.title(f"{title} - freq spec: img {i+1}")
            plt.axis('off')
            
        plt.tight_layout()
        plt.show()

# %%
# Plotar todos os espectros de teste
#plot_specs(X_test, title="test")

# %%
#pausa de teste

# %%
# Defines the model layers (now for ResNet50)
def model_resnet50():  # (Optional: Rename the function for clarity)
    # Camada de entrada para imagens em escala de cinza (mantido igual)
    inputs = Input(shape=(224, 224, 1))
    
    # 1. Conversão para 3 canais (mantido igual)
    x = Lambda(lambda x: tf.repeat(x, 3, axis=-1))(inputs)
    
    # 2. Pré-processamento ResNet (mantido igual)
    x = tf.keras.applications.resnet.preprocess_input(x)
    
    # 3. *** ALTERAÇÃO PRINCIPAL: Carregar ResNet-50 ***
    base_model = tf.keras.applications.ResNet50(
        weights='imagenet',
        include_top=False,
        input_tensor=x
    )
    
    # 4. Topo personalizado (mantido igual)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(150, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    x = Dense(100, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    outputs = Dense(2, activation='softmax')(x)
    
    # Compilação (mantido igual)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer='Adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []

# Configurar K-Fold com random_state fixo para reprodutibilidade
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=53)

# Verificar quais folds já foram completados
completed_folds = []
for f in range(1, 6):
    model_path = output_dir + f'model_{nome}_fold_{f}.keras'
    if os.path.exists(model_path):
        completed_folds.append(f)
print(f"Folds concluídos: {completed_folds}")

fold_no = 1
histories = []
metrics = []

for train_idx, val_idx in kfold.split(X_train, y_train):
    # Pular folds já concluídos
    if fold_no in completed_folds:
        print(f"\nPulando fold {fold_no} (já concluído)")
        fold_no += 1
        continue

    print(f'\nTreinando Fold {fold_no}/5')
    
    # Split dos dados
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]

    # Pré-processamento final
    X_train_fold = np.expand_dims(X_train_fold, axis=-1)
    X_val_fold = np.expand_dims(X_val_fold, axis=-1)
    y_train_fold_cat = to_categorical(y_train_fold, 2)
    y_val_fold_cat = to_categorical(y_val_fold, 2)

    # Criar novo modelo para cada fold
    model = model_resnet50()

    # Checkpoint com nome do fold
    checkpoint_filepath = output_dir + f'model_{nome}_fold_{fold_no}.keras'
    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss'),
        tf.keras.callbacks.TensorBoard(log_dir='logs'),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=False,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
            verbose=1
        )
    ]

    # Calcula tempo (start)
    start_time = time.time()
    
    # Treinar modelo
    history = model.fit(
        X_train_fold, y_train_fold_cat,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val_fold, y_val_fold_cat),
        callbacks=callbacks,
        verbose=1
    )

    # Calcula tempo (end)
    end_time = time.time()

    training_time = end_time - start_time
    print(f"\nO modelo demorou {training_time:.2f} segundos para treinar.")

    # Coletar métricas e salvar modelo
    predictions = model.predict(X_val_fold)
    y_pred = np.argmax(predictions, axis=1)
    
    metrics.append({
        'fold': fold_no,
        'report': classification_report(y_val_fold, y_pred, output_dict=True, zero_division=0),
        'matrix': confusion_matrix(y_val_fold, y_pred)
    })

    # Métricas de classificação (por fold)
    acc.append(accuracy_score(y_val_fold, y_pred))
    jacc.append(jaccard_score(y_val_fold, y_pred))
    f1.append(f1_score(y_val_fold, y_pred))
    prec.append(precision_score(y_val_fold, y_pred))
    rec.append(recall_score(y_val_fold, y_pred))

    # Salvar métricas em um arquivo .txt
    metrics_filename = os.path.join(output_dir, f'metrics_{nome}_fold_{fold_no}.txt')
    with open(metrics_filename, 'w') as f:
        f.write(f"Fold {fold_no} Metrics:\n")
        f.write(f"Accuracy: {acc[-1]}\n")
        f.write(f"Jaccard Score: {jacc[-1]}\n")
        f.write(f"F1 Score: {f1[-1]}\n")
        f.write(f"Precision: {prec[-1]}\n")
        f.write(f"Recall: {rec[-1]}\n")
        f.write("\nClassification Report:\n")
        f.write(classification_report(y_val_fold, y_pred, zero_division=0))
        f.write("\nConfusion Matrix:\n")
        f.write(np.array2string(confusion_matrix(y_val_fold, y_pred)))

    # Limpeza de memória
    del model
    tf.keras.backend.clear_session()
    gc.collect()

    # Salvar checkpoint a cada 3 folds
    if fold_no % 3 == 0:
        print(f"\nCheckpoint: Folds {fold_no-2}-{fold_no} concluídos")

    fold_no += 1
# Out:
# Folds concluídos: []
#
# Treinando Fold 1/5
# I0000 00:00:1742932594.971390     944 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1742932594.971506     944 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1742932594.971564     944 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1742932595.359799     944 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1742932595.359898     944 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-25 16:56:35.359909: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1742932595.359994     944 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-25 16:56:35.360012: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:10:00.0, compute capability: 8.6
# Epoch 1/200
# I0000 00:00:1742932675.769611    1023 service.cc:146] XLA service 0x7f5fc4001d20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1742932675.769671    1023 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-03-25 16:58:01.558261: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-25 16:58:12.876095: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 2025-03-25 16:58:18.238944: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15567', 196 bytes spill stores, 196 bytes spill loads
#
# I0000 00:00:1742932758.795118    1023 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 685ms/step - accuracy: 0.7425 - loss: 3.8735
# 2025-03-25 16:59:54.559306: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1760', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-03-25 16:59:54.814303: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1760', 8 bytes spill stores, 8 bytes spill loads
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.7458 - loss: 3.8536 - val_accuracy: 0.5000 - val_loss: 7859.9736
# Epoch 2/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9901 - loss: 1.4418
# Epoch 2: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 0.9902 - loss: 1.4360 - val_accuracy: 0.5000 - val_loss: 4.3073
# Epoch 3/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9990 - loss: 0.6937
# Epoch 3: val_accuracy improved from 0.50000 to 0.56481, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 194ms/step - accuracy: 0.9989 - loss: 0.6917 - val_accuracy: 0.5648 - val_loss: 1.9280
# Epoch 4/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.3928
# Epoch 4: val_accuracy did not improve from 0.56481
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.3919 - val_accuracy: 0.5340 - val_loss: 1.6568
# Epoch 5/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 1.0000 - loss: 0.2474
# Epoch 5: val_accuracy did not improve from 0.56481
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 225ms/step - accuracy: 1.0000 - loss: 0.2469 - val_accuracy: 0.5247 - val_loss: 1.0138
# Epoch 6/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9974 - loss: 0.1800
# Epoch 6: val_accuracy improved from 0.56481 to 0.75926, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 194ms/step - accuracy: 0.9973 - loss: 0.1800 - val_accuracy: 0.7593 - val_loss: 0.6278
# Epoch 7/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9947 - loss: 0.1589
# Epoch 7: val_accuracy improved from 0.75926 to 0.77469, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 195ms/step - accuracy: 0.9947 - loss: 0.1586 - val_accuracy: 0.7747 - val_loss: 0.6620
# Epoch 8/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9994 - loss: 0.1075
# Epoch 8: val_accuracy improved from 0.77469 to 0.99383, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 194ms/step - accuracy: 0.9994 - loss: 0.1074 - val_accuracy: 0.9938 - val_loss: 0.0968
# Epoch 9/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9993 - loss: 0.0877
# Epoch 9: val_accuracy improved from 0.99383 to 1.00000, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 267ms/step - accuracy: 0.9993 - loss: 0.0876 - val_accuracy: 1.0000 - val_loss: 0.0732
# Epoch 10/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0686
# Epoch 10: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0685 - val_accuracy: 1.0000 - val_loss: 0.0596
# Epoch 11/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0553
# Epoch 11: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0552 - val_accuracy: 1.0000 - val_loss: 0.0531
# Epoch 12/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0463
# Epoch 12: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0462 - val_accuracy: 1.0000 - val_loss: 0.0468
# Epoch 13/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0398
# Epoch 13: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0397 - val_accuracy: 1.0000 - val_loss: 0.0407
# Epoch 14/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 1.0000 - loss: 0.0341
# Epoch 14: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 224ms/step - accuracy: 1.0000 - loss: 0.0341 - val_accuracy: 1.0000 - val_loss: 0.0346
# Epoch 15/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0296
# Epoch 15: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0296 - val_accuracy: 1.0000 - val_loss: 0.0307
# Epoch 16/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0261
# Epoch 16: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0261 - val_accuracy: 1.0000 - val_loss: 0.0265
# Epoch 17/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0236
# Epoch 17: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0236 - val_accuracy: 1.0000 - val_loss: 0.0246
# Epoch 18/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0206
# Epoch 18: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0206 - val_accuracy: 1.0000 - val_loss: 0.0251
# Epoch 19/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 0.0187
# Epoch 19: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 225ms/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 1.0000 - val_loss: 0.0212
# Epoch 20/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0168
# Epoch 20: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0168 - val_accuracy: 1.0000 - val_loss: 0.0186
# Epoch 21/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0147
# Epoch 21: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 22/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 22: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0154
# Epoch 23/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 23: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 24/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 24: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 225ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 1.0000 - val_loss: 0.0125
# Epoch 25/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0103
# Epoch 25: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 0.0125
# Epoch 26/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.
val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0265 - val_accuracy: 0.9969 - val_loss: 0.0180
# Epoch 39/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 39: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.9969 - val_loss: 0.0206
#
# O modelo demorou 352.39 segundos para treinar.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 235ms/step
#
# Treinando Fold 3/5
# Epoch 1/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.6723 - loss: 3.9243
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 66s 803ms/step - accuracy: 0.6760 - loss: 3.9043 - val_accuracy: 0.5000 - val_loss: 60.9025
# Epoch 2/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9817 - loss: 1.3795
# Epoch 2: val_accuracy improved from 0.50000 to 0.58951, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 200ms/step - accuracy: 0.9818 - loss: 1.3734 - val_accuracy: 0.5895 - val_loss: 1.3354
# Epoch 3/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9896 - loss: 0.6156
# Epoch 3: val_accuracy did not improve from 0.58951
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 0.9898 - loss: 0.6135 - val_accuracy: 0.5000 - val_loss: 7.2160
# Epoch 4/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9909 - loss: 0.3358
# Epoch 4: val_accuracy improved from 0.58951 to 0.65123, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 196ms/step - accuracy: 0.9911 - loss: 0.3346 - val_accuracy: 0.6512 - val_loss: 0.8202
# Epoch 5/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.1886
# Epoch 5: val_accuracy did not improve from 0.65123
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - accuracy: 1.0000 - loss: 0.1882 - val_accuracy: 0.6481 - val_loss: 0.7459
# Epoch 6/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 1.0000 - loss: 0.1240
# Epoch 6: val_accuracy improved from 0.65123 to 0.73148, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 285ms/step - accuracy: 1.0000 - loss: 0.1237 - val_accuracy: 0.7315 - val_loss: 0.6078
# Epoch 7/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0891
# Epoch 7: val_accuracy improved from 0.73148 to 0.86728, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 208ms/step - accuracy: 1.0000 - loss: 0.0890 - val_accuracy: 0.8673 - val_loss: 0.3931
# Epoch 8/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0686
# Epoch 8: val_accuracy improved from 0.86728 to 0.96605, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 202ms/step - accuracy: 1.0000 - loss: 0.0685 - val_accuracy: 0.9660 - val_loss: 0.2063
# Epoch 9/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0536
# Epoch 9: val_accuracy improved from 0.96605 to 0.99074, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 277ms/step - accuracy: 1.0000 - loss: 0.0535 - val_accuracy: 0.9907 - val_loss: 0.1116
# Epoch 10/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0428
# Epoch 10: val_accuracy improved from 0.99074 to 0.99383, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 203ms/step - accuracy: 1.0000 - loss: 0.0427 - val_accuracy: 0.9938 - val_loss: 0.0688
# Epoch 11/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0350
# Epoch 11: val_accuracy improved from 0.99383 to 1.00000, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_3.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 203ms/step - accuracy: 1.0000 - loss: 0.0350 - val_accuracy: 1.0000 - val_loss: 0.0476
# Epoch 12/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0295
# Epoch 12: val_accuracy did not improve from 1.00000
# ...
# Epoch 19/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 19: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 230ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0122
# Epoch 20/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 20: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 0.0110
# Epoch 21/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0099
# Epoch 21: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 22/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0091
# Epoch 22: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 0.0096
# Epoch 23/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 23: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 24/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 24: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 25/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 25: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 26/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 26: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 27/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 27: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 28/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 28: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 29/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 29: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 30/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 30: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 31/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 31: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 32/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 32: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 33/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 33: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 34/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 34: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 35/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 35: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 36/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 36: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 37/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 37: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 38/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 38: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 39/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9881 - loss: 0.0913
# Epoch 39: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 0.9879 - loss: 0.0933 - val_accuracy: 0.5000 - val_loss: 2020702.3750
# Epoch 40/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9941 - loss: 0.1580
# Epoch 40: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 0.9942 - loss: 0.1572 - val_accuracy: 0.5000 - val_loss: 1982.2932
# Epoch 41/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9926 - loss: 0.0624
# Epoch 41: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 0.9927 - loss: 0.0620 - val_accuracy: 0.5000 - val_loss: 553.1434
# Epoch 42/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0208
# Epoch 42: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - accuracy: 1.0000 - loss: 0.0208 - val_accuracy: 0.5123 - val_loss: 29.9882
# Epoch 43/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 43: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.7778 - val_loss: 2.7419
# Epoch 44/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 1.0000 - loss: 0.0104
# Epoch 44: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.9969 - val_loss: 0.0283
# Epoch 45/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0091
# Epoch 45: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.9907 - val_loss: 0.0519
# Epoch 46/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0091
# Epoch 46: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.9969 - val_loss: 0.0144
# Epoch 47/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 47: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9969 - val_loss: 0.0145
# Epoch 48/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 48: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.9969 - val_loss: 0.0153
# Epoch 49/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 49: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 50/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 50: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 51/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 51: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 52/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 52: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 53/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 53: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 54/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 54: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 55/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 55: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 56/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 56: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9938 - val_loss: 0.0132
# Epoch 57/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 57: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9969 - val_loss: 0.0095
# Epoch 58/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 58: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 0.9999 - loss: 0.0041 - val_accuracy: 0.9907 - val_loss: 0.0385
# Epoch 59/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9869 - loss: 0.1052
# Epoch 59: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 0.9871 - loss: 0.1052 - val_accuracy: 0.5000 - val_loss: 988.6235
# Epoch 60/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9878 - loss: 0.1140
# Epoch 60: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 0.9878 - loss: 0.1138 - val_accuracy: 0.5000 - val_loss: 3872.6914
# Epoch 61/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0371
# Epoch 61: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0369 - val_accuracy: 0.6142 - val_loss: 26.5130
# Epoch 62/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9997 - loss: 0.0153
# Epoch 62: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 0.9997 - loss: 0.0154 - val_accuracy: 0.9321 - val_loss: 0.6251
# Epoch 63/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0183
# Epoch 63: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.9938 - val_loss: 0.0509
# Epoch 64/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 64: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 65/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 65: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 66/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 66: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 67/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9998 - loss: 0.0055
# Epoch 67: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 0.9998 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 68/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 68: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 69/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 69: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 70/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 70: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 71/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 71: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 72/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 72: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 73/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 73: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 74/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 74: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0053
#
# O modelo demorou 595.88 segundos para treinar.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 238ms/step
#
# Checkpoint: Folds 1-3 concluídos
#
# Treinando Fold 4/5
# Epoch 1/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.6876 - loss: 4.0997
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to 8-CNN-espectro-ResNet50 (10%)/model_Yildirim_fold_4.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.6911 - loss: 4.0812 - val_accuracy: 0.5000 - val_loss: 15246.5508
# Epoch 2/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9905 - loss: 1.6684
# Epoch 2: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 235ms/step - accuracy: 0.9906 - loss: 1.6624 - val_accuracy: 0.5000 - val_loss: 1.7233
# Epoch 3/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9995 - loss: 0.8353
# Epoch 3: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 134s 3s/step - accuracy: 0.9995 - loss: 0.8330 - val_accuracy: 0.5000 - val_loss: 1.5576
# Epoch 4/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9971 - loss: 0.4789
# Epoch 4: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 222s 6s/step - accuracy: 0.9971 - loss: 0.4778 - val_accuracy: 0.5000 - val_loss: 1.1132
# Epoch 5/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 44s/step - accuracy: 0.9967 - loss: 0.3305
# Epoch 5: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1771s 44s/step - accuracy: 0.9968 - loss: 0.3293 - val_accuracy: 0.5000 - val_loss: 1.0407
# Epoch 6/200
# 15/41 ━━━━━━━━━━━━━━━━━━━━ 3:24 8s/step - accuracy: 0.9726 - loss: 0.3360

# %%
print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
print("Dice: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))

# %%
# GC collect
tf.keras.backend.clear_session()
gc.collect()
