# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, jaccard_score, f1_score, precision_score, recall_score
from skimage.metrics import structural_similarity as ssim
from sklearn import preprocessing
from keras.utils import to_categorical
from keras import regularizers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.layers import Input, Dense, Dropout, Lambda, GlobalAveragePooling2D
from keras.src.legacy.preprocessing.image import ImageDataGenerator

import random
import re
import glob
from tqdm import tqdm
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
import gc
# Out:
# 2025-04-07 14:16:47.692629: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-07 14:16:47.761944: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-07 14:16:47.792338: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-07 14:16:48.518268: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs disponíveis: {gpus}")
else:
    print("Nenhuma GPU encontrada.")
# Out:
# GPUs disponíveis: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744046224.857093    1891 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1744046226.671257    1891 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1744046226.671402    1891 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# nome = 'PACS'
nome = 'Yildirim'
#nome = 'Todos'

imgs_path = 'Bases/Dataset' + nome

output_dir = "13-CNN-espectro-ResNet152 results (2%)/"
os.makedirs(output_dir, exist_ok=True)

TEST_SIZE = 0.1
VALIDATION_SIZE = 0.1

SIMILARITY = 0.75

EPOCHS = 200
BATCH_SIZE = 32

HIGH_FREQ_THRESHOLD = 2

# %%
def get_next_filename(output_folder, base_name, type):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    image_index = 0
    
    while True:
        output_filename = f"{base_name}_{image_index}.{type}"
        output_path = os.path.join(output_folder, output_filename)
        
        if not os.path.exists(output_path):
            return output_filename
            
        image_index += 1

# %%
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else 0

# %%
def sort_files_numerically(file_paths):
    return sorted(file_paths, key=lambda x: extract_number(x))

# %%
def read_dataset(path, jpg, png):
    print(f'Reading dataset...\n')
    
    img_type = []
    images = []
    image_paths = []

    if jpg:
        img_type.append('*.jpg')
    if png:
        img_type.append('*.png')

# Normal

    normal_path = os.path.join(path, 'Train', 'Normal')
    print(f'Reading Normal images from: {normal_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(normal_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# Kidney

    kidney_stone_path = os.path.join(path, 'Train', 'Kidney_stone')
    print(f'Reading Kidney_stone images from: {kidney_stone_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(kidney_stone_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# ...
    
    images = np.array(images)
    image_paths = np.array(image_paths)

    return images, image_paths

# %%
all_X, all_image_paths = read_dataset(path=imgs_path, jpg=True, png=True)
# Out:
# Reading dataset...
#
# Reading Normal images from: Bases/DatasetYildirim/Train/Normal
# Reading Kidney_stone images from: Bases/DatasetYildirim/Train/Kidney_stone

# %%
def freq_spec(image, threshold, add_noise):
    f = np.fft.fft2(image)
    fshift = np.fft.fftshift(f)

    if add_noise:
        amplification_factor = 0.5
        rows, cols = image.shape
        crow, ccol = rows//2, cols//2

        corner = np.random.randint(0, 4)
        
        mask = np.zeros((rows, cols), dtype=bool)
        
        if corner == 0:    # Canto superior esquerdo
            mask[:crow - threshold, :ccol - threshold] = True
        elif corner == 1:  # Canto superior direito
            mask[:crow - threshold, ccol + threshold:] = True
        elif corner == 2:  # Canto inferior esquerdo
            mask[crow + threshold:, :ccol - threshold] = True
        else:              # Canto inferior direito
            mask[crow + threshold:, ccol + threshold:] = True

        fshift[mask] *= amplification_factor

    magnitude_spectrum_high = 20 * np.log(np.abs(fshift) + 1)

    return magnitude_spectrum_high

# %%
def save_specs(images, threshold, add_noise):
    specs = []
    for img in images:
        specs.append(freq_spec(img, threshold, add_noise))
    return specs

# %%
all_specs = []
all_labels = []

half = len(all_X) // 2
for i, img in enumerate(all_X):
    if i < half:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=False))
        all_labels.append(0)
    else:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=True))
        all_labels.append(1)

all_specs = np.array(all_specs)
all_labels = np.array(all_labels)

# %%
print("Quantidade das imagens:", all_specs.shape)
print("Exemplo dos labels (False = original, True = com ruído):", all_labels)
# Out:
# Quantidade das imagens: (1799, 224, 224)
# Exemplo dos labels (False = original, True = com ruído): [0 0 0 ... 1 1 1]

# %%
X_train, X_test, y_train, y_test, paths_train, paths_test = train_test_split(
        all_specs, all_labels, all_image_paths,
        test_size=TEST_SIZE, 
        stratify=all_labels,
#       random_state=53
    )

# %%
def plot_specs(specs, title):
    total_images = len(specs)
    imgs_per_figure = 100
    cols = 5
    rows = (imgs_per_figure + cols - 1) // cols

    for start in range(0, total_images, imgs_per_figure):
        plt.figure(figsize=(cols * 3, rows * 3))
        end = min(start + imgs_per_figure, total_images)
        
        for i in range(start, end):
            plt.subplot(rows, cols, i - start + 1)
            plt.imshow(specs[i], cmap='gray')
            plt.title(f"{title} - freq spec: img {i+1}")
            plt.axis('off')
            
        plt.tight_layout()
        plt.show()

# %%
# Plotar todos os espectros de teste
#plot_specs(X_test, title="test")

# %%
#pausa de teste

# %%
# Defines the model layers (now for ResNet50)
def model_resnet152():  # (Optional: Rename the function for clarity)
    # Camada de entrada para imagens em escala de cinza (mantido igual)
    inputs = Input(shape=(224, 224, 1))
    
    # 1. Conversão para 3 canais
    x = Lambda(
        lambda x: tf.stack([x[..., 0]]*3, axis=-1),
        output_shape=(224, 224, 3)
    )(inputs)
    
    # 2. Pré-processamento ResNet
    x = tf.keras.applications.resnet.preprocess_input(x)
    
    # 3. *** ALTERAÇÃO PRINCIPAL: Carregar ResNet-152 ***
    base_model = tf.keras.applications.ResNet152(
        weights='imagenet',
        include_top=False,
        input_tensor=x
    )
    
    # 4. Topo personalizado
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(150, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    x = Dense(100, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    outputs = Dense(2, activation='softmax')(x)
    
    # Compilação (mantido igual)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer='Adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []

# Configurar K-Fold com random_state fixo para reprodutibilidade
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=53)

# Verificar quais folds já foram completados
completed_folds = []
for f in range(1, 6):
    model_path = output_dir + f'model_{nome}_fold_{f}.keras'
    if os.path.exists(model_path):
        completed_folds.append(f)
print(f"Folds concluídos: {completed_folds}")

fold_no = 1
histories = []
metrics = []

for train_idx, val_idx in kfold.split(X_train, y_train):
    # Pular folds já concluídos
    if fold_no in completed_folds:
        print(f"\nPulando fold {fold_no} (já concluído)")
        fold_no += 1
        continue

    print(f'\nTreinando Fold {fold_no}/5')
    
    # Split dos dados
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]

    # Pré-processamento final
    X_train_fold = np.expand_dims(X_train_fold, axis=-1)
    X_val_fold = np.expand_dims(X_val_fold, axis=-1)
    y_train_fold_cat = to_categorical(y_train_fold, 2)
    y_val_fold_cat = to_categorical(y_val_fold, 2)

    # Criar novo modelo para cada fold
    model = model_resnet152()

    # Checkpoint com nome do fold
    checkpoint_filepath = output_dir + f'model_{nome}_fold_{fold_no}.keras'
    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss'),
        tf.keras.callbacks.TensorBoard(log_dir='logs'),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=False,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
            verbose=1
        )
    ]

    # Calcula tempo (start)
    start_time = time.time()
    
    # Treinar modelo
    history = model.fit(
        X_train_fold, y_train_fold_cat,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val_fold, y_val_fold_cat),
        callbacks=callbacks,
        verbose=1
    )

    # Calcula tempo (end)
    end_time = time.time()

    training_time = end_time - start_time
    print(f"\nO modelo demorou {training_time:.2f} segundos para treinar.")

    # Coletar métricas e salvar modelo
    predictions = model.predict(X_val_fold)
    y_pred = np.argmax(predictions, axis=1)
    
    metrics.append({
        'fold': fold_no,
        'report': classification_report(y_val_fold, y_pred, output_dict=True, zero_division=0),
        'matrix': confusion_matrix(y_val_fold, y_pred)
    })

    # Métricas de classificação (por fold)
    acc.append(accuracy_score(y_val_fold, y_pred))
    jacc.append(jaccard_score(y_val_fold, y_pred))
    f1.append(f1_score(y_val_fold, y_pred))
    prec.append(precision_score(y_val_fold, y_pred))
    rec.append(recall_score(y_val_fold, y_pred))

    # Salvar métricas em um arquivo .txt
    metrics_filename = os.path.join(output_dir, f'metrics_{nome}_fold_{fold_no}.txt')
    with open(metrics_filename, 'w') as f:
        f.write(f"Fold {fold_no} Metrics:\n")
        f.write(f"Accuracy: {acc[-1]}\n")
        f.write(f"Jaccard Score: {jacc[-1]}\n")
        f.write(f"F1 Score: {f1[-1]}\n")
        f.write(f"Precision: {prec[-1]}\n")
        f.write(f"Recall: {rec[-1]}\n")
        f.write("\nClassification Report:\n")
        f.write(classification_report(y_val_fold, y_pred, zero_division=0))
        f.write("\nConfusion Matrix:\n")
        f.write(np.array2string(confusion_matrix(y_val_fold, y_pred)))

    # Limpeza de memória
    del model
    tf.keras.backend.clear_session()
    gc.collect()

    # Salvar checkpoint a cada 3 folds
    if fold_no % 3 == 0:
        print(f"\nCheckpoint: Folds {fold_no-2}-{fold_no} concluídos")

    fold_no += 1
# Out:
# Folds concluídos: []
#
# Treinando Fold 1/5
# I0000 00:00:1744046309.959062    1891 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1744046309.959173    1891 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1744046309.959228    1891 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1744046312.924465    1891 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1744046312.924571    1891 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-07 14:18:32.924583: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1744046312.924692    1891 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-07 14:18:32.924720: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:10:00.0, compute capability: 8.6
# Epoch 1/200
# I0000 00:00:1744046379.059145    1969 service.cc:146] XLA service 0x7f71a8001d20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1744046379.059242    1969 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-04-07 14:19:41.974127: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-04-07 14:19:48.743953: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 2025-04-07 14:19:59.816059: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_45152', 196 bytes spill stores, 196 bytes spill loads
#
# 2025-04-07 14:20:43.444591: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_74', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1744046443.972140    1969 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.7728 - loss: 3.9035
# 2025-04-07 14:21:53.597301: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_divide_multiply_subtract_fusion_159', 4 bytes spill stores, 16 bytes spill loads
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7753 - loss: 3.8846
# 2025-04-07 14:22:10.454555: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4961', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-04-07 14:22:11.121526: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4961', 8 bytes spill stores, 8 bytes spill loads
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to 13-CNN-espectro-ResNet152 results (2%)/model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 266s 4s/step - accuracy: 0.7776 - loss: 3.8667 - val_accuracy: 0.5000 - val_loss: 43837591552.0000
# Epoch 2/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.9761 - loss: 1.4263
# Epoch 2: val_accuracy did not improve from 0.50000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 19s 446ms/step - accuracy: 0.9762 - loss: 1.4204 - val_accuracy: 0.5000 - val_loss: 2175.7332
# Epoch 3/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9992 - loss: 0.6077
# Epoch 3: val_accuracy improved from 0.50000 to 0.51235, saving model to 13-CNN-espectro-ResNet152 results (2%)/model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.9991 - loss: 0.6059 - val_accuracy: 0.5123 - val_loss: 1.0687
# Epoch 4/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.9958 - loss: 0.3294
# Epoch 4: val_accuracy did not improve from 0.51235
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 446ms/step - accuracy: 0.9958 - loss: 0.3284 - val_accuracy: 0.5062 - val_loss: 0.9316
# Epoch 5/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.9953 - loss: 0.2095
# Epoch 5: val_accuracy improved from 0.51235 to 0.65432, saving model to 13-CNN-espectro-ResNet152 results (2%)/model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.9951 - loss: 0.2101 - val_accuracy: 0.6543 - val_loss: 0.7886
# Epoch 6/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.9859 - loss: 0.2768
# Epoch 6: val_accuracy improved from 0.65432 to 0.96605, saving model to 13-CNN-espectro-ResNet152 results (2%)/model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.9859 - loss: 0.2762 - val_accuracy: 0.9660 - val_loss: 0.2590
# Epoch 7/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.9984 - loss: 0.1464
# Epoch 7: val_accuracy improved from 0.96605 to 0.98148, saving model to 13-CNN-espectro-ResNet152 results (2%)/model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.9984 - loss: 0.1461 - val_accuracy: 0.9815 - val_loss: 0.1523
# Epoch 8/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 1.0000 - loss: 0.0965
# Epoch 8: val_accuracy improved from 0.98148 to 0.99074, saving model to 13-CNN-espectro-ResNet152 results (2%)/model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 1.0000 - loss: 0.0964 - val_accuracy: 0.9907 - val_loss: 0.1112
# Epoch 9/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 1.0000 - loss: 0.0736
# Epoch 9: val_accuracy improved from 0.99074 to 1.00000, saving model to 13-CNN-espectro-ResNet152 results (2%)/model_Yildirim_fold_1.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 1.0000 - loss: 0.0735 - val_accuracy: 1.0000 - val_loss: 0.0809
# Epoch 10/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9993 - loss: 0.0612
# Epoch 10: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 372ms/step - accuracy: 0.9993 - loss: 0.0614 - val_accuracy: 1.0000 - val_loss: 0.0987
# Epoch 11/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.9988 - loss: 0.0613
# Epoch 11: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 443ms/step - accuracy: 0.9987 - loss: 0.0613 - val_accuracy: 1.0000 - val_loss: 0.0637
# Epoch 12/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 1.0000 - loss: 0.0443
# Epoch 12: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 373ms/step - accuracy: 1.0000 - loss: 0.0443 - val_accuracy: 1.0000 - val_loss: 0.0510
# Epoch 13/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 1.0000 - loss: 0.0369
# Epoch 13: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 447ms/step - accuracy: 1.0000 - loss: 0.0368 - val_accuracy: 1.0000 - val_loss: 0.0389
# Epoch 14/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9988 - loss: 0.0343
# Epoch 14: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 375ms/step - accuracy: 0.9987 - loss: 0.0344 - val_accuracy: 1.0000 - val_loss: 0.0464
# Epoch 15/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 1.0000 - loss: 0.0344
# Epoch 15: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 447ms/step - accuracy: 1.0000 - loss: 0.0344 - val_accuracy: 1.0000 - val_loss: 0.0288
# Epoch 16/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 1.0000 - loss: 0.0294
# Epoch 16: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 373ms/step - accuracy: 1.0000 - loss: 0.0294 - val_accuracy: 1.0000 - val_loss: 0.0285
# Epoch 17/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9965 - loss: 0.0358
# Epoch 17: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 375ms/step - accuracy: 0.9965 - loss: 0.0359 - val_accuracy: 0.9969 - val_loss: 0.0484
# Epoch 18/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.9992 - loss: 0.0282
# Epoch 18: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 449ms/step - accuracy: 0.9992 - loss: 0.0282 - val_accuracy: 0.8858 - val_loss: 0.5653
# Epoch 19/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 1.0000 - loss: 0.0220
# Epoch 19: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 376ms/step - accuracy: 1.0000 - loss: 0.0220 - val_accuracy: 1.0000 - val_loss: 0.0251
# Epoch 20/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 1.0000 - loss: 0.0183
# Epoch 20: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 449ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 1.0000 - val_loss: 0.0194
# Epoch 21/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 1.0000 - loss: 0.0163
# Epoch 21: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 375ms/step - accuracy: 1.0000 - loss: 0.0162 - val_accuracy: 1.0000 - val_loss: 0.0170
# Epoch 22/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 1.0000 - loss: 0.0146
# Epoch 22: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 449ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 1.0000 - val_loss: 0.0160
# Epoch 23/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 23: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 16s 378ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 0.0147
# Epoch 24/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 24: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 448ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 25/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 25: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 375ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 0.0128
# Epoch 26/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 26: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 448ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 27/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 1.0000 - loss: 0.0108
# Epoch 27: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 376ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 0.0110
# Epoch 28/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 28: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 447ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 29/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 29: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 375ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0101
# Epoch 30/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 30: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 448ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 31/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 31: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 374ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 32/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 32: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 448ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 33/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 33: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 374ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 34/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 34: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 448ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 35/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9972 - loss: 0.0208
# Epoch 35: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 374ms/step - accuracy: 0.9972 - loss: 0.0212 - val_accuracy: 0.9907 - val_loss: 0.0785
# Epoch 36/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.9971 - loss: 0.0269
# Epoch 36: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 448ms/step - accuracy: 0.9971 - loss: 0.0269 - val_accuracy: 0.8827 - val_loss: 0.4383
# Epoch 37/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9975 - loss: 0.0189
# Epoch 37: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 375ms/step - accuracy: 0.9975 - loss: 0.0188 - val_accuracy: 0.9630 - val_loss: 0.1559
# Epoch 38/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9985 - loss: 0.0161
# Epoch 38: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 447ms/step - accuracy: 0.9984 - loss: 0.0167 - val_accuracy: 0.9136 - val_loss: 1.1987
# Epoch 39/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9966 - loss: 0.0678
# Epoch 39: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 374ms/step - accuracy: 0.9966 - loss: 0.0676 - val_accuracy: 0.5525 - val_loss: 11.4840
# Epoch 40/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9989 - loss: 0.0251
# Epoch 40: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 375ms/step - accuracy: 0.9989 - loss: 0.0250 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 41/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.9986 - loss: 0.0209
# Epoch 41: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 448ms/step - accuracy: 0.9986 - loss: 0.0209 - val_accuracy: 0.9907 - val_loss: 0.0364
# Epoch 42/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 42: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 373ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 43/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 43: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 447ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 44/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 44: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 371ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0127
# Epoch 45/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.9993 - loss: 0.0156
# Epoch 45: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 443ms/step - accuracy: 0.9993 - loss: 0.0155 - val_accuracy: 0.9969 - val_loss: 0.0177
# Epoch 46/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 46: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 370ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 47/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 1.0000 - loss: 0.0063
# Epoch 47: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 442ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 48/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 48: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 370ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 49/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 49: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 443ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 50/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 50: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 369ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 51/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 51: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 444ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 52/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 52: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 370ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 53/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 53: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 443ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 54/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 54: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 370ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 55/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.9994 - loss: 0.0056
# Epoch 55: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 444ms/step - accuracy: 0.9994 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0088
# Epoch 56/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9965 - loss: 0.0159
# Epoch 56: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 370ms/step - accuracy: 0.9966 - loss: 0.0159 - val_accuracy: 1.0000 - val_loss: 0.0120
# Epoch 57/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9978 - loss: 0.0111
# Epoch 57: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 370ms/step - accuracy: 0.9979 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 58/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9930 - loss: 0.0488
# Epoch 58: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 370ms/step - accuracy: 0.9931 - loss: 0.0486 - val_accuracy: 0.9877 - val_loss: 0.0928
# Epoch 59/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 1.0000 - loss: 0.0152
# Epoch 59: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 370ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.9969 - val_loss: 0.0097
# Epoch 60/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 60: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 443ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 61/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 61: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 371ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 62/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 62: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 443ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 63/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 63: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 371ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 64/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 64: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 443ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 65/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 65: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 370ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 66/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 1.0000 - loss: 0.0124
# Epoch 66: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 444ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 67/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9993 - loss: 0.0128
# Epoch 67: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 371ms/step - accuracy: 0.9993 - loss: 0.0129 - val_accuracy: 0.9938 - val_loss: 0.0499
# Epoch 68/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.9999 - loss: 0.0177
# Epoch 68: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 444ms/step - accuracy: 0.9999 - loss: 0.0176 - val_accuracy: 0.9969 - val_loss: 0.0175
# Epoch 69/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 69: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 370ms/step - accuracy: 0.9999 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 0.0081
# Epoch 70/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 1.0000 - loss: 0.0140
# Epoch 70: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 445ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 71/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 71: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 371ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 72/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 72: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 445ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 73/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 73: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 371ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 74/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9995 - loss: 0.0057
# Epoch 74: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 445ms/step - accuracy: 0.9995 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0235
# Epoch 75/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 1.0000 - loss: 0.0176
# Epoch 75: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 371ms/step - accuracy: 1.0000 - loss: 0.0176 - val_accuracy: 0.8241 - val_loss: 0.8755
# Epoch 76/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9877 - loss: 0.0586
# Epoch 76: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 372ms/step - accuracy: 0.9878 - loss: 0.0585 - val_accuracy: 0.5000 - val_loss: 208.7069
# Epoch 77/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.9972 - loss: 0.0218
# Epoch 77: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 443ms/step - accuracy: 0.9972 - loss: 0.0218 - val_accuracy: 0.6605 - val_loss: 19.3975
# Epoch 78/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9981 - loss: 0.0211
# Epoch 78: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 372ms/step - accuracy: 0.9981 - loss: 0.0211 - val_accuracy: 0.6728 - val_loss: 5.0729
# Epoch 79/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.9986 - loss: 0.0140
# Epoch 79: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 445ms/step - accuracy: 0.9986 - loss: 0.0140 - val_accuracy: 0.9198 - val_loss: 0.7048
# Epoch 80/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 80: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 371ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 81/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 81: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 444ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 82/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 82: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 372ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 83/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 83: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 445ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9969 - val_loss: 0.0141
# Epoch 84/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 84: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 372ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 85/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 85: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 444ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0048
#
# O modelo demorou 1875.46 segundos para treinar.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step
#
# Treinando Fold 2/5
# Epoch 1/200

# %%
print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
print("Dice: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))

# %%
# GC collect
tf.keras.backend.clear_session()
gc.collect()
