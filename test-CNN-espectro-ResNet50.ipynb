# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, jaccard_score, f1_score, precision_score, recall_score
from skimage.metrics import structural_similarity as ssim
from sklearn import preprocessing
from keras.utils import to_categorical
from keras import regularizers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.layers import Input, Dense, Dropout, Lambda, GlobalAveragePooling2D
from keras.src.legacy.preprocessing.image import ImageDataGenerator

import random
import re
import glob
from tqdm import tqdm
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
import gc
# Out:
# 2025-03-31 17:08:06.416024: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-31 17:08:06.497690: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-31 17:08:06.551621: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-31 17:08:07.249387: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs disponíveis: {gpus}")
else:
    print("Nenhuma GPU encontrada.")
# Out:
# GPUs disponíveis: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743451706.619249    2058 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743451708.444789    2058 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743451708.444919    2058 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# nome = 'PACS'
nome = 'Yildirim'
#nome = 'Todos'

imgs_path = 'Bases/Dataset' + nome

output_dir = "test-CNN-espectro-ResNet50 results (2%)/"
os.makedirs(output_dir, exist_ok=True)

TEST_SIZE = 0.1
VALIDATION_SIZE = 0.1

SIMILARITY = 0.75

EPOCHS = 200
BATCH_SIZE = 32

HIGH_FREQ_THRESHOLD = 2
NUM_FOLD = 2

# %%
def get_next_filename(output_folder, base_name, type):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    image_index = 0
    
    while True:
        output_filename = f"{base_name}_{image_index}.{type}"
        output_path = os.path.join(output_folder, output_filename)
        
        if not os.path.exists(output_path):
            return output_filename
            
        image_index += 1

# %%
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else 0

# %%
def sort_files_numerically(file_paths):
    return sorted(file_paths, key=lambda x: extract_number(x))

# %%
def read_dataset(path, jpg, png):
    print(f'Reading dataset...\n')
    
    img_type = []
    images = []
    image_paths = []

    if jpg:
        img_type.append('*.jpg')
    if png:
        img_type.append('*.png')

# Normal

    normal_path = os.path.join(path, 'Train', 'Normal')
    print(f'Reading Normal images from: {normal_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(normal_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# Kidney

    kidney_stone_path = os.path.join(path, 'Train', 'Kidney_stone')
    print(f'Reading Kidney_stone images from: {kidney_stone_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(kidney_stone_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# ...
    
    images = np.array(images)
    image_paths = np.array(image_paths)

    return images, image_paths

# %%
all_X, all_image_paths = read_dataset(path=imgs_path, jpg=True, png=True)
# Out:
# Reading dataset...
#
# Reading Normal images from: Bases/DatasetYildirim/Train/Normal
# Reading Kidney_stone images from: Bases/DatasetYildirim/Train/Kidney_stone

# %%
def freq_spec(image, threshold, add_noise):
    f = np.fft.fft2(image)
    fshift = np.fft.fftshift(f)

    if add_noise:
        amplification_factor = 0.5
        rows, cols = image.shape
        crow, ccol = rows//2, cols//2

        corner = np.random.randint(0, 4)
        
        mask = np.zeros((rows, cols), dtype=bool)
        
        if corner == 0:    # Canto superior esquerdo
            mask[:crow - threshold, :ccol - threshold] = True
        elif corner == 1:  # Canto superior direito
            mask[:crow - threshold, ccol + threshold:] = True
        elif corner == 2:  # Canto inferior esquerdo
            mask[crow + threshold:, :ccol - threshold] = True
        else:              # Canto inferior direito
            mask[crow + threshold:, ccol + threshold:] = True

        fshift[mask] *= amplification_factor

    magnitude_spectrum_high = 20 * np.log(np.abs(fshift) + 1)

    return magnitude_spectrum_high

# %%
def save_specs(images, threshold, add_noise):
    specs = []
    for img in images:
        specs.append(freq_spec(img, threshold, add_noise))
    return specs

# %%
all_specs = []
all_labels = []

half = len(all_X) // 2
for i, img in enumerate(all_X):
    if i < half:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=False))
        all_labels.append(0)
    else:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=True))
        all_labels.append(1)

all_specs = np.array(all_specs)
all_labels = np.array(all_labels)

# %%
print("Quantidade das imagens:", all_specs.shape)
print("Exemplo dos labels (False = original, True = com ruído):", all_labels)
# Out:
# Quantidade das imagens: (1799, 224, 224)
# Exemplo dos labels (False = original, True = com ruído): [0 0 0 ... 1 1 1]

# %%
X_train, X_test, y_train, y_test, paths_train, paths_test = train_test_split(
        all_specs, all_labels, all_image_paths,
        test_size=TEST_SIZE, 
        stratify=all_labels,
#       random_state=53
    )

# %%
def plot_specs(specs, title):
    total_images = len(specs)
    imgs_per_figure = 100
    cols = 5
    rows = (imgs_per_figure + cols - 1) // cols

    for start in range(0, total_images, imgs_per_figure):
        plt.figure(figsize=(cols * 3, rows * 3))
        end = min(start + imgs_per_figure, total_images)
        
        for i in range(start, end):
            plt.subplot(rows, cols, i - start + 1)
            plt.imshow(specs[i], cmap='gray')
            plt.title(f"{title} - freq spec: img {i+1}")
            plt.axis('off')
            
        plt.tight_layout()
        plt.show()

# %%
# Plotar todos os espectros de teste
#plot_specs(X_test, title="test")

# %%
#pausa de teste

# %%
# Defines the model layers (now for ResNet50)
def model_resnet50():  # (Optional: Rename the function for clarity)
    # Camada de entrada para imagens em escala de cinza (mantido igual)
    inputs = Input(shape=(224, 224, 1))
    
    # 1. Conversão para 3 canais
    x = Lambda(
        lambda x: tf.stack([x[..., 0]]*3, axis=-1),
        output_shape=(224, 224, 3)
    )(inputs)
    
    # 2. Pré-processamento ResNet
    x = tf.keras.applications.resnet.preprocess_input(x)
    
    # 3. *** ALTERAÇÃO PRINCIPAL: Carregar ResNet-50 ***
    base_model = tf.keras.applications.ResNet50(
        weights='imagenet',
        include_top=False,
        input_tensor=x
    )
    
    # 4. Topo personalizado (mantido igual)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(150, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    x = Dense(100, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    outputs = Dense(2, activation='softmax')(x)
    
    # Compilação (mantido igual)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer='Adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []

# Configurar K-Fold com random_state fixo para reprodutibilidade
#kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=53)
kfold = StratifiedKFold(n_splits=NUM_FOLD, shuffle=True, random_state=53)

# Verificar quais folds já foram completados
completed_folds = []
for f in range(1, NUM_FOLD + 1):
    model_path = output_dir + f'model_{nome}_fold_{f}.keras'
    if os.path.exists(model_path):
        completed_folds.append(f)
print(f"Folds concluídos: {completed_folds}")

fold_no = 1
histories = []
metrics = []

for train_idx, val_idx in kfold.split(X_train, y_train):
    # Pular folds já concluídos
    if fold_no in completed_folds:
        print(f"\nPulando fold {fold_no} (já concluído)")
        fold_no += 1
        continue

    print(f'\nTreinando Fold {fold_no}/{NUM_FOLD}')
    
    # Split dos dados
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]

    # Pré-processamento final
    X_train_fold = np.expand_dims(X_train_fold, axis=-1)
    X_val_fold = np.expand_dims(X_val_fold, axis=-1)
    y_train_fold_cat = to_categorical(y_train_fold, 2)
    y_val_fold_cat = to_categorical(y_val_fold, 2)

    # Criar novo modelo para cada fold
    model = model_resnet50()

    # Checkpoint com nome do fold
    checkpoint_filepath = output_dir + f'model_{nome}_fold_{fold_no}.keras'
    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss'),
        tf.keras.callbacks.TensorBoard(log_dir='logs'),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=False,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
            verbose=1
        )
    ]

    # Calcula tempo (start)
    start_time = time.time()
    
    # Treinar modelo
    history = model.fit(
        X_train_fold, y_train_fold_cat,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val_fold, y_val_fold_cat),
        callbacks=callbacks,
        verbose=1
    )

    # Calcula tempo (end)
    end_time = time.time()

    training_time = end_time - start_time
    print(f"\nO modelo demorou {training_time:.2f} segundos para treinar.")

    # Coletar métricas e salvar modelo
    predictions = model.predict(X_val_fold)
    y_pred = np.argmax(predictions, axis=1)
    
    metrics.append({
        'fold': fold_no,
        'report': classification_report(y_val_fold, y_pred, output_dict=True, zero_division=0),
        'matrix': confusion_matrix(y_val_fold, y_pred)
    })

    # Métricas de classificação (por fold)
    acc.append(accuracy_score(y_val_fold, y_pred))
    jacc.append(jaccard_score(y_val_fold, y_pred))
    f1.append(f1_score(y_val_fold, y_pred))
    prec.append(precision_score(y_val_fold, y_pred))
    rec.append(recall_score(y_val_fold, y_pred))

    # Salvar métricas em um arquivo .txt
    metrics_filename = os.path.join(output_dir, f'metrics_{nome}_fold_{fold_no}.txt')
    with open(metrics_filename, 'w') as f:
        f.write(f"Fold {fold_no} Metrics:\n")
        f.write(f"Accuracy: {acc[-1]}\n")
        f.write(f"Jaccard Score: {jacc[-1]}\n")
        f.write(f"F1 Score: {f1[-1]}\n")
        f.write(f"Precision: {prec[-1]}\n")
        f.write(f"Recall: {rec[-1]}\n")
        f.write("\nClassification Report:\n")
        f.write(classification_report(y_val_fold, y_pred, zero_division=0))
        f.write("\nConfusion Matrix:\n")
        f.write(np.array2string(confusion_matrix(y_val_fold, y_pred)))

    # Limpeza de memória
    del model
    tf.keras.backend.clear_session()
    gc.collect()

    # Salvar checkpoint a cada 3 folds
    if fold_no % 3 == 0:
        print(f"\nCheckpoint: Folds {fold_no-2}-{fold_no} concluídos")

    fold_no += 1
# Out:
# Folds concluídos: []
#
# Treinando Fold 1/2
# I0000 00:00:1743451790.861035    2058 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743451790.861164    2058 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743451790.861215    2058 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743451794.847071    2058 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743451794.847205    2058 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-31 17:09:54.847226: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1743451794.847328    2058 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-31 17:09:54.847399: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:10:00.0, compute capability: 8.6
# Epoch 1/200
# I0000 00:00:1743451836.961657    2133 service.cc:146] XLA service 0x7ff974003c20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1743451836.961699    2133 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-03-31 17:10:41.514622: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-31 17:10:44.163164: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 2025-03-31 17:10:47.800718: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15572', 196 bytes spill stores, 196 bytes spill loads
#
# I0000 00:00:1743451880.208127    2133 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6238 - loss: 4.2753
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.6292 - loss: 4.2551 - val_accuracy: 0.5000 - val_loss: 5786.8931
# Epoch 2/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9300 - loss: 2.3259
# Epoch 2: val_accuracy improved from 0.50000 to 0.50247, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 295ms/step - accuracy: 0.9314 - loss: 2.3122 - val_accuracy: 0.5025 - val_loss: 5.1761
# Epoch 3/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9894 - loss: 1.2116
# Epoch 3: val_accuracy did not improve from 0.50247
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.9896 - loss: 1.2067 - val_accuracy: 0.5000 - val_loss: 7.0751
# Epoch 4/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9914 - loss: 0.7630
# Epoch 4: val_accuracy did not improve from 0.50247
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - accuracy: 0.9912 - loss: 0.7612 - val_accuracy: 0.5000 - val_loss: 2.8885
# Epoch 5/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9851 - loss: 0.5516
# Epoch 5: val_accuracy did not improve from 0.50247
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 367ms/step - accuracy: 0.9852 - loss: 0.5498 - val_accuracy: 0.4975 - val_loss: 9.3508
# Epoch 6/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9991 - loss: 0.3618
# Epoch 6: val_accuracy improved from 0.50247 to 0.54321, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 306ms/step - accuracy: 0.9991 - loss: 0.3609 - val_accuracy: 0.5432 - val_loss: 2.2737
# Epoch 7/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 1.0000 - loss: 0.2681
# Epoch 7: val_accuracy did not improve from 0.54321
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - accuracy: 1.0000 - loss: 0.2675 - val_accuracy: 0.5049 - val_loss: 1.2446
# Epoch 8/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.2035
# Epoch 8: val_accuracy did not improve from 0.54321
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 1.0000 - loss: 0.2031 - val_accuracy: 0.5136 - val_loss: 0.9832
# Epoch 9/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.1619
# Epoch 9: val_accuracy improved from 0.54321 to 0.56543, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 297ms/step - accuracy: 1.0000 - loss: 0.1616 - val_accuracy: 0.5654 - val_loss: 0.8582
# Epoch 10/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.1323
# Epoch 10: val_accuracy improved from 0.56543 to 0.65802, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 442ms/step - accuracy: 1.0000 - loss: 0.1321 - val_accuracy: 0.6580 - val_loss: 0.7239
# Epoch 11/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.1098
# Epoch 11: val_accuracy improved from 0.65802 to 0.76914, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 299ms/step - accuracy: 1.0000 - loss: 0.1096 - val_accuracy: 0.7691 - val_loss: 0.5820
# Epoch 12/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 1.0000 - loss: 0.0935
# Epoch 12: val_accuracy improved from 0.76914 to 0.85679, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 303ms/step - accuracy: 1.0000 - loss: 0.0934 - val_accuracy: 0.8568 - val_loss: 0.4491
# Epoch 13/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 1.0000 - loss: 0.0800
# Epoch 13: val_accuracy improved from 0.85679 to 0.88519, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 299ms/step - accuracy: 1.0000 - loss: 0.0799 - val_accuracy: 0.8852 - val_loss: 0.3885
# Epoch 14/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0692
# Epoch 14: val_accuracy improved from 0.88519 to 0.90617, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 440ms/step - accuracy: 1.0000 - loss: 0.0692 - val_accuracy: 0.9062 - val_loss: 0.3291
# Epoch 15/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 1.0000 - loss: 0.0603
# Epoch 15: val_accuracy improved from 0.90617 to 0.92963, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 301ms/step - accuracy: 1.0000 - loss: 0.0602 - val_accuracy: 0.9296 - val_loss: 0.2861
# Epoch 16/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0534
# Epoch 16: val_accuracy improved from 0.92963 to 0.96173, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 297ms/step - accuracy: 1.0000 - loss: 0.0533 - val_accuracy: 0.9617 - val_loss: 0.2037
# Epoch 17/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0475
# Epoch 17: val_accuracy did not improve from 0.96173
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 1.0000 - loss: 0.0474 - val_accuracy: 0.9605 - val_loss: 0.1951
# Epoch 18/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0418
# Epoch 18: val_accuracy improved from 0.96173 to 0.96420, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 442ms/step - accuracy: 1.0000 - loss: 0.0418 - val_accuracy: 0.9642 - val_loss: 0.1737
# Epoch 19/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 1.0000 - loss: 0.0374
# Epoch 19: val_accuracy improved from 0.96420 to 0.96790, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 297ms/step - accuracy: 1.0000 - loss: 0.0374 - val_accuracy: 0.9679 - val_loss: 0.1514
# Epoch 20/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0341
# Epoch 20: val_accuracy improved from 0.96790 to 0.97654, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 301ms/step - accuracy: 1.0000 - loss: 0.0341 - val_accuracy: 0.9765 - val_loss: 0.1109
# Epoch 21/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0310
# Epoch 21: val_accuracy improved from 0.97654 to 0.98148, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 295ms/step - accuracy: 1.0000 - loss: 0.0310 - val_accuracy: 0.9815 - val_loss: 0.0966
# Epoch 22/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0281
# Epoch 22: val_accuracy did not improve from 0.98148
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 1.0000 - loss: 0.0281 - val_accuracy: 0.9642 - val_loss: 0.1505
# Epoch 23/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 1.0000 - loss: 0.0267
# Epoch 23: val_accuracy did not improve from 0.98148
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 364ms/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 0.9506 - val_loss: 0.1846
# Epoch 24/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 1.0000 - loss: 0.0238
# Epoch 24: val_accuracy improved from 0.98148 to 0.98642, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 292ms/step - accuracy: 1.0000 - loss: 0.0238 - val_accuracy: 0.9864 - val_loss: 0.1070
# Epoch 25/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0221
# Epoch 25: val_accuracy did not improve from 0.98642
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 1.0000 - loss: 0.0221 - val_accuracy: 0.9728 - val_loss: 0.1031
# Epoch 26/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0205
# Epoch 26: val_accuracy did not improve from 0.98642
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 1.0000 - loss: 0.0205 - val_accuracy: 0.9605 - val_loss: 0.1278
# Epoch 27/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0191
# Epoch 27: val_accuracy did not improve from 0.98642
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.9148 - val_loss: 0.2359
# Epoch 28/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0170
# Epoch 28: val_accuracy did not improve from 0.98642
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 365ms/step - accuracy: 1.0000 - loss: 0.0170 - val_accuracy: 0.9395 - val_loss: 0.1814
# Epoch 29/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9989 - loss: 0.0213
# Epoch 29: val_accuracy did not improve from 0.98642
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.9985 - loss: 0.0226 - val_accuracy: 0.5000 - val_loss: 185.0843
# Epoch 30/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9749 - loss: 0.2309
# Epoch 30: val_accuracy did not improve from 0.98642
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.9747 - loss: 0.2307 - val_accuracy: 0.5000 - val_loss: 11006.7119
# Epoch 31/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9668 - loss: 0.1504
# Epoch 31: val_accuracy did not improve from 0.98642
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.9672 - loss: 0.1498 - val_accuracy: 0.5000 - val_loss: 41153.5469
# Epoch 32/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9977 - loss: 0.0737
# Epoch 32: val_accuracy did not improve from 0.98642
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.9977 - loss: 0.0733 - val_accuracy: 0.5000 - val_loss: 1631.7482
# Epoch 33/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9994 - loss: 0.0421
# Epoch 33: val_accuracy did not improve from 0.98642
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 0.9994 - loss: 0.0420 - val_accuracy: 0.5000 - val_loss: 105.7050
# Epoch 34/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0288
# Epoch 34: val_accuracy did not improve from 0.98642
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 365ms/step - accuracy: 1.0000 - loss: 0.0288 - val_accuracy: 0.5000 - val_loss: 14.8492
# Epoch 35/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9979 - loss: 0.0276
# Epoch 35: val_accuracy improved from 0.98642 to 0.98889, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 300ms/step - accuracy: 0.9979 - loss: 0.0275 - val_accuracy: 0.9889 - val_loss: 0.1787
# Epoch 36/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9988 - loss: 0.0233
# Epoch 36: val_accuracy improved from 0.98889 to 0.99259, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 298ms/step - accuracy: 0.9988 - loss: 0.0233 - val_accuracy: 0.9926 - val_loss: 0.0716
# Epoch 37/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0217
# Epoch 37: val_accuracy improved from 0.99259 to 0.99877, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_1.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 298ms/step - accuracy: 1.0000 - loss: 0.0216 - val_accuracy: 0.9988 - val_loss: 0.0270
# Epoch 38/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 1.0000 - loss: 0.0189
# Epoch 38: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 366ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 0.9963 - val_loss: 0.0389
# Epoch 39/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0170
# Epoch 39: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 1.0000 - loss: 0.0170 - val_accuracy: 0.9901 - val_loss: 0.0475
# Epoch 40/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0162
# Epoch 40: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 1.0000 - loss: 0.0162 - val_accuracy: 0.9704 - val_loss: 0.1061
# Epoch 41/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0161
# Epoch 41: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 1.0000 - loss: 0.0161 - val_accuracy: 0.9765 - val_loss: 0.0752
# Epoch 42/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9999 - loss: 0.0153
# Epoch 42: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 0.9998 - loss: 0.0153 - val_accuracy: 0.9951 - val_loss: 0.0358
# Epoch 43/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0195
# Epoch 43: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 0.9938 - val_loss: 0.0429
# Epoch 44/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9953 - loss: 0.0472
# Epoch 44: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 366ms/step - accuracy: 0.9953 - loss: 0.0472 - val_accuracy: 0.9963 - val_loss: 0.0452
# Epoch 45/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9953 - loss: 0.0389
# Epoch 45: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.9954 - loss: 0.0386 - val_accuracy: 0.9951 - val_loss: 0.0399
# Epoch 46/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 0.0203
# Epoch 46: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 1.0000 - loss: 0.0203 - val_accuracy: 0.9938 - val_loss: 0.0437
# Epoch 47/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0157
# Epoch 47: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.9938 - val_loss: 0.0457
# Epoch 48/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 48: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.9877 - val_loss: 0.0536
# Epoch 49/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 49: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 366ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.9852 - val_loss: 0.0629
# Epoch 50/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0112
# Epoch 50: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.9840 - val_loss: 0.0668
# Epoch 51/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0109
# Epoch 51: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.9840 - val_loss: 0.0660
# Epoch 52/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 52: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.9765 - val_loss: 0.0847
# Epoch 53/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0101
# Epoch 53: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9667 - val_loss: 0.1107
# Epoch 54/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0098
# Epoch 54: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.9519 - val_loss: 0.1495
# Epoch 55/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9998 - loss: 0.0098
# Epoch 55: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 366ms/step - accuracy: 0.9998 - loss: 0.0098 - val_accuracy: 0.9889 - val_loss: 0.0541
# Epoch 56/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 56: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.9765 - val_loss: 0.0891
# Epoch 57/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0101
# Epoch 57: val_accuracy did not improve from 0.99877
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9716 - val_loss: 0.0942
#
# O modelo demorou 504.26 segundos para treinar.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step
#
# Treinando Fold 2/2
# Epoch 1/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5640 - loss: 4.4595
# Epoch 1: val_accuracy improved from -inf to 0.50062, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_2.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.5667 - loss: 4.4421 - val_accuracy: 0.5006 - val_loss: 33392.3203
# Epoch 2/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9416 - loss: 2.5474
# Epoch 2: val_accuracy did not improve from 0.50062
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - accuracy: 0.9422 - loss: 2.5353 - val_accuracy: 0.5006 - val_loss: 537.7297
# Epoch 3/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9894 - loss: 1.4346
# Epoch 3: val_accuracy improved from 0.50062 to 0.53399, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_2.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 305ms/step - accuracy: 0.9895 - loss: 1.4297 - val_accuracy: 0.5340 - val_loss: 1.8600
# Epoch 4/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9687 - loss: 1.0004
# Epoch 4: val_accuracy improved from 0.53399 to 0.62917, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_2.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 310ms/step - accuracy: 0.9691 - loss: 0.9964 - val_accuracy: 0.6292 - val_loss: 1.3590
# Epoch 5/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9988 - loss: 0.6144
# Epoch 5: val_accuracy improved from 0.62917 to 0.68727, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_2.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 443ms/step - accuracy: 0.9988 - loss: 0.6126 - val_accuracy: 0.6873 - val_loss: 1.1030
# Epoch 6/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9990 - loss: 0.4258
# Epoch 6: val_accuracy did not improve from 0.68727
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.9989 - loss: 0.4247 - val_accuracy: 0.6057 - val_loss: 1.0906
# Epoch 7/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.3050
# Epoch 7: val_accuracy did not improve from 0.68727
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 1.0000 - loss: 0.3043 - val_accuracy: 0.5538 - val_loss: 0.9847
# Epoch 8/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9996 - loss: 0.2311
# Epoch 8: val_accuracy did not improve from 0.68727
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.9995 - loss: 0.2307 - val_accuracy: 0.5278 - val_loss: 0.9253
# Epoch 9/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9995 - loss: 0.1800
# Epoch 9: val_accuracy did not improve from 0.68727
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.9995 - loss: 0.1799 - val_accuracy: 0.5365 - val_loss: 0.8466
# Epoch 10/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9930 - loss: 0.1659
# Epoch 10: val_accuracy improved from 0.68727 to 0.80593, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_2.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 445ms/step - accuracy: 0.9931 - loss: 0.1655 - val_accuracy: 0.8059 - val_loss: 0.5697
# Epoch 11/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9948 - loss: 0.1324
# Epoch 11: val_accuracy improved from 0.80593 to 0.93696, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_2.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 307ms/step - accuracy: 0.9949 - loss: 0.1321 - val_accuracy: 0.9370 - val_loss: 0.3344
# Epoch 12/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9982 - loss: 0.1042
# Epoch 12: val_accuracy improved from 0.93696 to 0.95179, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_2.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 302ms/step - accuracy: 0.9982 - loss: 0.1042 - val_accuracy: 0.9518 - val_loss: 0.2499
# Epoch 13/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9943 - loss: 0.1090
# Epoch 13: val_accuracy improved from 0.95179 to 0.95921, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_2.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 22s 866ms/step - accuracy: 0.9944 - loss: 0.1085 - val_accuracy: 0.9592 - val_loss: 0.2108
# Epoch 14/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0725
# Epoch 14: val_accuracy improved from 0.95921 to 0.98393, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_2.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 306ms/step - accuracy: 1.0000 - loss: 0.0724 - val_accuracy: 0.9839 - val_loss: 0.1180
# Epoch 15/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9999 - loss: 0.0601
# Epoch 15: val_accuracy improved from 0.98393 to 0.99135, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_2.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 311ms/step - accuracy: 0.9998 - loss: 0.0601 - val_accuracy: 0.9913 - val_loss: 0.1301
# Epoch 16/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0616
# Epoch 16: val_accuracy did not improve from 0.99135
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 1.0000 - loss: 0.0616 - val_accuracy: 0.9901 - val_loss: 0.1407
# Epoch 17/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0516
# Epoch 17: val_accuracy improved from 0.99135 to 0.99753, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_2.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 443ms/step - accuracy: 1.0000 - loss: 0.0515 - val_accuracy: 0.9975 - val_loss: 0.0968
# Epoch 18/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0412
# Epoch 18: val_accuracy did not improve from 0.99753
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 1.0000 - loss: 0.0412 - val_accuracy: 0.9951 - val_loss: 0.0797
# Epoch 19/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 1.0000 - loss: 0.0361
# Epoch 19: val_accuracy did not improve from 0.99753
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - accuracy: 1.0000 - loss: 0.0361 - val_accuracy: 0.9975 - val_loss: 0.0588
# Epoch 20/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 1.0000 - loss: 0.0320
# Epoch 20: val_accuracy did not improve from 0.99753
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - accuracy: 1.0000 - loss: 0.0320 - val_accuracy: 0.9963 - val_loss: 0.0474
# Epoch 21/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 1.0000 - loss: 0.0285
# Epoch 21: val_accuracy did not improve from 0.99753
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 1.0000 - loss: 0.0284 - val_accuracy: 0.9975 - val_loss: 0.0397
# Epoch 22/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 1.0000 - loss: 0.0246
# Epoch 22: val_accuracy improved from 0.99753 to 0.99876, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_2.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 450ms/step - accuracy: 1.0000 - loss: 0.0246 - val_accuracy: 0.9988 - val_loss: 0.0405
# Epoch 23/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0225
# Epoch 23: val_accuracy did not improve from 0.99876
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 1.0000 - loss: 0.0225 - val_accuracy: 0.9975 - val_loss: 0.0409
# Epoch 24/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 0.0198
# Epoch 24: val_accuracy did not improve from 0.99876
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 1.0000 - loss: 0.0198 - val_accuracy: 0.9975 - val_loss: 0.0383
# Epoch 25/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 0.0177
# Epoch 25: val_accuracy did not improve from 0.99876
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 1.0000 - loss: 0.0176 - val_accuracy: 0.9963 - val_loss: 0.0384
# Epoch 26/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0162
# Epoch 26: val_accuracy did not improve from 0.99876
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 1.0000 - loss: 0.0162 - val_accuracy: 0.9988 - val_loss: 0.0341
# Epoch 27/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0155
# Epoch 27: val_accuracy did not improve from 0.99876
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.9975 - val_loss: 0.0318
# Epoch 28/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 1.0000 - loss: 0.0138
# Epoch 28: val_accuracy did not improve from 0.99876
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.9988 - val_loss: 0.0307
# Epoch 29/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 29: val_accuracy did not improve from 0.99876
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.9988 - val_loss: 0.0314
# Epoch 30/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 30: val_accuracy did not improve from 0.99876
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 0.9988 - val_loss: 0.0309
# Epoch 31/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 31: val_accuracy improved from 0.99876 to 1.00000, saving model to test-CNN-espectro-ResNet50 results (2%)/model_Yildirim_fold_2.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 311ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0268
# Epoch 32/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 1.0000 - loss: 0.0105
# Epoch 32: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.9963 - val_loss: 0.0395
# Epoch 33/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 33: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 367ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 0.9975 - val_loss: 0.0259
# Epoch 34/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 34: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.9988 - val_loss: 0.0241
# Epoch 35/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 35: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9988 - val_loss: 0.0239
# Epoch 36/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 36: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.9988 - val_loss: 0.0217
# Epoch 37/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 37: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0246
# Epoch 38/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 38: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 368ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 0.0221
# Epoch 39/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 39: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.9999 - loss: 0.0082 - val_accuracy: 0.4994 - val_loss: 3.3794
# Epoch 40/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8297 - loss: 0.9486
# Epoch 40: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.8324 - loss: 0.9352 - val_accuracy: 0.5006 - val_loss: 11441361.0000
# Epoch 41/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9849 - loss: 0.3296
# Epoch 41: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 233ms/step - accuracy: 0.9851 - loss: 0.3281 - val_accuracy: 0.5006 - val_loss: 133922.5938
# Epoch 42/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9978 - loss: 0.1982
# Epoch 42: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - accuracy: 0.9978 - loss: 0.1978 - val_accuracy: 0.5723 - val_loss: 158.9114
# Epoch 43/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9989 - loss: 0.1423
# Epoch 43: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 232ms/step - accuracy: 0.9989 - loss: 0.1420 - val_accuracy: 0.7367 - val_loss: 22.6467
# Epoch 44/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 1.0000 - loss: 0.1080
# Epoch 44: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 374ms/step - accuracy: 1.0000 - loss: 0.1078 - val_accuracy: 0.8702 - val_loss: 3.1175
# Epoch 45/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 0.0865
# Epoch 45: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 1.0000 - loss: 0.0863 - val_accuracy: 0.9258 - val_loss: 1.1129
# Epoch 46/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 0.0717
# Epoch 46: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 1.0000 - loss: 0.0716 - val_accuracy: 0.9642 - val_loss: 0.3495
# Epoch 47/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 0.0591
# Epoch 47: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 1.0000 - loss: 0.0590 - val_accuracy: 0.9864 - val_loss: 0.1163
# Epoch 48/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 1.0000 - loss: 0.0492
# Epoch 48: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 1.0000 - loss: 0.0491 - val_accuracy: 0.9963 - val_loss: 0.0613
# Epoch 49/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 1.0000 - loss: 0.0420
# Epoch 49: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - accuracy: 1.0000 - loss: 0.0420 - val_accuracy: 0.9975 - val_loss: 0.0444
# Epoch 50/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 0.0360
# Epoch 50: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 1.0000 - loss: 0.0360 - val_accuracy: 1.0000 - val_loss: 0.0346
# Epoch 51/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 1.0000 - loss: 0.0351
# Epoch 51: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - accuracy: 1.0000 - loss: 0.0350 - val_accuracy: 1.0000 - val_loss: 0.0329
# Epoch 52/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0285
# Epoch 52: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 1.0000 - loss: 0.0285 - val_accuracy: 1.0000 - val_loss: 0.0272
# Epoch 53/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0243
# Epoch 53: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 1.0000 - loss: 0.0242 - val_accuracy: 1.0000 - val_loss: 0.0244
# Epoch 54/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9991 - loss: 0.0230
# Epoch 54: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.9991 - loss: 0.0230 - val_accuracy: 0.9889 - val_loss: 0.0732
# Epoch 55/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9992 - loss: 0.0235
# Epoch 55: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 367ms/step - accuracy: 0.9992 - loss: 0.0235 - val_accuracy: 0.9963 - val_loss: 0.0254
# Epoch 56/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9919 - loss: 0.0292
# Epoch 56: val_accuracy did not improve from 1.00000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.9921 - loss: 0.0290 - val_accuracy: 0.9901 - val_loss: 0.0461
#
# O modelo demorou 488.94 segundos para treinar.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step

# %%
print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
print("Dice: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))
# Out:
# Accuracy: 0.9808580933632438+- 0.009253155091638765
# Jaccard: 0.9617283950617284+- 0.018518518518518545
# Dice: 0.9804000164772313+- 0.009624921178629009
# Precision: 1.0+- 0.0
# Recall: 0.9617283950617284+- 0.018518518518518545
