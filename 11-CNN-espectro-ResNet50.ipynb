# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, jaccard_score, f1_score, precision_score, recall_score
from skimage.metrics import structural_similarity as ssim
from sklearn import preprocessing
from keras.utils import to_categorical
from keras import regularizers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.layers import Input, Dense, Dropout, Lambda, GlobalAveragePooling2D
from keras.src.legacy.preprocessing.image import ImageDataGenerator

import random
import re
import glob
from tqdm import tqdm
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
import gc
# Out:
# 2025-03-27 16:22:47.398520: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-27 16:22:47.497153: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-27 16:22:47.534069: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-27 16:22:48.314389: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs disponíveis: {gpus}")
else:
    print("Nenhuma GPU encontrada.")
# Out:
# GPUs disponíveis: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743103392.394323   37148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743103394.394332   37148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743103394.394423   37148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# nome = 'PACS'
nome = 'Yildirim'
#nome = 'Todos'

imgs_path = 'Bases/Dataset' + nome

output_dir = "11-CNN-espectro-ResNet50 results (4%)/"
os.makedirs(output_dir, exist_ok=True)

TEST_SIZE = 0.1
VALIDATION_SIZE = 0.1

SIMILARITY = 0.75

EPOCHS = 200
BATCH_SIZE = 32

HIGH_FREQ_THRESHOLD = 4

# %%
def get_next_filename(output_folder, base_name, type):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    image_index = 0
    
    while True:
        output_filename = f"{base_name}_{image_index}.{type}"
        output_path = os.path.join(output_folder, output_filename)
        
        if not os.path.exists(output_path):
            return output_filename
            
        image_index += 1

# %%
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else 0

# %%
def sort_files_numerically(file_paths):
    return sorted(file_paths, key=lambda x: extract_number(x))

# %%
def find_groups(images, image_paths, test_size, similarity_threshold):
    def are_similar(img1, img2, threshold):
        similarity = ssim(img1, img2)
        return similarity >= threshold

    groups = []
    current_group = [image_paths[0]]

    for i in range(1, len(images)):
        if are_similar(images[i-1], images[i], similarity_threshold):
            current_group.append(image_paths[i])
        else:
            groups.append(current_group)
            current_group = [image_paths[i]]
    
    if current_group:
        groups.append(current_group)

    all_images = [img_path for group in groups for img_path in group]

    for img_path in image_paths:
        if img_path not in all_images:
            groups.append([img_path])

    random.shuffle(groups)

    train_set = []
    test_set = []
    current_test_size = 0
    
    for i, group in enumerate(groups):
        if current_test_size + len(group) <= test_size:
            test_set.extend(group)
            current_test_size += len(group)
        else:
            train_set.extend(group)

    return train_set, test_set

# %%
output_folder = 'Groups'
type = 'txt'

def save_groups(train_groups, test_groups, base_name):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    output_filename = get_next_filename(output_folder, base_name, type)
    output_path = os.path.join(output_folder, output_filename)

    with open(output_path, 'w') as file:
        file.write('- test:\n')
        for idx, group in enumerate(test_groups, start=1):
            for img in group:
                file.write(f"{img}\n")
        
        file.write('- train:\n')
        for idx, group in enumerate(train_groups, start=1):
            for img in group:
                file.write(f'{img}\n')
    
    print(f'Group information saved in {output_path}')

# %%
def read_dataset(path, jpg, png):
    print(f'Reading dataset...\n')
    
    img_type = []
    images = []
    image_paths = []

    if jpg:
        img_type.append('*.jpg')
    if png:
        img_type.append('*.png')

# Normal

    normal_path = os.path.join(path, 'Train', 'Normal')
    print(f'Reading Normal images from: {normal_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(normal_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# Kidney

    kidney_stone_path = os.path.join(path, 'Train', 'Kidney_stone')
    print(f'Reading Kidney_stone images from: {kidney_stone_path}')
    
    for img_type_pattern in img_type:
        img_paths = glob.glob(os.path.join(kidney_stone_path, img_type_pattern))
        img_paths = sort_files_numerically(img_paths)
        
        for img_path in img_paths:
            img = cv2.imread(img_path, 0)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            image_paths.append(img_path)

# ...
    
    images = np.array(images)
    image_paths = np.array(image_paths)

    return images, image_paths

# %%
all_X, all_image_paths = read_dataset(path=imgs_path, jpg=True, png=True)
# Out:
# Reading dataset...
#
# Reading Normal images from: Bases/DatasetYildirim/Train/Normal
# Reading Kidney_stone images from: Bases/DatasetYildirim/Train/Kidney_stone

# %%
def freq_spec(image, threshold, add_noise):
    f = np.fft.fft2(image)
    fshift = np.fft.fftshift(f)

    if add_noise:
        amplification_factor = 0.5
        rows, cols = image.shape
        crow, ccol = rows//2, cols//2

        corner = np.random.randint(0, 4)
        
        mask = np.zeros((rows, cols), dtype=bool)
        
        if corner == 0:    # Canto superior esquerdo
            mask[:crow - threshold, :ccol - threshold] = True
        elif corner == 1:  # Canto superior direito
            mask[:crow - threshold, ccol + threshold:] = True
        elif corner == 2:  # Canto inferior esquerdo
            mask[crow + threshold:, :ccol - threshold] = True
        else:              # Canto inferior direito
            mask[crow + threshold:, ccol + threshold:] = True

        fshift[mask] *= amplification_factor

    magnitude_spectrum_high = 20 * np.log(np.abs(fshift) + 1)

    return magnitude_spectrum_high

# %%
def save_specs(images, threshold, add_noise):
    specs = []
    for img in images:
        specs.append(freq_spec(img, threshold, add_noise))
    return specs

# %%
all_specs = []
all_labels = []

half = len(all_X) // 2
for i, img in enumerate(all_X):
    if i < half:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=False))
        all_labels.append(0)
    else:
        all_specs.append(freq_spec(img, 100 - HIGH_FREQ_THRESHOLD, add_noise=True))
        all_labels.append(1)

all_specs = np.array(all_specs)
all_labels = np.array(all_labels)

# %%
print("Quantidade das imagens:", all_specs.shape)
print("Exemplo dos labels (False = original, True = com ruído):", all_labels)
# Out:
# Quantidade das imagens: (1799, 224, 224)
# Exemplo dos labels (False = original, True = com ruído): [0 0 0 ... 1 1 1]

# %%
X_train, X_test, y_train, y_test, paths_train, paths_test = train_test_split(
        all_specs, all_labels, all_image_paths,
        test_size=TEST_SIZE, 
        stratify=all_labels,
#       random_state=53
    )

# %%
def plot_specs(specs, title):
    total_images = len(specs)
    imgs_per_figure = 100
    cols = 5
    rows = (imgs_per_figure + cols - 1) // cols

    for start in range(0, total_images, imgs_per_figure):
        plt.figure(figsize=(cols * 3, rows * 3))
        end = min(start + imgs_per_figure, total_images)
        
        for i in range(start, end):
            plt.subplot(rows, cols, i - start + 1)
            plt.imshow(specs[i], cmap='gray')
            plt.title(f"{title} - freq spec: img {i+1}")
            plt.axis('off')
            
        plt.tight_layout()
        plt.show()

# %%
# Plotar todos os espectros de teste
#plot_specs(X_test, title="test")

# %%
#pausa de teste

# %%
# Defines the model layers (now for ResNet50)
def model_resnet50():  # (Optional: Rename the function for clarity)
    # Camada de entrada para imagens em escala de cinza (mantido igual)
    inputs = Input(shape=(224, 224, 1))
    
    # 1. Conversão para 3 canais (mantido igual)
    x = Lambda(lambda x: tf.repeat(x, 3, axis=-1))(inputs)
    
    # 2. Pré-processamento ResNet (mantido igual)
    x = tf.keras.applications.resnet.preprocess_input(x)
    
    # 3. *** ALTERAÇÃO PRINCIPAL: Carregar ResNet-50 ***
    base_model = tf.keras.applications.ResNet50(
        weights='imagenet',
        include_top=False,
        input_tensor=x
    )
    
    # 4. Topo personalizado (mantido igual)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(150, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    x = Dense(100, kernel_regularizer=regularizers.l2(0.01), activation='relu')(x)
    x = Dropout(0.25)(x)
    
    outputs = Dense(2, activation='softmax')(x)
    
    # Compilação (mantido igual)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer='Adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []

# Configurar K-Fold com random_state fixo para reprodutibilidade
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=53)

# Verificar quais folds já foram completados
completed_folds = []
for f in range(1, 6):
    model_path = output_dir + f'model_{nome}_fold_{f}.keras'
    if os.path.exists(model_path):
        completed_folds.append(f)
print(f"Folds concluídos: {completed_folds}")

fold_no = 1
histories = []
metrics = []

for train_idx, val_idx in kfold.split(X_train, y_train):
    # Pular folds já concluídos
    if fold_no in completed_folds:
        print(f"\nPulando fold {fold_no} (já concluído)")
        fold_no += 1
        continue

    print(f'\nTreinando Fold {fold_no}/5')
    
    # Split dos dados
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]

    # Pré-processamento final
    X_train_fold = np.expand_dims(X_train_fold, axis=-1)
    X_val_fold = np.expand_dims(X_val_fold, axis=-1)
    y_train_fold_cat = to_categorical(y_train_fold, 2)
    y_val_fold_cat = to_categorical(y_val_fold, 2)

    # Criar novo modelo para cada fold
    model = model_resnet50()

    # Checkpoint com nome do fold
    checkpoint_filepath = output_dir + f'model_{nome}_fold_{fold_no}.keras'
    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss'),
        tf.keras.callbacks.TensorBoard(log_dir='logs'),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=False,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
            verbose=1
        )
    ]

    # Calcula tempo (start)
    start_time = time.time()
    
    # Treinar modelo
    history = model.fit(
        X_train_fold, y_train_fold_cat,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val_fold, y_val_fold_cat),
        callbacks=callbacks,
        verbose=1
    )

    # Calcula tempo (end)
    end_time = time.time()

    training_time = end_time - start_time
    print(f"\nO modelo demorou {training_time:.2f} segundos para treinar.")

    # Coletar métricas e salvar modelo
    predictions = model.predict(X_val_fold)
    y_pred = np.argmax(predictions, axis=1)
    
    metrics.append({
        'fold': fold_no,
        'report': classification_report(y_val_fold, y_pred, output_dict=True, zero_division=0),
        'matrix': confusion_matrix(y_val_fold, y_pred)
    })

    # Métricas de classificação (por fold)
    acc.append(accuracy_score(y_val_fold, y_pred))
    jacc.append(jaccard_score(y_val_fold, y_pred))
    f1.append(f1_score(y_val_fold, y_pred))
    prec.append(precision_score(y_val_fold, y_pred))
    rec.append(recall_score(y_val_fold, y_pred))

    # Salvar métricas em um arquivo .txt
    metrics_filename = os.path.join(output_dir, f'metrics_{nome}_fold_{fold_no}.txt')
    with open(metrics_filename, 'w') as f:
        f.write(f"Fold {fold_no} Metrics:\n")
        f.write(f"Accuracy: {acc[-1]}\n")
        f.write(f"Jaccard Score: {jacc[-1]}\n")
        f.write(f"F1 Score: {f1[-1]}\n")
        f.write(f"Precision: {prec[-1]}\n")
        f.write(f"Recall: {rec[-1]}\n")
        f.write("\nClassification Report:\n")
        f.write(classification_report(y_val_fold, y_pred, zero_division=0))
        f.write("\nConfusion Matrix:\n")
        f.write(np.array2string(confusion_matrix(y_val_fold, y_pred)))

    # Limpeza de memória
    del model
    tf.keras.backend.clear_session()
    gc.collect()

    # Salvar checkpoint a cada 3 folds
    if fold_no % 3 == 0:
        print(f"\nCheckpoint: Folds {fold_no-2}-{fold_no} concluídos")

    fold_no += 1
# Out:
# Folds concluídos: [1, 2, 3, 4]
#
# Pulando fold 1 (já concluído)
#
# Pulando fold 2 (já concluído)
#
# Pulando fold 3 (já concluído)
#
# Pulando fold 4 (já concluído)
#
# Treinando Fold 5/5
# I0000 00:00:1743103499.081400   37148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743103499.081509   37148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743103499.081563   37148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743103499.408515   37148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743103499.408610   37148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-27 16:24:59.408635: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1743103499.408719   37148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:10:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-27 16:24:59.408742: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:10:00.0, compute capability: 8.6
# Epoch 1/200
# I0000 00:00:1743103525.443715   37216 service.cc:146] XLA service 0x7f3b84002820 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1743103525.443755   37216 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-03-27 16:25:26.392467: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-27 16:25:28.860384: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 2025-03-27 16:25:32.038459: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_15567', 196 bytes spill stores, 196 bytes spill loads
#
# I0000 00:00:1743103555.828256   37216 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 667ms/step - accuracy: 0.6209 - loss: 4.0309
# 2025-03-27 16:26:31.494873: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1760', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-03-27 16:26:31.859579: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1760', 12 bytes spill stores, 12 bytes spill loads
# Epoch 1: val_accuracy improved from -inf to 0.50155, saving model to 11-CNN-espectro-ResNet50 results (4%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 94s 981ms/step - accuracy: 0.6236 - loss: 4.0136 - val_accuracy: 0.5015 - val_loss: 377.7032
# Epoch 2/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9777 - loss: 1.4439
# Epoch 2: val_accuracy improved from 0.50155 to 0.56656, saving model to 11-CNN-espectro-ResNet50 results (4%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 196ms/step - accuracy: 0.9777 - loss: 1.4385 - val_accuracy: 0.5666 - val_loss: 1.3931
# Epoch 3/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9864 - loss: 0.7020
# Epoch 3: val_accuracy did not improve from 0.56656
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9866 - loss: 0.6993 - val_accuracy: 0.5666 - val_loss: 1.3389
# Epoch 4/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9997 - loss: 0.3552
# Epoch 4: val_accuracy did not improve from 0.56656
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9996 - loss: 0.3542 - val_accuracy: 0.4985 - val_loss: 0.9983
# Epoch 5/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9971 - loss: 0.2245
# Epoch 5: val_accuracy did not improve from 0.56656
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9971 - loss: 0.2241 - val_accuracy: 0.5418 - val_loss: 0.8561
# Epoch 6/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9974 - loss: 0.1547
# Epoch 6: val_accuracy improved from 0.56656 to 0.82043, saving model to 11-CNN-espectro-ResNet50 results (4%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 301ms/step - accuracy: 0.9974 - loss: 0.1544 - val_accuracy: 0.8204 - val_loss: 0.5753
# Epoch 7/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.1082
# Epoch 7: val_accuracy improved from 0.82043 to 0.96594, saving model to 11-CNN-espectro-ResNet50 results (4%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 197ms/step - accuracy: 1.0000 - loss: 0.1081 - val_accuracy: 0.9659 - val_loss: 0.3682
# Epoch 8/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0810
# Epoch 8: val_accuracy improved from 0.96594 to 0.99071, saving model to 11-CNN-espectro-ResNet50 results (4%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 192ms/step - accuracy: 1.0000 - loss: 0.0809 - val_accuracy: 0.9907 - val_loss: 0.2723
# Epoch 9/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0637
# Epoch 9: val_accuracy improved from 0.99071 to 0.99690, saving model to 11-CNN-espectro-ResNet50 results (4%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 195ms/step - accuracy: 1.0000 - loss: 0.0636 - val_accuracy: 0.9969 - val_loss: 0.2138
# Epoch 10/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 1.0000 - loss: 0.0528
# Epoch 10: val_accuracy did not improve from 0.99690
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 1.0000 - loss: 0.0527 - val_accuracy: 0.9938 - val_loss: 0.1512
# Epoch 11/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0444
# Epoch 11: val_accuracy improved from 0.99690 to 1.00000, saving model to 11-CNN-espectro-ResNet50 results (4%)/model_Yildirim_fold_5.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 195ms/step - accuracy: 1.0000 - loss: 0.0444 - val_accuracy: 1.0000 - val_loss: 0.1070
# Epoch 12/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0360
# Epoch 12: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0359 - val_accuracy: 1.0000 - val_loss: 0.0705
# Epoch 13/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0307
# Epoch 13: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0307 - val_accuracy: 1.0000 - val_loss: 0.0521
# Epoch 14/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0264
# Epoch 14: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0264 - val_accuracy: 1.0000 - val_loss: 0.0402
# Epoch 15/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 1.0000 - loss: 0.0254
# Epoch 15: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 1.0000 - loss: 0.0254 - val_accuracy: 1.0000 - val_loss: 0.0266
# Epoch 16/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0205
# Epoch 16: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0205 - val_accuracy: 1.0000 - val_loss: 0.0215
# Epoch 17/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0188
# Epoch 17: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 0.0200
# Epoch 18/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0165
# Epoch 18: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0165 - val_accuracy: 1.0000 - val_loss: 0.0255
# Epoch 19/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0163
# Epoch 19: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 0.9845 - val_loss: 0.0780
# Epoch 20/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9895 - loss: 0.0749
# Epoch 20: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - accuracy: 0.9895 - loss: 0.0751 - val_accuracy: 0.5015 - val_loss: 5943.3809
# Epoch 21/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9945 - loss: 0.0621
# Epoch 21: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9945 - loss: 0.0617 - val_accuracy: 0.5387 - val_loss: 16.7758
# Epoch 22/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9241 - loss: 0.2821
# Epoch 22: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9246 - loss: 0.2814 - val_accuracy: 0.5015 - val_loss: 2605.3391
# Epoch 23/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9989 - loss: 0.0647
# Epoch 23: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9989 - loss: 0.0645 - val_accuracy: 0.5015 - val_loss: 60.3094
# Epoch 24/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9980 - loss: 0.0455
# Epoch 24: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9979 - loss: 0.0456 - val_accuracy: 0.8235 - val_loss: 3.9968
# Epoch 25/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 1.0000 - loss: 0.0297
# Epoch 25: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 1.0000 - loss: 0.0296 - val_accuracy: 0.9938 - val_loss: 0.0853
# Epoch 26/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9987 - loss: 0.0203
# Epoch 26: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9987 - loss: 0.0202 - val_accuracy: 1.0000 - val_loss: 0.0189
# Epoch 27/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9992 - loss: 0.0190
# Epoch 27: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9992 - loss: 0.0190 - val_accuracy: 0.9938 - val_loss: 0.0415
# Epoch 28/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0145
# Epoch 28: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 0.0145
# Epoch 29/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0142
# Epoch 29: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 0.9969 - val_loss: 0.0294
# Epoch 30/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9979 - loss: 0.0197
# Epoch 30: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - accuracy: 0.9978 - loss: 0.0201 - val_accuracy: 0.9226 - val_loss: 1.0146
# Epoch 31/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9995 - loss: 0.0311
# Epoch 31: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 0.9995 - loss: 0.0311 - val_accuracy: 0.9938 - val_loss: 0.0658
# Epoch 32/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9981 - loss: 0.0205
# Epoch 32: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9981 - loss: 0.0205 - val_accuracy: 0.9969 - val_loss: 0.0152
# Epoch 33/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9987 - loss: 0.0200
# Epoch 33: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9987 - loss: 0.0199 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 34/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0120
# Epoch 34: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 0.0139
# Epoch 35/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0105
# Epoch 35: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.9969 - val_loss: 0.0153
# Epoch 36/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9996 - loss: 0.0110
# Epoch 36: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9996 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0132
# Epoch 37/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0112
# Epoch 37: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 1.0000 - val_loss: 0.0096
# Epoch 38/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9990 - loss: 0.0097
# Epoch 38: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 0.9990 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 39/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 39: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 40/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 40: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 0.0089
# Epoch 41/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 41: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.9969 - val_loss: 0.0103
# Epoch 42/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 42: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9969 - val_loss: 0.0093
# Epoch 43/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 43: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0092
# Epoch 44/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 44: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9969 - val_loss: 0.0090
# Epoch 45/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0063
# Epoch 45: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9969 - val_loss: 0.0134
# Epoch 46/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 46: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 241ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 47/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 47: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 48/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 48: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 49/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 49: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 50/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0063
# Epoch 50: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9969 - val_loss: 0.0081
# Epoch 51/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 51: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 52/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 52: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 53/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9998 - loss: 0.0075
# Epoch 53: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9998 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 54/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 54: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 55/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 55: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9814 - val_loss: 0.2187
# Epoch 56/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9993 - loss: 0.0078
# Epoch 56: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - accuracy: 0.9993 - loss: 0.0078 - val_accuracy: 0.9938 - val_loss: 0.0618
# Epoch 57/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 57: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9999 - loss: 0.0066 - val_accuracy: 0.9969 - val_loss: 0.0239
# Epoch 58/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 58: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9969 - val_loss: 0.0117
# Epoch 59/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 59: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 60/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 60: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9969 - val_loss: 0.0335
# Epoch 61/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 61: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.9969 - val_loss: 0.0122
# Epoch 62/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 62: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9969 - val_loss: 0.0189
# Epoch 63/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 63: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 64/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9998 - loss: 0.0045
# Epoch 64: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9998 - loss: 0.0045 - val_accuracy: 0.9969 - val_loss: 0.0239
# Epoch 65/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9993 - loss: 0.0122
# Epoch 65: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9993 - loss: 0.0122 - val_accuracy: 0.9969 - val_loss: 0.0203
# Epoch 66/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9994 - loss: 0.0101
# Epoch 66: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9994 - loss: 0.0101 - val_accuracy: 0.9969 - val_loss: 0.0166
# Epoch 67/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9974 - loss: 0.0164
# Epoch 67: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 0.9974 - loss: 0.0164 - val_accuracy: 0.9969 - val_loss: 0.0222
# Epoch 68/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9992 - loss: 0.0208
# Epoch 68: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9990 - loss: 0.0245 - val_accuracy: 0.9752 - val_loss: 0.0680
# Epoch 69/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9023 - loss: 0.3903
# Epoch 69: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9008 - loss: 0.3924 - val_accuracy: 0.5015 - val_loss: 100.9034
# Epoch 70/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5035 - loss: 0.8587
# Epoch 70: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.5035 - loss: 0.8579 - val_accuracy: 0.5015 - val_loss: 21.3898
# Epoch 71/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5961 - loss: 0.7139
# Epoch 71: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.5970 - loss: 0.7130 - val_accuracy: 0.5015 - val_loss: 145.3742
# Epoch 72/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.7529 - loss: 0.5445
# Epoch 72: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 0.7549 - loss: 0.5418 - val_accuracy: 0.5015 - val_loss: 422.4375
# Epoch 73/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9725 - loss: 0.1894
# Epoch 73: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9724 - loss: 0.1892 - val_accuracy: 0.5015 - val_loss: 52.7580
# Epoch 74/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9912 - loss: 0.0975
# Epoch 74: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9911 - loss: 0.0974 - val_accuracy: 0.5015 - val_loss: 10.2956
# Epoch 75/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9907 - loss: 0.0675
# Epoch 75: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9908 - loss: 0.0673 - val_accuracy: 0.7678 - val_loss: 0.9063
# Epoch 76/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9953 - loss: 0.0494
# Epoch 76: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9953 - loss: 0.0492 - val_accuracy: 0.9969 - val_loss: 0.0334
# Epoch 77/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0290
# Epoch 77: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 1.0000 - loss: 0.0290 - val_accuracy: 1.0000 - val_loss: 0.0246
# Epoch 78/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0239
# Epoch 78: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 1.0000 - loss: 0.0239 - val_accuracy: 1.0000 - val_loss: 0.0224
# Epoch 79/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0223
# Epoch 79: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: 1.0000 - val_loss: 0.0194
# Epoch 80/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9964 - loss: 0.0440
# Epoch 80: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9964 - loss: 0.0438 - val_accuracy: 0.9969 - val_loss: 0.0243
# Epoch 81/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9967 - loss: 0.0222
# Epoch 81: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9968 - loss: 0.0222 - val_accuracy: 1.0000 - val_loss: 0.0191
# Epoch 82/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0167
# Epoch 82: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - accuracy: 1.0000 - loss: 0.0167 - val_accuracy: 0.9969 - val_loss: 0.0234
# Epoch 83/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9917 - loss: 0.0378
# Epoch 83: val_accuracy did not improve from 1.00000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 0.9918 - loss: 0.0379 - val_accuracy: 0.9783 - val_loss: 0.1211
#
# O modelo demorou 668.97 segundos para treinar.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step

# %%
print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
print("Dice: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))
# Out:
# Accuracy: 0.978328173374613+- 0.0
# Jaccard: 0.9585798816568047+- 0.0
# Dice: 0.9788519637462235+- 0.0
# Precision: 0.9585798816568047+- 0.0
# Recall: 1.0+- 0.0

# %%
# GC collect
tf.keras.backend.clear_session()
gc.collect()
# Out:
# 0
